# %% [markdown]
# # Code to be added to utils

# %% [markdown]
# ## plotting utils

# %%
def tiss_cell_fractions(adata,
                        technology_col='method', # this makes separate plots
                        breakby='tissue', # this makes separate plots
                        category='cell_ontology_class',
                        dataset="Pilot2",
                        groupby = "donor"):
    
    
    import sys
    sys.path.append('/home/angela/sapiens/tabula-sapiens/')
    from utils.colorDict import donor_colors
    donors_color_dict = donor_colors()
    
    for m in set(adata.obs[technology_col]):
        adata_subset = adata[adata.obs[technology_col] == m].copy()
        adata_subset = remove_cats(adata_subset)
        for t in set(adata_subset.obs[breakby]):
            print(t)
            tiss = adata_subset[adata_subset.obs[breakby] == t].copy()
            tiss = remove_cats(tiss)

#             aux = tiss.obs.groupby([category,groupby]).count()
#             aux = pd.DataFrame(aux).reset_index()
#             aux['fraction'] = aux[aux.columns[1]]/aux[aux.columns[1]].sum()
#             aux['cell_number'] = aux[aux.columns[1]]
            aux = tiss.obs.groupby([category,groupby])['cell_id'].count()
            aux = pd.DataFrame(aux).reset_index()
            aux['fraction'] = aux['cell_id']/aux['cell_id'].sum()
            aux['cell_number'] = aux['cell_id']

#             aux[[category,'fraction','cell_number']].to_csv("./cell_fractions/"+dataset+"_"+m+"_"+t+'.csv')

            f, ax = plt.subplots(figsize=(15,10)) 
            g = sns.barplot(data = aux, y = 'fraction',x = category, 
                            hue = groupby,palette=donors_color_dict,
                            ax = ax)
            ax.set_xticklabels(ax.get_xticklabels(),rotation=90);
            ax.set(xlabel= dataset +" "+ t +' cell types', ylabel='Relative abundance in'+ m +' data');
            plt.tight_layout()
#             plt.savefig("./cell_fractions/"+dataset+"_"+m+"_"+t+'.pdf')

# %%
pwd
# Out:
# '/data/angela/sapiens/tabula-sapiens/analysis-scripts/publication/v0'

# %% [markdown]
# # Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import scanpy as sc
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# %%
import sys
sys.path.append('/data/angela/src/scVI_TSP/')
sys.path.append('/data/angela/sapiens/tabula-sapiens/')
# from utils.annotations_utils import *
from utils.colorDict import *
from utils.general_utils import *
from utils.plotting_utils import *

# %% [markdown]
# # Load color dicts

# %%
donors_color_dict = donor_colors()
tissues_color_dict = tissue_colors()
methods_color_dict = method_colors()
compartments_color_dict = compartment_colors()

# %% [markdown]
# # Read data

# %%
data_path = "/mnt/ibm_lg/angela/sapiens/data/sapiens_paper1/"

# %%
adata = pd.read_csv(
    "/mnt/ibm_lg/angela/sapiens/data/TSP1_TSP15/TSP1_TSP15_metadata_clean.csv",
    low_memory=False
)
# adata = remove_cats(adata)
adata
# Out:
#                                                   cell_id donor       tissue  \
# 0                  AAACCCACACTCCTGT_TSP6_Liver_NA_10X_1_1  TSP6        Liver
# 1                  AAACGAAGTACCAGAG_TSP6_Liver_NA_10X_1_1  TSP6        Liver
# 2                  AAACGCTCAACGGCTC_TSP6_Liver_NA_10X_1_1  TSP6        Liver
# 3                  AAAGAACAGCCTCTTC_TSP6_Liver_NA_10X_1_1  TSP6        Liver
# 4                  AAAGAACGTAGCACAG_TSP6_Liver_NA_10X_1_1  TSP6        Liver
# ...                                                   ...   ...          ...
# 481115  TSP2_Vasculature_aorta_SS2_B114577_B133059_End...  TSP2  Vasculature
# 481116  TSP2_Vasculature_aorta_SS2_B114577_B133059_End...  TSP2  Vasculature
# 481117  TSP2_Vasculature_aorta_SS2_B114577_B133059_End...  TSP2  Vasculature
# 481118  TSP2_Vasculature_aorta_SS2_B114577_B133059_End...  TSP2  Vasculature
# 481119  TSP2_Vasculature_aorta_SS2_B114577_B133059_End...  TSP2  Vasculature
#
#        anatomical_position     method                   cell_ontology_class  \
# 0                      NaN        10X                            macrophage
# 1                      NaN        10X                              monocyte
# 2                      NaN        10X  endothelial cell of hepatic sinusoid
# 3                      NaN        10X                            macrophage
# 4                      NaN        10X                  liver dendritic cell
# ...                    ...        ...                                   ...
# 481115               aorta  smartseq2                      endothelial cell
# 481116               aorta  smartseq2                      endothelial cell
# 481117               aorta  smartseq2                      endothelial cell
# 481118               aorta  smartseq2                      endothelial cell
# 481119               aorta  smartseq2                      endothelial cell
#
#             free_annotation consensus_prediction  consensus_percentage  \
# 0       Monocyte/Macrophage           macrophage                 42.86
# 1                  Monocyte             monocyte                 42.86
# 2               Endothelial     endothelial cell                 28.57
# 3       Monocyte/Macrophage           macrophage                 85.71
# 4            Dendritic cell       dendritic cell                 57.14
# ...                     ...                  ...                   ...
# 481115     endothelial cell     endothelial cell                  1.00
# 481116     endothelial cell     endothelial cell                  0.86
# 481117     endothelial cell     endothelial cell                  1.00
# 481118     endothelial cell     endothelial cell                  1.00
# 481119     endothelial cell     endothelial cell                  1.00
#
#         manually_annotated  ...       10X_barcode  cDNAplate  libraryplate  \
# 0                     True  ...  AAACCCACACTCCTGT        NaN           NaN
# 1                     True  ...  AAACGAAGTACCAGAG        NaN           NaN
# 2                     True  ...  AAACGCTCAACGGCTC        NaN           NaN
# 3                     True  ...  AAAGAACAGCCTCTTC        NaN           NaN
# 4                     True  ...  AAAGAACGTAGCACAG        NaN           NaN
# ...                    ...  ...               ...        ...           ...
# 481115                True  ...               NaN        NaN           NaN
# 481116                True  ...               NaN        NaN           NaN
# 481117                True  ...               NaN        NaN           NaN
# 481118                True  ...               NaN        NaN           NaN
# 481119                True  ...               NaN        NaN           NaN
#
#        well notes seqrun                                    cell_identifier  \
# 0       NaN   NaN      5             AAACCCACACTCCTGT_TSP6_Liver_NA_10X_1_1
# 1       NaN   NaN      5             AAACGAAGTACCAGAG_TSP6_Liver_NA_10X_1_1
# 2       NaN   NaN      5             AAACGCTCAACGGCTC_TSP6_Liver_NA_10X_1_1
# 3       NaN   NaN      5             AAAGAACAGCCTCTTC_TSP6_Liver_NA_10X_1_1
# 4       NaN   NaN      5             AAAGAACGTAGCACAG_TSP6_Liver_NA_10X_1_1
# ...     ...   ...    ...                                                ...
# 481115  NaN   NaN      2  TSP2_Vasculature_aorta_SS2_B114577_B133059_End...
# 481116  NaN   NaN      2  TSP2_Vasculature_aorta_SS2_B114577_B133059_End...
# 481117  NaN   NaN      2  TSP2_Vasculature_aorta_SS2_B114577_B133059_End...
# 481118  NaN   NaN      2  TSP2_Vasculature_aorta_SS2_B114577_B133059_End...
# 481119  NaN   NaN      2  TSP2_Vasculature_aorta_SS2_B114577_B133059_End...
#
#         n_counts n_genes  compartment
# 0         7633.0    2259       immune
# 1         2858.0    1152       immune
# 2         7787.0    2983  endothelial
# 3        10395.0    2598       immune
# 4         6610.0    2125       immune
# ...          ...     ...          ...
# 481115   13205.0     579  endothelial
# 481116    9565.0     529  endothelial
# 481117  195639.0    2753  endothelial
# 481118   37260.0     984  endothelial
# 481119   63837.0    1509  endothelial
#
# [481120 rows x 23 columns]

# %% [markdown]
# # Generate figures

# %% [markdown]
# ## Sequencing data

# %%
# metadata = adata.obs.copy()
metadata = adata.copy()

metadata.head()
# Out:
#                                   cell_id donor tissue anatomical_position  \
# 0  AAACCCACACTCCTGT_TSP6_Liver_NA_10X_1_1  TSP6  Liver                 NaN
# 1  AAACGAAGTACCAGAG_TSP6_Liver_NA_10X_1_1  TSP6  Liver                 NaN
# 2  AAACGCTCAACGGCTC_TSP6_Liver_NA_10X_1_1  TSP6  Liver                 NaN
# 3  AAAGAACAGCCTCTTC_TSP6_Liver_NA_10X_1_1  TSP6  Liver                 NaN
# 4  AAAGAACGTAGCACAG_TSP6_Liver_NA_10X_1_1  TSP6  Liver                 NaN
#
#   method                   cell_ontology_class      free_annotation  \
# 0    10X                            macrophage  Monocyte/Macrophage
# 1    10X                              monocyte             Monocyte
# 2    10X  endothelial cell of hepatic sinusoid          Endothelial
# 3    10X                            macrophage  Monocyte/Macrophage
# 4    10X                  liver dendritic cell       Dendritic cell
#
#   consensus_prediction  consensus_percentage  manually_annotated  ...  \
# 0           macrophage                 42.86                True  ...
# 1             monocyte                 42.86                True  ...
# 2     endothelial cell                 28.57                True  ...
# 3           macrophage                 85.71                True  ...
# 4       dendritic cell                 57.14                True  ...
#
#         10X_barcode  cDNAplate  libraryplate well notes seqrun  \
# 0  AAACCCACACTCCTGT        NaN           NaN  NaN   NaN      5
# 1  AAACGAAGTACCAGAG        NaN           NaN  NaN   NaN      5
# 2  AAACGCTCAACGGCTC        NaN           NaN  NaN   NaN      5
# 3  AAAGAACAGCCTCTTC        NaN           NaN  NaN   NaN      5
# 4  AAAGAACGTAGCACAG        NaN           NaN  NaN   NaN      5
#
#                           cell_identifier n_counts n_genes  compartment
# 0  AAACCCACACTCCTGT_TSP6_Liver_NA_10X_1_1   7633.0    2259       immune
# 1  AAACGAAGTACCAGAG_TSP6_Liver_NA_10X_1_1   2858.0    1152       immune
# 2  AAACGCTCAACGGCTC_TSP6_Liver_NA_10X_1_1   7787.0    2983  endothelial
# 3  AAAGAACAGCCTCTTC_TSP6_Liver_NA_10X_1_1  10395.0    2598       immune
# 4  AAAGAACGTAGCACAG_TSP6_Liver_NA_10X_1_1   6610.0    2125       immune
#
# [5 rows x 23 columns]

# %%
# df = pd.DataFrame(metadata.groupby(['donor','tissue','compartment','cell_ontology_type'])['cell_id'].count())
df = metadata[metadata['method']=='10X'].copy()
df["cell_id"] = df.index.copy()
# df["tissue"] = df["Organ"].copy()
df = pd.DataFrame(df.groupby(['tissue','compartment','donor'])['cell_id'].count())
df = df.reset_index()
df = pd.pivot_table(data = df,values='cell_id', index=['tissue','donor'],columns=['compartment'])
df = df.replace({np.nan:0})
df['sum'] = df.sum(axis=1)
df.iloc[:, :] = df.iloc[:, :].div(df['sum'],axis=0)*100
df = df.drop('sum',axis=1)
df
# Out:
# compartment            endothelial  epithelial  germ line      immune  \
# tissue          donor
# Bladder         TSP1      1.760116   16.185810   0.000000   40.074397
#                 TSP2      1.328477    9.235055   0.000000   59.031498
# Blood           TSP1      0.000000    0.000000   0.000000  100.000000
#                 TSP10     0.000000    0.000000   0.000000  100.000000
#                 TSP14     0.000000    0.000000   0.000000  100.000000
#                 TSP2      0.000000    0.000000   0.000000  100.000000
#                 TSP7      0.000000    0.000000   0.000000  100.000000
#                 TSP8      0.000000    0.000000   0.000000  100.000000
# Bone_Marrow     TSP11     0.000000    0.000000   0.000000  100.000000
#                 TSP14     0.000000    0.000000   0.000000  100.000000
#                 TSP2      0.000000    0.000000   0.000000  100.000000
# Eye             TSP15     9.623953   66.583497   0.000000    7.859562
#                 TSP3      0.046232   99.815072   0.000000    0.092464
#                 TSP5      1.016673   79.056527   0.000000   12.240748
# Fat             TSP10    14.980740    0.000000   0.000000   29.098978
#                 TSP14    24.458931    0.000000   0.000000   40.299870
# Heart           TSP12    22.773424    9.262558   0.000000    0.427503
# Kidney          TSP2      1.024701   87.994823   0.000000   10.980477
# Large_Intestine TSP14     0.271003   36.515430   0.000000   55.765364
#                 TSP2      1.222902   89.772096   0.000000    3.835464
# Liver           TSP14    16.162087   70.889613   0.000000   12.668840
#                 TSP6     12.466944    2.531167   0.000000   82.508500
# Lung            TSP1      2.893916   14.781357   0.000000   80.669918
#                 TSP14     1.080460   89.011494   0.000000    8.758621
#                 TSP2     12.574711   44.774560   0.000000   40.068473
# Lymph_Node      TSP14     0.450258    0.000000   0.000000   99.201367
#                 TSP2      0.105325    0.000000   0.000000   99.894675
#                 TSP7      0.033560    0.000000   0.000000   99.924490
# Mammary         TSP4      4.094488   52.153775   0.000000   23.983326
# Muscle          TSP1     29.020701    0.000000   0.000000    5.254777
#                 TSP14     7.684060    0.000000   0.000000    8.291637
#                 TSP2     22.220720    0.000000   0.000000    8.197608
# Pancreas        TSP1      4.044180   93.916737   0.000000    1.478335
#                 TSP9     27.735792   29.262394   0.000000   36.955865
# Prostate        TSP14     3.473492   64.929921   0.335161   30.773918
#                 TSP8      3.870173   77.781430   0.000000   14.305670
# Salivary_Gland  TSP14     2.803738   62.678752   0.000000   26.145704
#                 TSP7      1.685067   22.742592   0.000000   63.625799
# Skin            TSP10    13.986850    1.175533   0.000000   52.261407
#                 TSP14    13.367032    0.140410   0.000000   38.528503
# Small_Intestine TSP14     0.143431   18.483458   0.000000   80.531650
#                 TSP2      2.209551   84.034212   0.000000   12.045617
# Spleen          TSP14     0.674963    0.000000   0.000000   99.325037
#                 TSP2      2.329053    0.000000   0.000000   97.670947
#                 TSP7      4.633516    0.000000   0.000000   95.366484
# Thymus          TSP14    11.289276    0.648809   0.000000   66.326814
#                 TSP2     13.954906    0.295987   0.000000   75.406982
# Tongue          TSP14     5.335056   81.410375   0.000000    9.119439
#                 TSP7      1.339503   83.170969   0.000000   13.638578
# Trachea         TSP2      0.770128   92.998833   0.000000    0.420070
#                 TSP6      4.031073   17.069074   0.000000   53.327735
# Uterus          TSP4     31.324949    3.495174   0.000000   13.381106
# Vasculature     TSP14    14.614745    0.000000   0.000000   20.574617
#                 TSP2     16.331240    0.333291   0.000000   26.791437
#
# compartment              stromal
# tissue          donor
# Bladder         TSP1   41.979677
#                 TSP2   30.404971
# Blood           TSP1    0.000000
#                 TSP10   0.000000
#                 TSP14   0.000000
#                 TSP2    0.000000
#                 TSP7    0.000000
#                 TSP8    0.000000
# Bone_Marrow     TSP11   0.000000
#                 TSP14   0.000000
#                 TSP2    0.000000
# Eye             TSP15  15.932989
#                 TSP3    0.046232
#                 TSP5    7.686051
# Fat             TSP10  55.920281
#                 TSP14  35.241199
# Heart           TSP12  67.536516
# Kidney          TSP2    0.000000
# Large_Intestine TSP14   7.448204
#                 TSP2    5.169539
# Liver           TSP14   0.279460
#                 TSP6    2.493389
# Lung            TSP1    1.654809
#                 TSP14   1.149425
#                 TSP2    2.582255
# Lymph_Node      TSP14   0.348375
#                 TSP2    0.000000
#                 TSP7    0.041950
# Mammary         TSP4   19.768411
# Muscle          TSP1   65.724522
#                 TSP14  84.024303
#                 TSP2   69.581672
# Pancreas        TSP1    0.560748
#                 TSP9    6.045949
# Prostate        TSP14   0.487508
#                 TSP8    4.042728
# Salivary_Gland  TSP14   8.371805
#                 TSP7   11.946543
# Skin            TSP10  32.576210
#                 TSP14  47.964055
# Small_Intestine TSP14   0.841461
#                 TSP2    1.710620
# Spleen          TSP14   0.000000
#                 TSP2    0.000000
#                 TSP7    0.000000
# Thymus          TSP14  21.735101
#                 TSP2   10.342126
# Tongue          TSP14   4.135130
#                 TSP7    1.850950
# Trachea         TSP2    5.810968
#                 TSP6   25.572118
# Uterus          TSP4   51.798772
# Vasculature     TSP14  64.810638
#                 TSP2   56.544033

# %%
# # df = pd.DataFrame(metadata.groupby(['donor','tissue','compartment','cell_ontology_type'])['cell_id'].count())
# df = metadata[metadata['method']=='10X'].copy()
# df = pd.DataFrame(df.groupby(['tissue','compartment'])['cell_id'].count())
# df = df.reset_index()
# df = pd.pivot_table(data = df,values='cell_id', index=['tissue'],columns=['compartment'])
# df = df.replace({np.nan:0})
# df['sum'] = df.sum(axis=1)
# df.iloc[:, :] = df.iloc[:, :].div(df['sum'],axis=0)*100
# df = df.drop('sum',axis=1)
# df

# %%
f = plt.figure(figsize=(10,8))
df.plot(
    kind='bar',stacked=True, ax=f.gca(),color=compartments_color_dict,legend=False
)
plt.savefig("figures/compartment_proportions_sequencing.pdf")

# %%
compartments_color_dict
# Out:
# {'endothelial': '#ffe793',
#  'epithelial': '#febf5a',
#  'immune': '#fd8c3c',
#  'stromal': '#f43d25',
#  'germ line': '#c90823',
#  'PNS': '#800026'}

# %% [markdown]
# ## Read Serena's table

# %% [markdown]
# ### TSP1+TSP2

# %%
pathology = pd.read_excel("Tabula Sapiens Tissue Abundance Ratios.xlsx",index_col=0)
pathology
# Out:
#                   Epithelilal  Endothelial  Stromal  Immune  Neuroglia  \
# Lymph Node                  0           15        7      78          0
# Spleen                      0           27       16      57          0
# Muscle                      0           32       65       3          0
# Diaphragm                   0           48       48       4          0
# Aorta                       0           13       81       6          0
# Duodenum                   35            5       24      35          1
# Ileum                      15            2       22      60          1
# Colon (Proximal)           40            5       29      25          1
# Colon (Distal)             35            5       34      25          1
# Bladder                    40           30       10      20          0
# Trachea                    40           10       40      10          0
# Lung (Proximal)            34           14       29      23          0
# Lung (Distal)              24           24       22      30          0
#
#                   Spatial Heterogeneity (AKA Error)
# Lymph Node                                        1
# Spleen                                            1
# Muscle                                            1
# Diaphragm                                         1
# Aorta                                             1
# Duodenum                                          2
# Ileum                                             2
# Colon (Proximal)                                  2
# Colon (Distal)                                    2
# Bladder                                           2
# Trachea                                           2
# Lung (Proximal)                                   3
# Lung (Distal)                                     3

# %%
pathology.columns
# Out:
# Index(['Epithelilal', 'Endothelial', 'Stromal', 'Immune', 'Neuroglia',
#        'Spatial Heterogeneity (AKA Error)'],
#       dtype='object')

# %%
pathology_pancreas = pd.read_csv("serena_tsp1_tsp2_count_per_cell_type.csv",index_col=0)
pathology_pancreas = pathology_pancreas.iloc[-4:]
pathology_pancreas
# Out:
#                                      endothelial_cell_count  \
# image_id
# PN 20x 1_pilot1_pancreas_labels.png                      10
# PN 20x 3_pilot1_pancreas_labels.png                      46
# PN 40x 5_pilot1_pancreas_labels.png                      58
# PN 40x 6_pilot1_pancreas_labels.png                      29
#
#                                      epithelial_cell_count  immune_cell_count  \
# image_id
# PN 20x 1_pilot1_pancreas_labels.png                   2378                 15
# PN 20x 3_pilot1_pancreas_labels.png                   1830                  8
# PN 40x 5_pilot1_pancreas_labels.png                     93                 19
# PN 40x 6_pilot1_pancreas_labels.png                     61                  0
#
#                                      stromal_cell_count  \
# image_id
# PN 20x 1_pilot1_pancreas_labels.png                 325
# PN 20x 3_pilot1_pancreas_labels.png                  91
# PN 40x 5_pilot1_pancreas_labels.png                 116
# PN 40x 6_pilot1_pancreas_labels.png                 306
#
#                                      endothelial_pixel_count  \
# image_id
# PN 20x 1_pilot1_pancreas_labels.png                      222
# PN 20x 3_pilot1_pancreas_labels.png                     1117
# PN 40x 5_pilot1_pancreas_labels.png                     5085
# PN 40x 6_pilot1_pancreas_labels.png                     2280
#
#                                      epithelial_pixel_count  \
# image_id
# PN 20x 1_pilot1_pancreas_labels.png                  117701
# PN 20x 3_pilot1_pancreas_labels.png                   83315
# PN 40x 5_pilot1_pancreas_labels.png                   11865
# PN 40x 6_pilot1_pancreas_labels.png                    7373
#
#                                      immune_pixel_count  stromal_pixel_count
# image_id
# PN 20x 1_pilot1_pancreas_labels.png                 809                14203
# PN 20x 3_pilot1_pancreas_labels.png                 253                 2473
# PN 40x 5_pilot1_pancreas_labels.png                1600                10279
# PN 40x 6_pilot1_pancreas_labels.png                   0                35055

# %%
pathology_pancreas = pathology_pancreas[["epithelial_cell_count","endothelial_cell_count","stromal_cell_count","immune_cell_count"]]
pathology_pancreas.columns = ['Epithelilal', 'Endothelial', 'Stromal', 'Immune']
pathology_pancreas['Neuroglia'] = 0
pathology_pancreas['Spatial Heterogeneity (AKA Error)'] = 0
pathology_pancreas.loc["Pancreas"] = pathology_pancreas.sum(axis=0)
pathology_pancreas
# Out:
# <ipython-input-19-9f8f5e41b4dc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pathology_pancreas['Neuroglia'] = 0
# <ipython-input-19-9f8f5e41b4dc>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pathology_pancreas['Spatial Heterogeneity (AKA Error)'] = 0
# /data/angela/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                                      Epithelilal  Endothelial  Stromal  \
# image_id
# PN 20x 1_pilot1_pancreas_labels.png         2378           10      325
# PN 20x 3_pilot1_pancreas_labels.png         1830           46       91
# PN 40x 5_pilot1_pancreas_labels.png           93           58      116
# PN 40x 6_pilot1_pancreas_labels.png           61           29      306
# Pancreas                                    4362          143      838
#
#                                      Immune  Neuroglia  \
# image_id
# PN 20x 1_pilot1_pancreas_labels.png      15          0
# PN 20x 3_pilot1_pancreas_labels.png       8          0
# PN 40x 5_pilot1_pancreas_labels.png      19          0
# PN 40x 6_pilot1_pancreas_labels.png       0          0
# Pancreas                                 42          0
#
#                                      Spatial Heterogeneity (AKA Error)
# image_id
# PN 20x 1_pilot1_pancreas_labels.png                                  0
# PN 20x 3_pilot1_pancreas_labels.png                                  0
# PN 40x 5_pilot1_pancreas_labels.png                                  0
# PN 40x 6_pilot1_pancreas_labels.png                                  0
# Pancreas                                                             0

# %%
pathology.loc["Pancreas"] = pathology_pancreas.loc["Pancreas"]

# %%
pathology = pathology.rename(
    {'Epithelilal':'epithelial','Neuroglia':'PNS',"Endothelial": "endothelial","Stromal":"stromal","Immune":"immune"},
    axis=1
)
pathology
# Out:
#                   epithelial  endothelial  stromal  immune  PNS  \
# Lymph Node                 0           15        7      78    0
# Spleen                     0           27       16      57    0
# Muscle                     0           32       65       3    0
# Diaphragm                  0           48       48       4    0
# Aorta                      0           13       81       6    0
# Duodenum                  35            5       24      35    1
# Ileum                     15            2       22      60    1
# Colon (Proximal)          40            5       29      25    1
# Colon (Distal)            35            5       34      25    1
# Bladder                   40           30       10      20    0
# Trachea                   40           10       40      10    0
# Lung (Proximal)           34           14       29      23    0
# Lung (Distal)             24           24       22      30    0
#
#                   Spatial Heterogeneity (AKA Error)
# Lymph Node                                        1
# Spleen                                            1
# Muscle                                            1
# Diaphragm                                         1
# Aorta                                             1
# Duodenum                                          2
# Ileum                                             2
# Colon (Proximal)                                  2
# Colon (Distal)                                    2
# Bladder                                           2
# Trachea                                           2
# Lung (Proximal)                                   3
# Lung (Distal)                                     3

# %%
f = plt.figure(figsize=(10,8))
pathology.drop('Spatial Heterogeneity (AKA Error)',axis=1).plot(
#     order = pathology["Spatial Heterogeneity (AKA Error)"],
    kind='bar',stacked=True, 
    ax=f.gca(),color=compartments_color_dict, 
    legend=True
)

plt.savefig("figures/compartment_proportions_pathology_tsp1_2.pdf")

# %% [markdown]
# ### TSP14

# %%
pathology_2 = pd.read_csv("Tabula_Sapiens_Tissue_Abundance_Ratios_TSP14.csv",index_col=0)
pathology_2
# Out:
#                       Epithelial  Endothelial  Stromal  Immune  PNS
# Tissue Type/Location
# Abdominal Muscle               0           60       30       0    0
# Anterior Tongue               15           10       62       8    5
# Ascending Colon               30            5       39      25    1
# Bladder                       50            5       34      10    1
# Diaphragm                      0           40       60       0    0
# Duodenum                      50            5        9      35    1
# Heart                          0           30       60      10    0
# Ileum                         20            5       43      30    2
# Liver                         75            5        5      15    0
# Lung (all distal)             27           25       21      27    0
# Mesenteric Fat                 0           10       80      10    0
# Pancreas                      65            5       20      10    0
# Parotid                       48           14       33       2    3
# Popsterior Tongue             20           10       52      15    3
# Sigmoid Colon                 30           10       33      25    2
# Spleen                         0           25       10      65    0
# Subcutaneous Fat               0            5       94       1    0
# Sublingual                    60           10       25       4    1
# Thymus                         0           10       60      30    0
# Trachea                       40           10       40      10    0

# %%
pathology_2["tissue"] = ["Muscle","Tongue","Large Intestine","Bladder",
                         "Muscle","Small Intestine","Heart", "Small Intestine",
                         "Liver","Lung","Fat","Pancreas",
                         "Salivary Gland","Tongue","Colon","Spleen",
                         "Fat","Salivary Gland","Thymus","Trachea"]

# %%
# pathology_2 = pathology[["endothelial_cell_count","epithelial_cell_count","immune_cell_count","stromal_cell_count"]]

# %%
pathology_2.columns = ["epithelial","endothelial","stromal","immune","PNS","tissue"]

# %%
pathology_2
# Out:
#                       epithelial  endothelial  stromal  immune  PNS  \
# Tissue Type/Location
# Abdominal Muscle               0           60       30       0    0
# Anterior Tongue               15           10       62       8    5
# Ascending Colon               30            5       39      25    1
# Bladder                       50            5       34      10    1
# Diaphragm                      0           40       60       0    0
# Duodenum                      50            5        9      35    1
# Heart                          0           30       60      10    0
# Ileum                         20            5       43      30    2
# Liver                         75            5        5      15    0
# Lung (all distal)             27           25       21      27    0
# Mesenteric Fat                 0           10       80      10    0
# Pancreas                      65            5       20      10    0
# Parotid                       48           14       33       2    3
# Popsterior Tongue             20           10       52      15    3
# Sigmoid Colon                 30           10       33      25    2
# Spleen                         0           25       10      65    0
# Subcutaneous Fat               0            5       94       1    0
# Sublingual                    60           10       25       4    1
# Thymus                         0           10       60      30    0
# Trachea                       40           10       40      10    0
#
#                                tissue
# Tissue Type/Location
# Abdominal Muscle               Muscle
# Anterior Tongue                Tongue
# Ascending Colon       Large Intestine
# Bladder                       Bladder
# Diaphragm                      Muscle
# Duodenum              Small Intestine
# Heart                           Heart
# Ileum                 Small Intestine
# Liver                           Liver
# Lung (all distal)                Lung
# Mesenteric Fat                    Fat
# Pancreas                     Pancreas
# Parotid                Salivary Gland
# Popsterior Tongue              Tongue
# Sigmoid Colon                   Colon
# Spleen                         Spleen
# Subcutaneous Fat                  Fat
# Sublingual             Salivary Gland
# Thymus                         Thymus
# Trachea                       Trachea

# %%
f = plt.figure(figsize=(10,8))
pathology_2.plot(
    kind='bar',stacked=True, ax=f.gca(),color=compartments_color_dict, legend=False
)

plt.savefig("figures/compartment_proportions_pathology_tsp14.pdf")

# %% [markdown]
# ## Updated Table

# %% [markdown]
# ### TSP1+TSP2

# %%
pathology = pd.read_excel("TabulaSapiensTissueAbundanceRatiosRevised.xlsx","TSP2",index_col=0)
pathology
# Out:
#                   Epithelilal  Endothelial  Stromal  Immune  Neuroglia  \
# Lymph Node                  0           15        7      78          0
# Spleen                      0           27       16      57          0
# Muscle                      0           32       65       3          0
# Diaphragm                   0           48       48       4          0
# Aorta                       0           13       81       6          0
# Duodenum                   35            5       24      35          1
# Ileum                      15            2       22      60          1
# Colon (Proximal)           40            5       29      25          1
# Colon (Distal)             35            5       34      25          1
# Bladder                    40           10       30      20          0
# Trachea                    40           10       40      10          0
# Lung (Proximal)            34           14       29      23          0
# Lung (Distal)              24           24       22      30          0
#
#                   Spatial Heterogeneity (AKA Error)
# Lymph Node                                        1
# Spleen                                            1
# Muscle                                            1
# Diaphragm                                         1
# Aorta                                             1
# Duodenum                                          2
# Ileum                                             2
# Colon (Proximal)                                  2
# Colon (Distal)                                    2
# Bladder                                           2
# Trachea                                           3
# Lung (Proximal)                                   3
# Lung (Distal)                                     3

# %%
pathology.columns
# Out:
# Index(['Epithelilal', 'Endothelial', 'Stromal', 'Immune', 'Neuroglia',
#        'Spatial Heterogeneity (AKA Error)'],
#       dtype='object')

# %%
pathology_pancreas = pd.read_csv("serena_tsp1_tsp2_count_per_cell_type.csv",index_col=0)
pathology_pancreas = pathology_pancreas.iloc[-4:]
pathology_pancreas
# Out:
#                                      endothelial_cell_count  \
# image_id
# PN 20x 1_pilot1_pancreas_labels.png                      10
# PN 20x 3_pilot1_pancreas_labels.png                      46
# PN 40x 5_pilot1_pancreas_labels.png                      58
# PN 40x 6_pilot1_pancreas_labels.png                      29
#
#                                      epithelial_cell_count  immune_cell_count  \
# image_id
# PN 20x 1_pilot1_pancreas_labels.png                   2378                 15
# PN 20x 3_pilot1_pancreas_labels.png                   1830                  8
# PN 40x 5_pilot1_pancreas_labels.png                     93                 19
# PN 40x 6_pilot1_pancreas_labels.png                     61                  0
#
#                                      stromal_cell_count  \
# image_id
# PN 20x 1_pilot1_pancreas_labels.png                 325
# PN 20x 3_pilot1_pancreas_labels.png                  91
# PN 40x 5_pilot1_pancreas_labels.png                 116
# PN 40x 6_pilot1_pancreas_labels.png                 306
#
#                                      endothelial_pixel_count  \
# image_id
# PN 20x 1_pilot1_pancreas_labels.png                      222
# PN 20x 3_pilot1_pancreas_labels.png                     1117
# PN 40x 5_pilot1_pancreas_labels.png                     5085
# PN 40x 6_pilot1_pancreas_labels.png                     2280
#
#                                      epithelial_pixel_count  \
# image_id
# PN 20x 1_pilot1_pancreas_labels.png                  117701
# PN 20x 3_pilot1_pancreas_labels.png                   83315
# PN 40x 5_pilot1_pancreas_labels.png                   11865
# PN 40x 6_pilot1_pancreas_labels.png                    7373
#
#                                      immune_pixel_count  stromal_pixel_count
# image_id
# PN 20x 1_pilot1_pancreas_labels.png                 809                14203
# PN 20x 3_pilot1_pancreas_labels.png                 253                 2473
# PN 40x 5_pilot1_pancreas_labels.png                1600                10279
# PN 40x 6_pilot1_pancreas_labels.png                   0                35055

# %%
pathology_pancreas = pathology_pancreas[["epithelial_cell_count","endothelial_cell_count","stromal_cell_count","immune_cell_count"]]
pathology_pancreas.columns = ['Epithelilal', 'Endothelial', 'Stromal', 'Immune']
pathology_pancreas['Neuroglia'] = 0
pathology_pancreas['Spatial Heterogeneity (AKA Error)'] = 0
pathology_pancreas.loc["Pancreas"] = pathology_pancreas.sum(axis=0)
pathology_pancreas
# Out:
# <ipython-input-56-9f8f5e41b4dc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pathology_pancreas['Neuroglia'] = 0
# <ipython-input-56-9f8f5e41b4dc>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pathology_pancreas['Spatial Heterogeneity (AKA Error)'] = 0
# /data/angela/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                                      Epithelilal  Endothelial  Stromal  \
# image_id
# PN 20x 1_pilot1_pancreas_labels.png         2378           10      325
# PN 20x 3_pilot1_pancreas_labels.png         1830           46       91
# PN 40x 5_pilot1_pancreas_labels.png           93           58      116
# PN 40x 6_pilot1_pancreas_labels.png           61           29      306
# Pancreas                                    4362          143      838
#
#                                      Immune  Neuroglia  \
# image_id
# PN 20x 1_pilot1_pancreas_labels.png      15          0
# PN 20x 3_pilot1_pancreas_labels.png       8          0
# PN 40x 5_pilot1_pancreas_labels.png      19          0
# PN 40x 6_pilot1_pancreas_labels.png       0          0
# Pancreas                                 42          0
#
#                                      Spatial Heterogeneity (AKA Error)
# image_id
# PN 20x 1_pilot1_pancreas_labels.png                                  0
# PN 20x 3_pilot1_pancreas_labels.png                                  0
# PN 40x 5_pilot1_pancreas_labels.png                                  0
# PN 40x 6_pilot1_pancreas_labels.png                                  0
# Pancreas                                                             0

# %%
pathology.loc["Pancreas"] = pathology_pancreas.loc["Pancreas"]

# %%
pathology = pathology.rename(
    {'Epithelilal':'epithelial','Neuroglia':'PNS',"Endothelial": "endothelial","Stromal":"stromal","Immune":"immune"},
    axis=1
)
pathology
# Out:
#                   epithelial  endothelial  stromal  immune  PNS  \
# Lymph Node                 0           15        7      78    0
# Spleen                     0           27       16      57    0
# Muscle                     0           32       65       3    0
# Diaphragm                  0           48       48       4    0
# Aorta                      0           13       81       6    0
# Duodenum                  35            5       24      35    1
# Ileum                     15            2       22      60    1
# Colon (Proximal)          40            5       29      25    1
# Colon (Distal)            35            5       34      25    1
# Bladder                   40           10       30      20    0
# Trachea                   40           10       40      10    0
# Lung (Proximal)           34           14       29      23    0
# Lung (Distal)             24           24       22      30    0
#
#                   Spatial Heterogeneity (AKA Error)
# Lymph Node                                        1
# Spleen                                            1
# Muscle                                            1
# Diaphragm                                         1
# Aorta                                             1
# Duodenum                                          2
# Ileum                                             2
# Colon (Proximal)                                  2
# Colon (Distal)                                    2
# Bladder                                           2
# Trachea                                           3
# Lung (Proximal)                                   3
# Lung (Distal)                                     3

# %%
f = plt.figure(figsize=(10,8))
pathology.drop('Spatial Heterogeneity (AKA Error)',axis=1).plot(
#     order = pathology["Spatial Heterogeneity (AKA Error)"],
    kind='bar',stacked=True, 
    ax=f.gca(),color=compartments_color_dict, 
    legend=True
)

plt.savefig("figures/compartment_proportions_pathology_tsp1_2.pdf")

# %% [markdown]
# ### TSP14

# %%
pathology_2 = pd.read_excel("TabulaSapiensTissueAbundanceRatiosRevised.xlsx","TSP14_AOP",index_col=0)
pathology_2
# Out:
#                           Slides  Epithelilal  Endothelial  Stromal  Immune  \
# Tissue Type/Location
# Diaphragm                 DI-A,B            0           38       57       5
# Subcutaneous Fat      FT-A,B,C,D            0            5       94       1
# Mesenteric Fat          FT-E,F,G            0           10       80      10
# Heart                       HT-A            0           30       60      10
# Duodenum                    IN-A           50            5        9      35
# Ileum                       IN-B           20            5       43      30
# Ascending Colon             IN-C           30            5       39      25
# Sigmoid Colon               IN-D           30           10       33      25
# Lung (all distal)       LU-A,B,C           27           25       21      27
# Liver                       LV-A           75            5        5      15
# Abdominal Muscle          MU-A,B            0           57       38       5
# Pancreas                  PA-A,B           65            5       20      10
# Parotid                     SG-A           55           10       32       2
# Parotid                     SG-B           45           15       33       2
# Parotid                     SG-C           45           15       35       2
# Sublingual                  SG-D           60           10       25       4
# Spleen                    SP-A,B            0           25       10      65
# Trachea                     TC-A           40           10       40      10
# Anterior Tongue             TG-A           15           10       62       8
# Popsterior Tongue           TG-B           20           10       52      15
# Thymus                    TY-A,B            0           10       60      30
# Bladder                   UB-A,B           50            5       34      10
#
#                       Neuroglia  Spatial Heterogeneity (AKA Error)
# Tissue Type/Location
# Diaphragm                     0                                  1
# Subcutaneous Fat              0                                  1
# Mesenteric Fat                0                                  1
# Heart                         0                                  1
# Duodenum                      1                                  2
# Ileum                         2                                  2
# Ascending Colon               1                                  2
# Sigmoid Colon                 2                                  2
# Lung (all distal)             0                                  3
# Liver                         0                                  2
# Abdominal Muscle              0                                  1
# Pancreas                      0                                  2
# Parotid                       1                                  3
# Parotid                       5                                  3
# Parotid                       3                                  3
# Sublingual                    1                                  3
# Spleen                        0                                  1
# Trachea                       0                                  3
# Anterior Tongue               5                                  2
# Popsterior Tongue             3                                  2
# Thymus                        0                                  1
# Bladder                       1                                  2

# %%
# pathology_2["tissue"] = ["Muscle","Tongue","Large Intestine","Bladder",
#                          "Muscle","Small Intestine","Heart", "Small Intestine",
#                          "Liver","Lung","Fat","Pancreas",
#                          "Salivary Gland","Tongue","Colon","Spleen",
#                          "Fat","Salivary Gland","Thymus","Trachea"]

# %%
pathology_2 = pathology_2.drop("Slides",axis=1)
pathology_2
# Out:
#                       Epithelilal  Endothelial  Stromal  Immune  Neuroglia  \
# Tissue Type/Location
# Diaphragm                       0           38       57       5          0
# Subcutaneous Fat                0            5       94       1          0
# Mesenteric Fat                  0           10       80      10          0
# Heart                           0           30       60      10          0
# Duodenum                       50            5        9      35          1
# Ileum                          20            5       43      30          2
# Ascending Colon                30            5       39      25          1
# Sigmoid Colon                  30           10       33      25          2
# Lung (all distal)              27           25       21      27          0
# Liver                          75            5        5      15          0
# Abdominal Muscle                0           57       38       5          0
# Pancreas                       65            5       20      10          0
# Parotid                        55           10       32       2          1
# Parotid                        45           15       33       2          5
# Parotid                        45           15       35       2          3
# Sublingual                     60           10       25       4          1
# Spleen                          0           25       10      65          0
# Trachea                        40           10       40      10          0
# Anterior Tongue                15           10       62       8          5
# Popsterior Tongue              20           10       52      15          3
# Thymus                          0           10       60      30          0
# Bladder                        50            5       34      10          1
#
#                       Spatial Heterogeneity (AKA Error)
# Tissue Type/Location
# Diaphragm                                             1
# Subcutaneous Fat                                      1
# Mesenteric Fat                                        1
# Heart                                                 1
# Duodenum                                              2
# Ileum                                                 2
# Ascending Colon                                       2
# Sigmoid Colon                                         2
# Lung (all distal)                                     3
# Liver                                                 2
# Abdominal Muscle                                      1
# Pancreas                                              2
# Parotid                                               3
# Parotid                                               3
# Parotid                                               3
# Sublingual                                            3
# Spleen                                                1
# Trachea                                               3
# Anterior Tongue                                       2
# Popsterior Tongue                                     2
# Thymus                                                1
# Bladder                                               2

# %%
# pathology_2 = pathology[["endothelial_cell_count","epithelial_cell_count","immune_cell_count","stromal_cell_count"]]

# %%
pathology_2.columns = ["epithelial","endothelial","stromal","immune","PNS","Spatial Heterogeneity (AKA Error)"]

# %%
pathology_2 = pathology_2.sort_values(by="Spatial Heterogeneity (AKA Error)")
pathology_2
# Out:
#                       epithelial  endothelial  stromal  immune  PNS  \
# Tissue Type/Location
# Diaphragm                      0           38       57       5    0
# Spleen                         0           25       10      65    0
# Thymus                         0           10       60      30    0
# Abdominal Muscle               0           57       38       5    0
# Subcutaneous Fat               0            5       94       1    0
# Heart                          0           30       60      10    0
# Mesenteric Fat                 0           10       80      10    0
# Duodenum                      50            5        9      35    1
# Popsterior Tongue             20           10       52      15    3
# Anterior Tongue               15           10       62       8    5
# Pancreas                      65            5       20      10    0
# Bladder                       50            5       34      10    1
# Sigmoid Colon                 30           10       33      25    2
# Ascending Colon               30            5       39      25    1
# Ileum                         20            5       43      30    2
# Liver                         75            5        5      15    0
# Lung (all distal)             27           25       21      27    0
# Parotid                       45           15       33       2    5
# Parotid                       45           15       35       2    3
# Sublingual                    60           10       25       4    1
# Trachea                       40           10       40      10    0
# Parotid                       55           10       32       2    1
#
#                       Spatial Heterogeneity (AKA Error)
# Tissue Type/Location
# Diaphragm                                             1
# Spleen                                                1
# Thymus                                                1
# Abdominal Muscle                                      1
# Subcutaneous Fat                                      1
# Heart                                                 1
# Mesenteric Fat                                        1
# Duodenum                                              2
# Popsterior Tongue                                     2
# Anterior Tongue                                       2
# Pancreas                                              2
# Bladder                                               2
# Sigmoid Colon                                         2
# Ascending Colon                                       2
# Ileum                                                 2
# Liver                                                 2
# Lung (all distal)                                     3
# Parotid                                               3
# Parotid                                               3
# Sublingual                                            3
# Trachea                                               3
# Parotid                                               3

# %%
f = plt.figure(figsize=(10,8))
pathology_2.drop('Spatial Heterogeneity (AKA Error)',axis=1).plot(
    kind='bar',stacked=True, ax=f.gca(),color=compartments_color_dict, legend=False
)

plt.savefig("figures/compartment_proportions_pathology_tsp14.pdf")

# %% [markdown]
# ## Compare

# %% [markdown]
# ### updated Table Revision

# %%
pathology_seq = pd.read_csv("TSsequencing_pathology-nobalance.csv").drop("index",axis=1)
pathology_seq = pd.read_csv("TSsequencing_pathology-nobalance_xy.csv").dropna()
pathology_seq.head()
# Out:
#              tissue donor  compartment  sequencing  pathology
# 13  Large_Intestine  TSP2  endothelial    1.222902        5.0
# 15  Large_Intestine  TSP2   epithelial   89.772096       37.5
# 17  Large_Intestine  TSP2       immune    3.835464       25.0
# 19  Large_Intestine  TSP2      stromal    5.169539       31.5
# 21             Lung  TSP1  endothelial    2.893916       19.0

# %%
pathology_seq.shape
# Out:
# (23, 5)

# %%
pathology_seq = pd.pivot_table(pathology_seq, 
               columns="source", 
               index=["tissue","donor","compartment"]
              ).reset_index().fillna(0)
pathology_seq.columns = ["tissue","donor","compartment","pathology","sequencing"]
pathology_seq.head()
# Out:
#             tissue donor  compartment  pathology  sequencing
# 0  Large_Intestine  TSP2  endothelial        5.0    1.222902
# 1  Large_Intestine  TSP2   epithelial       37.5   89.772096
# 2  Large_Intestine  TSP2       immune       25.0    3.835464
# 3  Large_Intestine  TSP2      stromal       31.5    5.169539
# 4             Lung  TSP1  endothelial        0.0    2.893916

# %%
pathology_seq.shape
# Out:
# (23, 5)

# %%
f = plt.figure(figsize=(16,8))
g = sns.scatterplot(data = pathology_seq,
               x = "pathology",
               y = "sequencing",
                hue='tissue',
                style='compartment',s=300,alpha=.9,
                palette=tissues_color_dict,
                   )
g.legend(loc='center right', bbox_to_anchor=(1.15, 0.5), ncol=1)
g.set(ylim=(-5,105),xlim=(-1,101))

# x0, x1 = g.get_xlim()
# y0, y1 = g.get_ylim()
# lims = [max(x0, y0), min(x1, y1)]
# g.plot(lims, lims, ':k')
plt.ylabel("Sequencing")
plt.xlabel("Pathology")
plt.title("Relative compartment abundances (%)")
# g.set_yscale("log")
# g.set_xscale("log")

plt.tight_layout()
plt.savefig("sequencing_pathology_comparison.pdf")


# sns.scatterplot(data = pathology_seq,
#                x = "pathology",
#                y = "sequencing",
#                 hue = "tissue",
#                palette=tissues_color_dict,
#                 style='compartment',s=300,alpha=.9,
#                )

# %% [markdown]
# ### use SRQ table

# %%
pathology_seq = pd.read_csv("TSsequencing_pathology_SRQ.csv")
pathology_seq
# Out:
#    Pathology  Pathology_err  Sequencing  Sequencing_err
# 0  10.029248       3.359035   14.955303        9.054520
# 1  29.600000       2.862291   26.024720       16.757316
# 2  51.125000       2.310085   50.356232       23.559921
# 3  71.400557       4.382162   77.018400        9.304556

# %%
fig,ax = plt.subplots(figsize=(10,8))
# ax = fig.add_subplot( aspect=1)
ax.errorbar(
        pathology_seq["Pathology"], pathology_seq["Sequencing"],  
        yerr=pathology_seq["Sequencing_err"],
        xerr=pathology_seq["Pathology_err"],
    fmt='o', markersize=8, capsize=10, color = "grey"
)


ax.set_xlabel("Cell Type Representation, Pathology")
ax.set_ylabel("Cell Type Representation, Sequencing")

plt.savefig("figures/bin_proportions_pathology_sequencing.pdf")

# %% [markdown]
# ### combine

# %%
df_long = df.copy()
df_long = df_long.reset_index()
df_long = df_long.groupby(['tissue','donor']).sum().reset_index()
df_long = df_long.melt(
    id_vars=['tissue','donor'], 
    value_vars=list(df_long.columns[2:]), # list of days of the week
    var_name='compartment', 
    value_name='count'
)
df_long['source'] = 'sequencing'
df_long
# Out:
#           tissue  donor  compartment      count      source
# 0        Bladder   TSP1  endothelial   1.760116  sequencing
# 1        Bladder   TSP2  endothelial   1.328477  sequencing
# 2          Blood   TSP1  endothelial   0.000000  sequencing
# 3          Blood  TSP10  endothelial   0.000000  sequencing
# 4          Blood  TSP14  endothelial   0.000000  sequencing
# ..           ...    ...          ...        ...         ...
# 265      Trachea   TSP2      stromal   5.810968  sequencing
# 266      Trachea   TSP6      stromal  25.572118  sequencing
# 267       Uterus   TSP4      stromal  51.798772  sequencing
# 268  Vasculature  TSP14      stromal  64.810638  sequencing
# 269  Vasculature   TSP2      stromal  56.544033  sequencing
#
# [270 rows x 5 columns]

# %%
df_long[df_long['tissue']=='Bladder']
# Out:
#       tissue donor  compartment      count      source
# 0    Bladder  TSP1  endothelial   1.760116  sequencing
# 1    Bladder  TSP2  endothelial   1.328477  sequencing
# 54   Bladder  TSP1   epithelial  16.185810  sequencing
# 55   Bladder  TSP2   epithelial   9.235055  sequencing
# 108  Bladder  TSP1    germ line   0.000000  sequencing
# 109  Bladder  TSP2    germ line   0.000000  sequencing
# 162  Bladder  TSP1       immune  40.074397  sequencing
# 163  Bladder  TSP2       immune  59.031498  sequencing
# 216  Bladder  TSP1      stromal  41.979677  sequencing
# 217  Bladder  TSP2      stromal  30.404971  sequencing

# %%
pathology
# Out:
#                   epithelial  endothelial  stromal  immune  PNS  \
# Lymph Node                 0           15        7      78    0
# Spleen                     0           27       16      57    0
# Muscle                     0           32       65       3    0
# Diaphragm                  0           48       48       4    0
# Aorta                      0           13       81       6    0
# Duodenum                  35            5       24      35    1
# Ileum                     15            2       22      60    1
# Colon (Proximal)          40            5       29      25    1
# Colon (Distal)            35            5       34      25    1
# Bladder                   40           30       10      20    0
# Trachea                   40           10       40      10    0
# Lung (Proximal)           34           14       29      23    0
# Lung (Distal)             24           24       22      30    0
# Pancreas                4362          143      838      42    0
#
#                   Spatial Heterogeneity (AKA Error)
# Lymph Node                                        1
# Spleen                                            1
# Muscle                                            1
# Diaphragm                                         1
# Aorta                                             1
# Duodenum                                          2
# Ileum                                             2
# Colon (Proximal)                                  2
# Colon (Distal)                                    2
# Bladder                                           2
# Trachea                                           2
# Lung (Proximal)                                   3
# Lung (Distal)                                     3
# Pancreas                                          0

# %%
p2 = pathology.drop('Spatial Heterogeneity (AKA Error)',axis=1).reset_index()
# p2 = pathology.copy()
# 
p2['index'] = [p.split(' (')[0] for p in p2['index']]
p2 = p2.replace(
    {
        'Colon':'Large_Intestine',
        'Duodenum':'Small_Intestine','Ileum':'Small_Intestine',
        'Aorta' : 'Vasculature'
    }
)
p2 = p2.groupby('index').sum().reset_index()
p2['sum'] = p2.sum(axis=1)
p2.iloc[:,1:] = p2.iloc[:,1:].div(p2['sum'],axis=0)*100
p2 = p2.drop('sum',axis=1)
p2 = p2.melt(
    id_vars='index', 
    value_vars=list(p2.columns[1:]), # list of days of the week
    var_name='compartment', 
    value_name='count'
)
p2 = p2.rename({'index':'tissue'},axis=1)
p2['source'] = 'pathology'
p2['donor'] = 'tsp1+2'
p2
# Out:
#              tissue  compartment      count     source   donor
# 0           Bladder   epithelial  40.000000  pathology  tsp1+2
# 1         Diaphragm   epithelial   0.000000  pathology  tsp1+2
# 2   Large_Intestine   epithelial  37.500000  pathology  tsp1+2
# 3              Lung   epithelial  29.000000  pathology  tsp1+2
# 4        Lymph Node   epithelial   0.000000  pathology  tsp1+2
# 5            Muscle   epithelial   0.000000  pathology  tsp1+2
# 6          Pancreas   epithelial  81.002786  pathology  tsp1+2
# 7   Small_Intestine   epithelial  25.000000  pathology  tsp1+2
# 8            Spleen   epithelial   0.000000  pathology  tsp1+2
# 9           Trachea   epithelial  40.000000  pathology  tsp1+2
# 10      Vasculature   epithelial   0.000000  pathology  tsp1+2
# 11          Bladder  endothelial  30.000000  pathology  tsp1+2
# 12        Diaphragm  endothelial  48.000000  pathology  tsp1+2
# 13  Large_Intestine  endothelial   5.000000  pathology  tsp1+2
# 14             Lung  endothelial  19.000000  pathology  tsp1+2
# 15       Lymph Node  endothelial  15.000000  pathology  tsp1+2
# 16           Muscle  endothelial  32.000000  pathology  tsp1+2
# 17         Pancreas  endothelial   2.655525  pathology  tsp1+2
# 18  Small_Intestine  endothelial   3.500000  pathology  tsp1+2
# 19           Spleen  endothelial  27.000000  pathology  tsp1+2
# 20          Trachea  endothelial  10.000000  pathology  tsp1+2
# 21      Vasculature  endothelial  13.000000  pathology  tsp1+2
# 22          Bladder      stromal  10.000000  pathology  tsp1+2
# 23        Diaphragm      stromal  48.000000  pathology  tsp1+2
# 24  Large_Intestine      stromal  31.500000  pathology  tsp1+2
# 25             Lung      stromal  25.500000  pathology  tsp1+2
# 26       Lymph Node      stromal   7.000000  pathology  tsp1+2
# 27           Muscle      stromal  65.000000  pathology  tsp1+2
# 28         Pancreas      stromal  15.561746  pathology  tsp1+2
# 29  Small_Intestine      stromal  23.000000  pathology  tsp1+2
# 30           Spleen      stromal  16.000000  pathology  tsp1+2
# 31          Trachea      stromal  40.000000  pathology  tsp1+2
# 32      Vasculature      stromal  81.000000  pathology  tsp1+2
# 33          Bladder       immune  20.000000  pathology  tsp1+2
# 34        Diaphragm       immune   4.000000  pathology  tsp1+2
# 35  Large_Intestine       immune  25.000000  pathology  tsp1+2
# 36             Lung       immune  26.500000  pathology  tsp1+2
# 37       Lymph Node       immune  78.000000  pathology  tsp1+2
# 38           Muscle       immune   3.000000  pathology  tsp1+2
# 39         Pancreas       immune   0.779944  pathology  tsp1+2
# 40  Small_Intestine       immune  47.500000  pathology  tsp1+2
# 41           Spleen       immune  57.000000  pathology  tsp1+2
# 42          Trachea       immune  10.000000  pathology  tsp1+2
# 43      Vasculature       immune   6.000000  pathology  tsp1+2
# 44          Bladder          PNS   0.000000  pathology  tsp1+2
# 45        Diaphragm          PNS   0.000000  pathology  tsp1+2
# 46  Large_Intestine          PNS   1.000000  pathology  tsp1+2
# 47             Lung          PNS   0.000000  pathology  tsp1+2
# 48       Lymph Node          PNS   0.000000  pathology  tsp1+2
# 49           Muscle          PNS   0.000000  pathology  tsp1+2
# 50         Pancreas          PNS   0.000000  pathology  tsp1+2
# 51  Small_Intestine          PNS   1.000000  pathology  tsp1+2
# 52           Spleen          PNS   0.000000  pathology  tsp1+2
# 53          Trachea          PNS   0.000000  pathology  tsp1+2
# 54      Vasculature          PNS   0.000000  pathology  tsp1+2

# %%
# ptsp14 = pathology.drop('Spatial Heterogeneity (AKA Error)',axis=1).reset_index()
ptsp14 = pathology_2.copy()
# 
# ptsp14['index'] = [p.split(' (')[0] for p in ptsp14['index']]
# ptsp14 = ptsp14.replace(
#     {
#         'Colon':'Large_Intestine',
#         'Duodenum':'Small_Intestine','Ileum':'Small_Intestine',
#         'Aorta' : 'Vasculature'
#     }
# )
ptsp14 = ptsp14.groupby('tissue').sum().reset_index()
ptsp14['sum'] = ptsp14.sum(axis=1)
ptsp14.iloc[:,1:] = ptsp14.iloc[:,1:].div(ptsp14['sum'],axis=0)*100
ptsp14 = ptsp14.drop('sum',axis=1)
ptsp14 = ptsp14.melt(
    id_vars='tissue', 
    value_vars=list(ptsp14.columns[1:]), # list of days of the week
    var_name='compartment', 
    value_name='count'
)
# ptsp14 = ptsp14.rename({'index':'tissue'},axis=1)
ptsp14['source'] = 'pathology'
ptsp14['donor'] = 'tsp14'
ptsp14
# Out:
#              tissue compartment  count     source  donor
# 0           Bladder  epithelial   50.0  pathology  tsp14
# 1             Colon  epithelial   30.0  pathology  tsp14
# 2               Fat  epithelial    0.0  pathology  tsp14
# 3             Heart  epithelial    0.0  pathology  tsp14
# 4   Large Intestine  epithelial   30.0  pathology  tsp14
# ..              ...         ...    ...        ...    ...
# 70  Small Intestine         PNS    1.5  pathology  tsp14
# 71           Spleen         PNS    0.0  pathology  tsp14
# 72           Thymus         PNS    0.0  pathology  tsp14
# 73           Tongue         PNS    4.0  pathology  tsp14
# 74          Trachea         PNS    0.0  pathology  tsp14
#
# [75 rows x 5 columns]

# %%
set(p2['tissue'])&set(df_long['tissue'])
# Out:
# {'Bladder',
#  'Large_Intestine',
#  'Lung',
#  'Muscle',
#  'Pancreas',
#  'Small_Intestine',
#  'Spleen',
#  'Trachea',
#  'Vasculature'}

# %%
set(ptsp14['tissue'])&set(df_long['tissue'])
# Out:
# {'Bladder',
#  'Fat',
#  'Heart',
#  'Liver',
#  'Lung',
#  'Muscle',
#  'Pancreas',
#  'Spleen',
#  'Thymus',
#  'Tongue',
#  'Trachea'}

# %%
seq_pat = pd.concat([df_long,p2,ptsp14],axis=0)
seq_pat['sample'] = seq_pat['tissue'] + "_" + seq_pat['source']
seq_pat = seq_pat[seq_pat['tissue'].isin(set(p2['tissue'])&set(df_long['tissue']))]
seq_pat
# Out:
#              tissue  donor  compartment     count      source  \
# 0           Bladder   TSP1  endothelial  1.760116  sequencing
# 1           Bladder   TSP2  endothelial  1.328477  sequencing
# 18  Large_Intestine  TSP14  endothelial  0.271003  sequencing
# 19  Large_Intestine   TSP2  endothelial  1.222902  sequencing
# 22             Lung   TSP1  endothelial  2.893916  sequencing
# ..              ...    ...          ...       ...         ...
# 66             Lung  tsp14          PNS  0.000000   pathology
# 67           Muscle  tsp14          PNS  0.000000   pathology
# 68         Pancreas  tsp14          PNS  0.000000   pathology
# 71           Spleen  tsp14          PNS  0.000000   pathology
# 74          Trachea  tsp14          PNS  0.000000   pathology
#
#                         sample
# 0           Bladder_sequencing
# 1           Bladder_sequencing
# 18  Large_Intestine_sequencing
# 19  Large_Intestine_sequencing
# 22             Lung_sequencing
# ..                         ...
# 66              Lung_pathology
# 67            Muscle_pathology
# 68          Pancreas_pathology
# 71            Spleen_pathology
# 74           Trachea_pathology
#
# [180 rows x 6 columns]

# %%
seq_pat.to_csv("sequencing_pathology.csv")

# %%
seq_pat[seq_pat['tissue']=='Spleen']
# Out:
#      tissue   donor  compartment      count      source             sample
# 42   Spleen   TSP14  endothelial   0.674963  sequencing  Spleen_sequencing
# 43   Spleen    TSP2  endothelial   2.329053  sequencing  Spleen_sequencing
# 44   Spleen    TSP7  endothelial   4.633516  sequencing  Spleen_sequencing
# 96   Spleen   TSP14   epithelial   0.000000  sequencing  Spleen_sequencing
# 97   Spleen    TSP2   epithelial   0.000000  sequencing  Spleen_sequencing
# 98   Spleen    TSP7   epithelial   0.000000  sequencing  Spleen_sequencing
# 150  Spleen   TSP14    germ line   0.000000  sequencing  Spleen_sequencing
# 151  Spleen    TSP2    germ line   0.000000  sequencing  Spleen_sequencing
# 152  Spleen    TSP7    germ line   0.000000  sequencing  Spleen_sequencing
# 204  Spleen   TSP14       immune  99.325037  sequencing  Spleen_sequencing
# 205  Spleen    TSP2       immune  97.670947  sequencing  Spleen_sequencing
# 206  Spleen    TSP7       immune  95.366484  sequencing  Spleen_sequencing
# 258  Spleen   TSP14      stromal   0.000000  sequencing  Spleen_sequencing
# 259  Spleen    TSP2      stromal   0.000000  sequencing  Spleen_sequencing
# 260  Spleen    TSP7      stromal   0.000000  sequencing  Spleen_sequencing
# 8    Spleen  tsp1+2   epithelial   0.000000   pathology   Spleen_pathology
# 19   Spleen  tsp1+2  endothelial  27.000000   pathology   Spleen_pathology
# 30   Spleen  tsp1+2      stromal  16.000000   pathology   Spleen_pathology
# 41   Spleen  tsp1+2       immune  57.000000   pathology   Spleen_pathology
# 52   Spleen  tsp1+2          PNS   0.000000   pathology   Spleen_pathology
# 11   Spleen   tsp14   epithelial   0.000000   pathology   Spleen_pathology
# 26   Spleen   tsp14  endothelial  25.000000   pathology   Spleen_pathology
# 41   Spleen   tsp14      stromal  10.000000   pathology   Spleen_pathology
# 56   Spleen   tsp14       immune  65.000000   pathology   Spleen_pathology
# 71   Spleen   tsp14          PNS   0.000000   pathology   Spleen_pathology

# %%
seq_pat_pivot = pd.pivot_table(seq_pat, values='count', index=['tissue','compartment','donor'],
                    columns=['source']).reset_index()

# %%
# seq_pat_pivot["pathology"] = np.log(seq_pat_pivot["pathology"])
# seq_pat_pivot["sequencing"] = np.log(seq_pat_pivot["sequencing"])

# %%
seq_pat_2 = seq_pat.groupby(["tissue","compartment","source"]).mean().reset_index()
seq_pat_2 = pd.pivot_table(seq_pat_2, values='count', index=['tissue','compartment'],
                    columns=['source']).reset_index()
seq_pat_2 = seq_pat_2.fillna(0)
seq_pat_2["sum"] = seq_pat_2["pathology"] + seq_pat_2["sequencing"]
seq_pat_2 = seq_pat_2[seq_pat_2["sum"]>0]
seq_pat_2

seq_pat_3 = seq_pat.groupby(["tissue","compartment","source"]).sem().reset_index()
seq_pat_3 = seq_pat_3.fillna(0)
seq_pat_3 = pd.pivot_table(seq_pat_3, values='count', index=['tissue','compartment'],
                    columns=['source']).reset_index()
seq_pat_3 = seq_pat_3.fillna(0)
seq_pat_3["pathology_err"] = seq_pat_3["pathology"]
seq_pat_3 = seq_pat_3.drop("pathology",axis=1)
seq_pat_3["sequencing_err"] = seq_pat_3["sequencing"]
seq_pat_3 = seq_pat_3.drop("sequencing",axis=1)
seq_pat_3.index = seq_pat_3["tissue"]+"_"+seq_pat_3["compartment"]
seq_pat_3 = seq_pat_3.drop("tissue",axis=1)
seq_pat_3 = seq_pat_3.drop("compartment",axis=1)
seq_pat_3

seq_pat_2.index = seq_pat_2["tissue"]+"_"+seq_pat_2["compartment"]
seq_pat_2 = seq_pat_2.join(seq_pat_3)

seq_pat_2["color"] = [tissues_color_dict[t] for t in seq_pat_2["tissue"]]
seq_pat_2
# Out:
# source                                tissue  compartment  pathology  \
# Bladder_PNS                          Bladder          PNS   0.500000
# Bladder_endothelial                  Bladder  endothelial  17.500000
# Bladder_epithelial                   Bladder   epithelial  45.000000
# Bladder_immune                       Bladder       immune  15.000000
# Bladder_stromal                      Bladder      stromal  22.000000
# Large_Intestine_PNS          Large_Intestine          PNS   1.000000
# Large_Intestine_endothelial  Large_Intestine  endothelial   5.000000
# Large_Intestine_epithelial   Large_Intestine   epithelial  37.500000
# Large_Intestine_immune       Large_Intestine       immune  25.000000
# Large_Intestine_stromal      Large_Intestine      stromal  31.500000
# Lung_endothelial                        Lung  endothelial  22.000000
# Lung_epithelial                         Lung   epithelial  28.000000
# Lung_immune                             Lung       immune  26.750000
# Lung_stromal                            Lung      stromal  23.250000
# Muscle_endothelial                    Muscle  endothelial  42.315789
# Muscle_immune                         Muscle       immune   1.500000
# Muscle_stromal                        Muscle      stromal  56.184211
# Pancreas_endothelial                Pancreas  endothelial   3.827762
# Pancreas_epithelial                 Pancreas   epithelial  73.001393
# Pancreas_immune                     Pancreas       immune   5.389972
# Pancreas_stromal                    Pancreas      stromal  17.780873
# Small_Intestine_PNS          Small_Intestine          PNS   1.000000
# Small_Intestine_endothelial  Small_Intestine  endothelial   3.500000
# Small_Intestine_epithelial   Small_Intestine   epithelial  25.000000
# Small_Intestine_immune       Small_Intestine       immune  47.500000
# Small_Intestine_stromal      Small_Intestine      stromal  23.000000
# Spleen_endothelial                    Spleen  endothelial  26.000000
# Spleen_immune                         Spleen       immune  61.000000
# Spleen_stromal                        Spleen      stromal  13.000000
# Trachea_endothelial                  Trachea  endothelial  10.000000
# Trachea_epithelial                   Trachea   epithelial  40.000000
# Trachea_immune                       Trachea       immune  10.000000
# Trachea_stromal                      Trachea      stromal  40.000000
# Vasculature_endothelial          Vasculature  endothelial  13.000000
# Vasculature_epithelial           Vasculature   epithelial   0.000000
# Vasculature_immune               Vasculature       immune   6.000000
# Vasculature_stromal              Vasculature      stromal  81.000000
#
# source                       sequencing         sum  pathology_err  \
# Bladder_PNS                    0.000000    0.500000       0.500000
# Bladder_endothelial            1.544296   19.044296      12.500000
# Bladder_epithelial            12.710432   57.710432       5.000000
# Bladder_immune                49.552947   64.552947       5.000000
# Bladder_stromal               36.192324   58.192324      12.000000
# Large_Intestine_PNS            0.000000    1.000000       0.000000
# Large_Intestine_endothelial    0.746952    5.746952       0.000000
# Large_Intestine_epithelial    63.143763  100.643763       0.000000
# Large_Intestine_immune        29.800414   54.800414       0.000000
# Large_Intestine_stromal        6.308871   37.808871       0.000000
# Lung_endothelial               5.516362   27.516362       3.000000
# Lung_epithelial               49.522471   77.522471       1.000000
# Lung_immune                   43.165671   69.915671       0.250000
# Lung_stromal                   1.795496   25.045496       2.250000
# Muscle_endothelial            19.641827   61.957617      10.315789
# Muscle_immune                  7.248007    8.748007       1.500000
# Muscle_stromal                73.110166  129.294376       8.815789
# Pancreas_endothelial          15.889986   19.717748       1.172238
# Pancreas_epithelial           61.589566  134.590959       8.001393
# Pancreas_immune               19.217100   24.607072       4.610028
# Pancreas_stromal               3.303348   21.084221       2.219127
# Small_Intestine_PNS            0.000000    1.000000       0.000000
# Small_Intestine_endothelial    1.176491    4.676491       0.000000
# Small_Intestine_epithelial    51.258835   76.258835       0.000000
# Small_Intestine_immune        46.288633   93.788633       0.000000
# Small_Intestine_stromal        1.276041   24.276041       0.000000
# Spleen_endothelial             2.545844   28.545844       1.000000
# Spleen_immune                 97.454156  158.454156       4.000000
# Spleen_stromal                 0.000000   13.000000       3.000000
# Trachea_endothelial            2.400601   12.400601       0.000000
# Trachea_epithelial            55.033954   95.033954       0.000000
# Trachea_immune                26.873902   36.873902       0.000000
# Trachea_stromal               15.691543   55.691543       0.000000
# Vasculature_endothelial       15.472992   28.472992       0.000000
# Vasculature_epithelial         0.166645    0.166645       0.000000
# Vasculature_immune            23.683027   29.683027       0.000000
# Vasculature_stromal           60.677335  141.677335       0.000000
#
# source                       sequencing_err    color
# Bladder_PNS                        0.000000  #e7969c
# Bladder_endothelial                0.215820  #e7969c
# Bladder_epithelial                 3.475378  #e7969c
# Bladder_immune                     9.478551  #e7969c
# Bladder_stromal                    5.787353  #e7969c
# Large_Intestine_PNS                0.000000  #31a354
# Large_Intestine_endothelial        0.475949  #31a354
# Large_Intestine_epithelial        26.628333  #31a354
# Large_Intestine_immune            25.964950  #31a354
# Large_Intestine_stromal            1.139332  #31a354
# Lung_endothelial                   3.567790  #3182bd
# Lung_epithelial                   21.559494  #3182bd
# Lung_immune                       20.816685  #3182bd
# Lung_stromal                       0.419561  #3182bd
# Muscle_endothelial                 6.292882  #e7ba52
# Muscle_immune                      0.996985  #e7ba52
# Muscle_stromal                     5.569506  #e7ba52
# Pancreas_endothelial              11.845806  #fd8d3c
# Pancreas_epithelial               32.327172  #fd8d3c
# Pancreas_immune                   17.738765  #fd8d3c
# Pancreas_stromal                   2.742601  #fd8d3c
# Small_Intestine_PNS                0.000000  #6baed6
# Small_Intestine_endothelial        1.033060  #6baed6
# Small_Intestine_epithelial        32.775377  #6baed6
# Small_Intestine_immune            34.243017  #6baed6
# Small_Intestine_stromal            0.434580  #6baed6
# Spleen_endothelial                 1.147865  #393b79
# Spleen_immune                      1.147865  #393b79
# Spleen_stromal                     0.000000  #393b79
# Trachea_endothelial                1.630472  #969696
# Trachea_epithelial                37.964880  #969696
# Trachea_immune                    26.453832  #969696
# Trachea_stromal                    9.880575  #969696
# Vasculature_endothelial            0.858247  #843c39
# Vasculature_epithelial             0.166645  #843c39
# Vasculature_immune                 3.108410  #843c39
# Vasculature_stromal                4.133302  #843c39

# %%
fig, ax = plt.subplots(figsize=(20, 10))

ax.set(ylim=(-5,105),xlim=(-5,105))

# x0, x1 = ax.get_xlim()
# y0, y1 = ax.get_ylim()
# lims = [max(x0, y0), min(x1, y1)]
# ax.plot(lims, lims, ':k')


for i in seq_pat_2.index:
    ax.errorbar(
        seq_pat_2.loc[i,"sequencing"], seq_pat_2.loc[i,"pathology"],  
        yerr=seq_pat_2.loc[i,"pathology_err"],
        xerr=seq_pat_2.loc[i,"sequencing_err"],
        ecolor = seq_pat_2.loc[i,"color"],
        c = seq_pat_2.loc[i,"color"],
         fmt='o'
    #          marker='s', mfc='red',
    #          mec='green', ms=20, mew=4
    )


plt.xlabel("sequencing")
plt.ylabel("pathology")
# ax.set_xscale("log")
# ax.set_yscale("log")
# Out:
# Text(0, 0.5, 'pathology')

# %%
seq_pat_pivot = seq_pat_pivot.fillna(0)
seq_pat_pivot["sum"] = seq_pat_pivot["pathology"] + seq_pat_pivot["sequencing"]
seq_pat_pivot = seq_pat_pivot[seq_pat_pivot["sum"]>0]
seq_pat_pivot
# Out:
# source       tissue  compartment   donor  pathology  sequencing        sum
# 1           Bladder          PNS   tsp14        1.0    0.000000   1.000000
# 2           Bladder  endothelial    TSP1        0.0    1.760116   1.760116
# 3           Bladder  endothelial    TSP2        0.0    1.328477   1.328477
# 4           Bladder  endothelial  tsp1+2       30.0    0.000000  30.000000
# 5           Bladder  endothelial   tsp14        5.0    0.000000   5.000000
# ..              ...          ...     ...        ...         ...        ...
# 175     Vasculature       immune    TSP2        0.0   26.791437  26.791437
# 176     Vasculature       immune  tsp1+2        6.0    0.000000   6.000000
# 177     Vasculature      stromal   TSP14        0.0   64.810638  64.810638
# 178     Vasculature      stromal    TSP2        0.0   56.544033  56.544033
# 179     Vasculature      stromal  tsp1+2       81.0    0.000000  81.000000
#
# [131 rows x 6 columns]

# %%
f = plt.figure(figsize=(16,8))
g = sns.pointplot(data = seq_pat_pivot,
                x='sequencing',
                y = 'pathology',
                hue='tissue',
#                 style='compartment',s=300,alpha=.9,
                palette=tissues_color_dict,
                   )
# g.legend(loc='center right', bbox_to_anchor=(1.15, 0.5), ncol=1)
# g.set(ylim=(-5,105),xlim=(-5,105))

# x0, x1 = g.get_xlim()
# y0, y1 = g.get_ylim()
# lims = [max(x0, y0), min(x1, y1)]
# g.plot(lims, lims, ':k')
# plt.xlabel("Sequencing")
# plt.ylabel("Pathology")
# plt.title("Relative compartment abundances (%)")
# # g.set_yscale("log")
# # g.set_xscale("log")

# plt.tight_layout()
# # plt.savefig("figures/compartment_proportions.pdf")

# %%
f = plt.figure(figsize=(16,8))
g = sns.scatterplot(data = seq_pat_2,
                x='sequencing',
                y = 'pathology',
                hue='tissue',
                style='compartment',s=300,alpha=.9,
                palette=tissues_color_dict,
                   )
g.legend(loc='center right', bbox_to_anchor=(1.15, 0.5), ncol=1)
g.set(ylim=(-5,105),xlim=(-5,105))

x0, x1 = g.get_xlim()
y0, y1 = g.get_ylim()
lims = [max(x0, y0), min(x1, y1)]
g.plot(lims, lims, ':k')
plt.xlabel("Sequencing")
plt.ylabel("Pathology")
plt.title("Relative compartment abundances (%)")
# g.set_yscale("log")
# g.set_xscale("log")

plt.tight_layout()
# plt.savefig("figures/compartment_proportions.pdf")

# %%
f = plt.figure(figsize=(16,8))
g = sns.scatterplot(data = seq_pat_2,
                x='sequencing',
                y = 'pathology',
                hue='tissue',
                style='compartment',s=300,alpha=.9,
                palette=tissues_color_dict,
                   )
g.legend(loc='center right', bbox_to_anchor=(1.15, 0.5), ncol=1)
# g.set(ylim=(-5,105),xlim=(-5,105))

# x0, x1 = g.get_xlim()
# y0, y1 = g.get_ylim()
# lims = [max(x0, y0), min(x1, y1)]
# g.plot(lims, lims, ':k')
plt.xlabel("Sequencing")
plt.ylabel("Pathology")
plt.title("Relative compartment abundances (%)")
g.set_yscale("log")
g.set_xscale("log")

plt.tight_layout()
# plt.savefig("figures/compartment_proportions.pdf")

# %% [markdown]
# ## bining

# %% [markdown]
# Bining on abundance, split x axis into 4 blocks

# %%
seq_pat_2["bin"] = 0

for i in seq_pat_2.index:
    if seq_pat_2.loc[i,"sequencing"] < 25:
        seq_pat_2.loc[i,"bin"] = "low (<25%)"
    elif seq_pat_2.loc[i,"sequencing"] >= 25 and seq_pat_2.loc[i,"sequencing"] < 50:
        seq_pat_2.loc[i,"bin"] = "mid-low (25-50%)"
    elif seq_pat_2.loc[i,"sequencing"] >= 50 and seq_pat_2.loc[i,"sequencing"] < 75:
        seq_pat_2.loc[i,"bin"] = "mid-high (50-75%)"
    elif seq_pat_2.loc[i,"sequencing"] >= 75:
        seq_pat_2.loc[i,"bin"] = "high (>75%)"

seq_pat_2["bin_pat"] = 0

for i in seq_pat_2.index:
    if seq_pat_2.loc[i,"pathology"] < 25:
        seq_pat_2.loc[i,"bin_pat"] = 1
    elif seq_pat_2.loc[i,"pathology"] >= 25 and seq_pat_2.loc[i,"pathology"] < 50:
        seq_pat_2.loc[i,"bin_pat"] = 2
    elif seq_pat_2.loc[i,"pathology"] >= 50 and seq_pat_2.loc[i,"pathology"] < 75:
        seq_pat_2.loc[i,"bin_pat"] = 3
    elif seq_pat_2.loc[i,"pathology"] >= 75:
        seq_pat_2.loc[i,"bin_pat"] = 4
seq_pat_2
# Out:
# source                                tissue  compartment  pathology  \
# Bladder_PNS                          Bladder          PNS   0.500000
# Bladder_endothelial                  Bladder  endothelial  17.500000
# Bladder_epithelial                   Bladder   epithelial  45.000000
# Bladder_immune                       Bladder       immune  15.000000
# Bladder_stromal                      Bladder      stromal  22.000000
# Large_Intestine_PNS          Large_Intestine          PNS   1.000000
# Large_Intestine_endothelial  Large_Intestine  endothelial   5.000000
# Large_Intestine_epithelial   Large_Intestine   epithelial  37.500000
# Large_Intestine_immune       Large_Intestine       immune  25.000000
# Large_Intestine_stromal      Large_Intestine      stromal  31.500000
# Lung_endothelial                        Lung  endothelial  22.000000
# Lung_epithelial                         Lung   epithelial  28.000000
# Lung_immune                             Lung       immune  26.750000
# Lung_stromal                            Lung      stromal  23.250000
# Muscle_endothelial                    Muscle  endothelial  42.315789
# Muscle_immune                         Muscle       immune   1.500000
# Muscle_stromal                        Muscle      stromal  56.184211
# Pancreas_endothelial                Pancreas  endothelial   3.827762
# Pancreas_epithelial                 Pancreas   epithelial  73.001393
# Pancreas_immune                     Pancreas       immune   5.389972
# Pancreas_stromal                    Pancreas      stromal  17.780873
# Small_Intestine_PNS          Small_Intestine          PNS   1.000000
# Small_Intestine_endothelial  Small_Intestine  endothelial   3.500000
# Small_Intestine_epithelial   Small_Intestine   epithelial  25.000000
# Small_Intestine_immune       Small_Intestine       immune  47.500000
# Small_Intestine_stromal      Small_Intestine      stromal  23.000000
# Spleen_endothelial                    Spleen  endothelial  26.000000
# Spleen_immune                         Spleen       immune  61.000000
# Spleen_stromal                        Spleen      stromal  13.000000
# Trachea_endothelial                  Trachea  endothelial  10.000000
# Trachea_epithelial                   Trachea   epithelial  40.000000
# Trachea_immune                       Trachea       immune  10.000000
# Trachea_stromal                      Trachea      stromal  40.000000
# Vasculature_endothelial          Vasculature  endothelial  13.000000
# Vasculature_epithelial           Vasculature   epithelial   0.000000
# Vasculature_immune               Vasculature       immune   6.000000
# Vasculature_stromal              Vasculature      stromal  81.000000
#
# source                       sequencing         sum  pathology_err  \
# Bladder_PNS                    0.000000    0.500000       0.500000
# Bladder_endothelial            1.544296   19.044296      12.500000
# Bladder_epithelial            12.710432   57.710432       5.000000
# Bladder_immune                49.552947   64.552947       5.000000
# Bladder_stromal               36.192324   58.192324      12.000000
# Large_Intestine_PNS            0.000000    1.000000       0.000000
# Large_Intestine_endothelial    0.746952    5.746952       0.000000
# Large_Intestine_epithelial    63.143763  100.643763       0.000000
# Large_Intestine_immune        29.800414   54.800414       0.000000
# Large_Intestine_stromal        6.308871   37.808871       0.000000
# Lung_endothelial               5.516362   27.516362       3.000000
# Lung_epithelial               49.522471   77.522471       1.000000
# Lung_immune                   43.165671   69.915671       0.250000
# Lung_stromal                   1.795496   25.045496       2.250000
# Muscle_endothelial            19.641827   61.957617      10.315789
# Muscle_immune                  7.248007    8.748007       1.500000
# Muscle_stromal                73.110166  129.294376       8.815789
# Pancreas_endothelial          15.889986   19.717748       1.172238
# Pancreas_epithelial           61.589566  134.590959       8.001393
# Pancreas_immune               19.217100   24.607072       4.610028
# Pancreas_stromal               3.303348   21.084221       2.219127
# Small_Intestine_PNS            0.000000    1.000000       0.000000
# Small_Intestine_endothelial    1.176491    4.676491       0.000000
# Small_Intestine_epithelial    51.258835   76.258835       0.000000
# Small_Intestine_immune        46.288633   93.788633       0.000000
# Small_Intestine_stromal        1.276041   24.276041       0.000000
# Spleen_endothelial             2.545844   28.545844       1.000000
# Spleen_immune                 97.454156  158.454156       4.000000
# Spleen_stromal                 0.000000   13.000000       3.000000
# Trachea_endothelial            2.400601   12.400601       0.000000
# Trachea_epithelial            55.033954   95.033954       0.000000
# Trachea_immune                26.873902   36.873902       0.000000
# Trachea_stromal               15.691543   55.691543       0.000000
# Vasculature_endothelial       15.472992   28.472992       0.000000
# Vasculature_epithelial         0.166645    0.166645       0.000000
# Vasculature_immune            23.683027   29.683027       0.000000
# Vasculature_stromal           60.677335  141.677335       0.000000
#
# source                       sequencing_err    color                bin  \
# Bladder_PNS                        0.000000  #e7969c         low (<25%)
# Bladder_endothelial                0.215820  #e7969c         low (<25%)
# Bladder_epithelial                 3.475378  #e7969c         low (<25%)
# Bladder_immune                     9.478551  #e7969c   mid-low (25-50%)
# Bladder_stromal                    5.787353  #e7969c   mid-low (25-50%)
# Large_Intestine_PNS                0.000000  #31a354         low (<25%)
# Large_Intestine_endothelial        0.475949  #31a354         low (<25%)
# Large_Intestine_epithelial        26.628333  #31a354  mid-high (50-75%)
# Large_Intestine_immune            25.964950  #31a354   mid-low (25-50%)
# Large_Intestine_stromal            1.139332  #31a354         low (<25%)
# Lung_endothelial                   3.567790  #3182bd         low (<25%)
# Lung_epithelial                   21.559494  #3182bd   mid-low (25-50%)
# Lung_immune                       20.816685  #3182bd   mid-low (25-50%)
# Lung_stromal                       0.419561  #3182bd         low (<25%)
# Muscle_endothelial                 6.292882  #e7ba52         low (<25%)
# Muscle_immune                      0.996985  #e7ba52         low (<25%)
# Muscle_stromal                     5.569506  #e7ba52  mid-high (50-75%)
# Pancreas_endothelial              11.845806  #fd8d3c         low (<25%)
# Pancreas_epithelial               32.327172  #fd8d3c  mid-high (50-75%)
# Pancreas_immune                   17.738765  #fd8d3c         low (<25%)
# Pancreas_stromal                   2.742601  #fd8d3c         low (<25%)
# Small_Intestine_PNS                0.000000  #6baed6         low (<25%)
# Small_Intestine_endothelial        1.033060  #6baed6         low (<25%)
# Small_Intestine_epithelial        32.775377  #6baed6  mid-high (50-75%)
# Small_Intestine_immune            34.243017  #6baed6   mid-low (25-50%)
# Small_Intestine_stromal            0.434580  #6baed6         low (<25%)
# Spleen_endothelial                 1.147865  #393b79         low (<25%)
# Spleen_immune                      1.147865  #393b79        high (>75%)
# Spleen_stromal                     0.000000  #393b79         low (<25%)
# Trachea_endothelial                1.630472  #969696         low (<25%)
# Trachea_epithelial                37.964880  #969696  mid-high (50-75%)
# Trachea_immune                    26.453832  #969696   mid-low (25-50%)
# Trachea_stromal                    9.880575  #969696         low (<25%)
# Vasculature_endothelial            0.858247  #843c39         low (<25%)
# Vasculature_epithelial             0.166645  #843c39         low (<25%)
# Vasculature_immune                 3.108410  #843c39         low (<25%)
# Vasculature_stromal                4.133302  #843c39  mid-high (50-75%)
#
# source                       bin_pat
# Bladder_PNS                        1
# Bladder_endothelial                1
# Bladder_epithelial                 2
# Bladder_immune                     1
# Bladder_stromal                    1
# Large_Intestine_PNS                1
# Large_Intestine_endothelial        1
# Large_Intestine_epithelial         2
# Large_Intestine_immune             2
# Large_Intestine_stromal            2
# Lung_endothelial                   1
# Lung_epithelial                    2
# Lung_immune                        2
# Lung_stromal                       1
# Muscle_endothelial                 2
# Muscle_immune                      1
# Muscle_stromal                     3
# Pancreas_endothelial               1
# Pancreas_epithelial                3
# Pancreas_immune                    1
# Pancreas_stromal                   1
# Small_Intestine_PNS                1
# Small_Intestine_endothelial        1
# Small_Intestine_epithelial         2
# Small_Intestine_immune             2
# Small_Intestine_stromal            1
# Spleen_endothelial                 2
# Spleen_immune                      3
# Spleen_stromal                     1
# Trachea_endothelial                1
# Trachea_epithelial                 2
# Trachea_immune                     1
# Trachea_stromal                    2
# Vasculature_endothelial            1
# Vasculature_epithelial             1
# Vasculature_immune                 1
# Vasculature_stromal                4

# %%
f = plt.figure(figsize=(4,10))
g = sns.scatterplot(data = seq_pat_2,
                x='bin',#"sequencing"
                y = 'pathology',#"bin_pat",#
                hue='tissue',
                style='compartment',s=300,alpha=.9,
                palette=tissues_color_dict,
                   )
g.legend(loc='center right', bbox_to_anchor=(1.15, 0.5), ncol=1)
# g.set(ylim=(-5,105),xlim=(-5,105))

# x0, x1 = g.get_xlim()
# y0, y1 = g.get_ylim()
# lims = [max(x0, y0), min(x1, y1)]
# g.plot(lims, lims, ':k')
plt.xlabel("Sequencing")
plt.ylabel("Pathology")
plt.title("Relative compartment abundances (%)")
# g.set_yscale("log")
# g.set_xscale("log")

plt.tight_layout()
plt.savefig("figures/compartment_proportions.pdf")

# %%
def source_colors():
    methods = ['pathology', 'sequencing']
    
    import matplotlib.colors as pltcolors
    
    method_color_dict = {}
    method_color_dict['pathology'] = '#90ee90'
    method_color_dict['sequencing'] = '#006400'
    
    return method_color_dict
      
    return source_color_dict


source_color_dict = source_colors()

# %%
help(sns.set_style)

# %%
sns.set(font_scale=1) 
sns.set_style("white")
g = sns.FacetGrid(seq_pat, col="tissue", 
                  col_wrap=3, height=4, aspect=.5, 
                      
#     col_order=tissue_order,
                  
                 )#, ylim=(0, 10))
g.map_dataframe(sns.barplot, x = "compartment", y = "count",hue='source', palette=source_color_dict)#, ci=None);
g.set_axis_labels("Tissue", "Relative compartment abundancies")
g.add_legend()
g.set_xticklabels(rotation=90)

# for ( col_val), ax in g.axes_dict.items():
#         ax.set_facecolor((0, 0, 0, 0))
plt.tight_layout()

plt.savefig("figures/compartment_proportions.pdf")

# %%
seq_pat

# %%
g = sns.catplot(data = seq_pat,
           x = 'tissue',
           y = 'count',
           hue = 'compartment',
                 row = "source",
           kind = 'bar',
           palette=compartments_color_dict, height=3, size=8)
g.set_xticklabels(rotation=90)

# %%
g = sns.catplot(data = seq_pat,
           x = 'sample',
           y = 'count',
           hue = 'compartment',
           kind = 'bar',
           palette=compartments_color_dict, height=10)
g.set_xticklabels(rotation=90)

# %% [markdown]
# ## Check for anatomical position

# %%
# df = pd.DataFrame(metadata.groupby(['donor','tissue','compartment','cell_ontology_type'])['cell_id'].count())
df_long_anat = metadata[metadata['method']=='10X'].copy()
df_long_anat = pd.DataFrame(df_long_anat.groupby(['tissue','anatomical_position','compartment'])['cell_id'].count())
df_long_anat = df_long_anat.reset_index()
df_long_anat = pd.pivot_table(
    data = df_long_anat,values='cell_id', 
    index=['tissue','anatomical_position'],
    columns=['compartment']
)
df_long_anat = df_long_anat.replace({np.nan:0})
df_long_anat['sum'] = df_long_anat.sum(axis=1)
df_long_anat.iloc[:, :] = df_long_anat.iloc[:, :].div(df_long_anat['sum'],axis=0)*100
df_long_anat = df_long_anat.drop('sum',axis=1)
df_long_anat

# %%
df_long_anat = df_long_anat.reset_index()
df_long_anat = df_long_anat.replace({"nan":""})
df_long_anat['tissue_anat'] = df_long_anat['tissue'] + "_" + df_long_anat['anatomical_position']

df_long_anat_dic = {
'Bladder_':'Bladder',
 'Blood_':'Blood',
 'Bone_Marrow_vertebralbody':'Bone_Marrow',
 'Kidney_':'Kidney',
 'Large_Intestine_distal':'Colon (Distal)',
 'Large_Intestine_proximal':'Colon (Proximal)',
 'Lung_':'Lung',
 'Lung_proxmedialdistal':'Lung',
 'Lymph_Node_':'Lymph Node',
 'Muscle_':'Muscle',
 'Muscle_diaphragm':'Diaphragm',
 'Muscle_rectusabdominus':'Muscle',
 'Pancreas_Endocrine':'Pancreas',
 'Pancreas_Exocrine':'Pancreas',
 'Small_Intestine_distal':'Ileum',
 'Small_Intestine_proximal':'Duodenum',
 'Spleen_':'Spleen',
 'Thymus_':'Thymus',
 'Trachea_':'Trachea',
 'Vasculature_Aorta':'Aorta'
}

df_long_anat['tissue_anat'] = df_long_anat['tissue_anat'].map(df_long_anat_dic)

df_long_anat

# %%
p3 = pathology.copy()
p3 = p3.reset_index()
p3 = p3.replace({'Lung (Proximal)':'Lung','Lung (Distal)':'Lung'})

p3 = p3.groupby('index').sum().reset_index()
p3['sum'] = p3.sum(axis=1)
p3.iloc[:,1:] = p3.iloc[:,1:].div(p3['sum'],axis=0)*100
p3 = p3.drop('sum',axis=1)
# p3 = p3.melt(
#     id_varsa='index', 
#     value_vars=list(p3.columns[1:]), # list of days of the week
#     var_name='compartment', 
#     value_name='count'
# )
# p3 = p3.rename({'index':'tissue'},axis=1)
p3

# %% [markdown]
# # Updating

# %%
tiss_cell_fractions(adata[adata.obs['donor']=='TSP2'].copy(),
                        technology_col='method',
                        groupby='tissue',
                        category='cell_ontology_type',
                        dataset="Pilot2")

# %%
tiss_cell_fractions(adata[adata.obs['donor']=='TSP1'].copy(),
                        technology_col='method',
                        groupby='tissue',
                        category='cell_ontology_type',
                        dataset="Pilot1")

# %%
adata.obs.head()#.columns

# %%
tiss_cell_fractions(adata,
                    technology_col='donor',
                    breakby='tissue',
                    category='Propagated Annotation',
                    dataset="Tabula Sapiens",groupby='method')

# %%
adata.obs.groupby(['tissue', 'propagated_cell_ontology_class', 'manual_cell_ontology_class'])

# %%
technology_col='method'
breakby='tissue'
category='propagated_cell_ontology_class'
dataset="Tabula Sapiens"
groupby='donor'

for m in set(adata.obs[technology_col]):
    adata_subset = adata[adata.obs[technology_col] == m].copy()
    adata_subset = remove_cats(adata_subset)
    for t in list(set(adata_subset.obs[breakby]))[3:4]:
        print(t)
        tiss = adata_subset[adata_subset.obs[breakby] == t].copy()
        tiss = remove_cats(tiss)

        aux = tiss.obs.groupby([category,groupby])['cell_id'].count()
        aux = pd.DataFrame(aux).reset_index()
        aux['fraction'] = aux['cell_id']/aux['cell_id'].sum()
        aux['cell_number'] = aux['cell_id']

# %%
aux
