# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import scanpy as sc
import pandas as pd
import seaborn as sns
from sklearn.metrics.pairwise import nan_euclidean_distances
from sklearn.metrics import pairwise_distances, pairwise_distances_chunked
from tqdm import tqdm

sc.settings.verbosity = 4
#sc.set_figure_params(dpi=200, dpi_save=300)
sc.logging.print_versions()
sc.set_figure_params(frameon=False, color_map='magma_r')

# %% [markdown]
# ## Data folder

# %%
splicing_folder = '/home/olga/data_sm/splicing/rawdata/rijk_zscore__2020-09-15'
! ls -lha $splicing_folder
# Out:
# total 30G
# drwxr-xr-x 2 olga czb 4.0K Sep 15 11:53 .
# drwxr-xr-x 4 olga czb 4.0K Sep 15 11:53 ..
# -rw-r--r-- 1 olga czb 829M Sep 15 11:29 COVID_pilot2_sym_S_0.1_z_0.0_b_5.pq
# -rw-r--r-- 1 olga czb 3.5G Sep 15 11:30 COVID_pilot3_sym_S_0.1_z_0.0_b_5.pq
# -rw-r--r-- 1 olga czb 3.0G Sep 15 11:37 lemur_Antoine_4_sym_S_0.1_z_0.0_b_5.pq
# -rw-r--r-- 1 olga czb 316M Sep 15 11:37 lemur_Bernard_4_sym_S_0.1_z_0.0_b_5.pq
# -rw-r--r-- 1 olga czb 333M Sep 15 11:37 lemur_Martine_4_sym_S_0.1_z_0.0_b_5.pq
# -rw-r--r-- 1 olga czb 1.6G Sep 15 11:38 lemur_Stumpy_4_sym_S_0.1_z_0.0_b_5.pq
# -rw-r--r-- 1 olga czb 1.8G Sep 15 11:36 TS_10x_redo_sym_S_0.1_z_0.0_b_5.pq
# -rw-r--r-- 1 olga czb 3.1G Sep 15 11:31 TSP1_SS2_sym_S_0.1_z_0.0_b_5.pq
# -rw-r--r-- 1 olga czb 5.5G Sep 15 11:33 TSP2_10x_rerun_3prime_sym_S_0.1_z_0.0_b_5.pq
# -rw-r--r-- 1 olga czb  11G Sep 15 11:35 TSP2_SS2_sym_S_0.1_z_0.0_b_5.pq

# %% [markdown]
# # Read in data

# %%
parquet = f"{splicing_folder}/TS_10x_redo_sym_S_0.1_z_0.0_b_5.pq"
df = pd.read_parquet(parquet)
print(df.shape)
df.head()
# Out:
# (12150005, 93)
#    inc_emp.p    tissue  gene_count_per_cell_filt  juncPosR1A geneR1A_uniq  \
# 0       True  Pancreas                      13.0  86968605.0        ADIRF
# 1       True      None                      10.0  86968605.0        ADIRF
# 2       True  Pancreas                       9.0  86968605.0        ADIRF
# 3       True  Pancreas                       6.0  86968605.0        ADIRF
# 4       True  Pancreas                       7.0  86968605.0        ADIRF
#
#    juncPosR1B  numReads                                         cell  \
# 0  86970200.0       5.0  TSP1_exopancreas2_3_S6_L00_ACGTAGTCACTTGGCG
# 1  86970200.0       6.0  TSP1_exopancreas2_3_S6_L00_TTCGGTCGTATAATGG
# 2  86970200.0       5.0  TSP1_exopancreas2_3_S6_L00_CTGCTCAGTCCAGTTA
# 3  86970200.0       2.0  TSP1_exopancreas2_3_S6_L00_TCATGCCCATGACCCG
# 4  86970200.0       3.0  TSP1_exopancreas2_3_S6_L00_GGTGGCTGTGCCTACG
#
#                       channel  splice_ann  ...  cov_ann     z_ann cov_dom_ch  \
# 0  TSP1_exopancreas2_3_S6_L00        True  ... -0.02279 -0.267072  -0.024372
# 1  TSP1_exopancreas2_3_S6_L00        True  ... -0.02279 -0.264596  -0.024372
# 2  TSP1_exopancreas2_3_S6_L00        True  ... -0.02279 -0.247094  -0.024372
# 3  TSP1_exopancreas2_3_S6_L00        True  ... -0.02279 -0.186327  -0.024372
# 4  TSP1_exopancreas2_3_S6_L00        True  ... -0.02279 -0.208286  -0.024372
#
#    z_dom_ch cov_unann   z_unann cov_dom_unch  z_dom_unch  \
# 0 -0.215724 -0.000632  0.050399          NaN         NaN
# 1 -0.263014 -0.000632       NaN          NaN         NaN
# 2 -0.245513 -0.000632       NaN          NaN         NaN
# 3 -0.184745 -0.000632       NaN          NaN         NaN
# 4 -0.206705 -0.000632       NaN          NaN         NaN
#
#                                    ontology  \
# 0  PancreasEpithelialpancreatic acinar cell
# 1                                      None
# 2  PancreasEpithelialpancreatic acinar cell
# 3  PancreasEpithelialpancreatic ductal cell
# 4  PancreasEpithelialpancreatic acinar cell
#
#                                    ontology_gene
# 0  PancreasEpithelialpancreatic acinar cellADIRF
# 1                                           None
# 2  PancreasEpithelialpancreatic acinar cellADIRF
# 3  PancreasEpithelialpancreatic ductal cellADIRF
# 4  PancreasEpithelialpancreatic acinar cellADIRF
#
# [5 rows x 93 columns]

# %%
df.columns
# Out:
# Index(['inc_emp.p', 'tissue', 'gene_count_per_cell_filt', 'juncPosR1A',
#        'geneR1A_uniq', 'juncPosR1B', 'numReads', 'cell', 'channel',
#        'splice_ann', 'compartment', 'free_annotation', 'missing_domains',
#        'domain_insertions', 'refName_newR1', 'gene_frac_filt', 'geneR1B_uniq',
#        'sign', 'cell_gene', 'posA_group', 'posB_group', 'rank_acc', 'rank_don',
#        'max_rank_acc', 'max_rank_don', 'num_missing_A', 'num_inserted_A',
#        'domain_changed_A', 'num_missing_B', 'num_inserted_B',
#        'domain_changed_B', 'noncon_count', 'max_rank', 'sum_reads_group',
#        'read_x_acc', 'num', 'rank_mean', 'sq_diff', 'don_num', 'don_sigma',
#        'S_ijk_A', 'S_ijk_A_unpinned', 'n_sijk', 'n_s', 'n_gene', 'sijkA_mean',
#        'sd_num', 'sijkA_var', 'n_g', 'nSijkA', 'mult', 'z_A', 'cell_gene_junc',
#        'x_sijk', 'denom_sq', 'temp', 'temp_mag', 'idxmax_z', 'junc_max_A',
#        'max_don_z_A', 'num_ann', 'num_dom_ch', 'z_A_ann', 'z_A_dom_ch',
#        'num_unann', 'num_dom_unch', 'z_A_unann', 'z_A_dom_unch', 'read_x_don',
#        'S_ijk_B', 'S_ijk_B_unpinned', 'sijkB_mean', 'sijkB_var', 'nSijkB',
#        'z_B', 'junc_max_B', 'max_don_z_B', 'z_B_ann', 'z_B_dom_ch',
#        'z_B_unann', 'z_B_dom_unch', 'cov', 'z', 'cov_ann', 'z_ann',
#        'cov_dom_ch', 'z_dom_ch', 'cov_unann', 'z_unann', 'cov_dom_unch',
#        'z_dom_unch', 'ontology', 'ontology_gene'],
#       dtype='object')

# %% [markdown]
# # function for multiprocessing splicing

# %%
# %%file splicing_utils.py

import itertools
from functools import partial
import multiprocessing
import sys
import tempfile
import time

import numpy as np
import pandas as pd

_quiet = False
_debug = False
def set_quiet(val, print_debug=False):
    global _quiet, _debug
    _quiet = bool(val)
    _debug = bool(print_debug)



# Cribbed from https://github.com/dib-lab/sourmash/blob/c7ed8bef7de9b1581b9b067517f64ac64f31f9d0/sourmash/logging.py
def notify(s, *args, **kwargs):
    "A simple logging function => stderr."
    if _quiet:
        return

    print(u'\r\033[K', end=u'', file=sys.stderr)
    print(s.format(*args, **kwargs), file=sys.stderr,
          end=kwargs.get('end', u'\n'))
    if kwargs.get('flush'):
        sys.stderr.flush()



def process_splicing(filename, gene='geneR1A_uniq', cell='cell', tissue=None):
    splicing_df = pd.read_parquet(filename)
    
    # Drop duplicate cell ids and gene names
    splicing_df_no_dups = splicing_df.drop_duplicates([cell, gene])
    
    if tissue is not None:
        splicing_df_no_dups = splicing_df_no_dups.query('tissue == @tissue')
        
    
    # Don't use rows with empty gene names -- these are unannotated genes
    splicing_df_no_dups = splicing_df_no_dups.query(f'{gene} != ""')
    print(splicing_df_no_dups.shape)
    splicing_df_no_dups.head()
    
    splicing2d = splicing_df_no_dups.pivot(index=cell, columns=gene, values='z')
    return splicing2d


def my_nan_euclidean_metric(row_i, row_j):
    #     assert row_i.shape == row_j.shape

    i_missing = np.isnan(row_i)
    j_missing = np.isnan(row_j)

    shared = (~i_missing) & (~j_missing)
    n_shared = shared.sum()
    if n_shared == 0:
        return 0
    weight = row_i.shape[0] / n_shared

    i_shared = row_i[shared]
    j_shared = row_j[shared]

    sum_of_squares = np.sum(np.square(i_shared - j_shared))
    distance = np.sqrt(weight * sum_of_squares)
    return distance


def to_memmap(array):
    """Write a memory mapped array
    Create a memory-map to an array stored in a binary file on disk.
    Memory-mapped files are used for accessing small segments of
    large files on disk, without reading the entire file into memory.
    :param np.array array to memory map
    :return: np.array large_memmap memory mapped array
    :return: str filename name of the file that memory mapped array is written to
    """
    import numpy as np

    filename = tempfile.NamedTemporaryFile(
        prefix="array", suffix=".mmap", delete=False
    ).name
    shape = array.shape
    f = np.memmap(filename, mode="w+", shape=shape, dtype=array.dtype)
    f[:] = array[:]
    del f
    large_memmap = np.memmap(filename, dtype=array.dtype, shape=shape)
    return large_memmap, filename


def distance_args_unpack(args):
    """Helper function to unpack the arguments. Written to use in pool.imap
    as it can only be given one argument."""
    row_i, row_j = args
    return my_nan_euclidean_metric(row_i, row_j)


def get_distances_at_index(index, matrix):
    """Returns similarities of all the combinations of signature at index in
    the siglist with the rest of the indices starting at index + 1. Doesn't
    redundantly calculate signatures with all the other indices prior to
    index - 1

    :param int index: generate masks from this image
    :param boolean ignore_abundance
        If the sketches are not abundance weighted, or ignore_abundance=True,
        compute Jaccard similarity.

        If the sketches are abundance weighted, calculate the angular
        similarity.
    :param boolean downsample by max_hash if True
    :param siglist list of signatures
    :return: list of similarities for the combinations of signature at index
        with rest of the signatures from index+1
    """
    startt = time.time()
    sig_iterator = itertools.product([matrix[index, :]], matrix[(index + 1) :, :])
    func = partial(distance_args_unpack,)
    similarity_list = list(map(func, sig_iterator))
    notify(
        "comparison for index {} done in {:.5f} seconds",
        index,
        time.time() - startt,
        end="\r",
    )
    return similarity_list


def distances_parallel(matrix, n_jobs):
    """Compare all combinations of signatures and return a matrix
    of similarities. Processes combinations parallely on number of processes
    given by n_jobs

    :param list siglist: list of signatures to compare
    :param boolean ignore_abundance
        If the sketches are not abundance weighted, or ignore_abundance=True,
        compute Jaccard similarity.

        If the sketches are abundance weighted, calculate the angular
        similarity.
    :param boolean downsample by max_hash if True
    :param int n_jobs number of processes to run the similarity calculations on
    :return: np.array similarity matrix
    """

    # Starting time - calculate time to keep track in case of lengthy siglist
    start_initial = time.time()

    # Create a memory map of the siglist using numpy to avoid memory burden
    # while accessing small parts in it
    matrix, _ = to_memmap(np.array(matrix))
    notify("Created memmapped input matrix")

    # Check that length of combinations can result in a square similarity matrix
    length_matrix = len(matrix)
    shape = (length_matrix, length_matrix)

    # Initialize with ones in the diagonal as the similarity of a signature with
    # itself is one
    distances = np.zeros(shape, dtype=np.float64)
    memmap_distances, filename = to_memmap(distances)
    notify("Initialized memmapped similarities matrix")

    # Initialize the function using func.partial with the common arguments like
    # siglist, ignore_abundance, downsample, for computing all the signatures
    # The only changing parameter that will be mapped from the pool is the index
    func = partial(get_distances_at_index, matrix=matrix,)
    notify("Created similarity func")

    # Initialize multiprocess.pool
    pool = multiprocessing.Pool(processes=n_jobs)

    # Calculate chunk size, by default pool.imap chunk size is 1
    chunksize, extra = divmod(length_matrix, n_jobs)
    if extra:
        chunksize += 1
    notify("Calculated chunk size for multiprocessing")

    # This will not generate the results yet, since pool.imap returns a generator
    result = pool.imap(func, range(length_matrix), chunksize=chunksize)
    notify("Initialized multiprocessing pool.imap")

    # Enumerate and calculate similarities at each of the indices
    # and set the results at the appropriate combination coordinate
    # locations inside the similarity matrix
    for index, l in enumerate(result):
        startt = time.time()
        col_idx = index + 1
        for idx_condensed, item in enumerate(l):
            i = index
            j = col_idx + idx_condensed
            memmap_distances[i, j] = memmap_distances[j, i] = item
        notify(
            "Setting similarities matrix for index {} done in {:.5f} seconds",
            index,
            time.time() - startt,
            end="\r",
        )
    notify("Setting similarities completed")

    pool.close()
    pool.join()

    notify(
        "Time taken to compare all pairs parallely is {:.5f} seconds ",
        time.time() - start_initial,
    )
    return np.memmap(filename, dtype=np.float64, shape=shape)


def compute_distances_df(splicing2d, n_jobs):
    dists = distances_parallel(splicing2d, n_jobs=n_jobs)
    dists_df = pd.DataFrame(dists, index=splicing2d.index, columns=splicing2d.index)
    return dists_df
# Out:
# Overwriting splicing_utils.py

# %% [markdown]
# ## Function to process splicing

# %%
import splicing_utils

# %%
df.tissue.value_counts()
# Out:
# Bladder     3505271
# Lung        3443061
# Pancreas    2156269
# Blood       1832072
# Muscle      1009895
# Name: tissue, dtype: int64

# %%
# %%time

splicing_df = splicing_utils.process_splicing(parquet)
print(splicing_df.shape)
splicing_df.head()
# Out:
# (4070048, 93)
# (32042, 2580)
# CPU times: user 43.9 s, sys: 1min 58s, total: 2min 41s
# Wall time: 29.9 s
# geneR1A_uniq                            A2M  AAK1     AAMDC  AARSD1  AASDH  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC  NaN   NaN       NaN     NaN    NaN
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC  NaN   NaN       NaN     NaN    NaN
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT  NaN   NaN       NaN     NaN    NaN
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT  NaN   NaN  0.302979     NaN    NaN
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT  NaN   NaN       NaN     NaN    NaN
#
# geneR1A_uniq                            ABCA6  ABCA9  ABHD12  ABI3BP  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC    NaN    NaN     NaN     NaN
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC    NaN    NaN     NaN     NaN
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT    NaN    NaN     NaN     NaN
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT    NaN    NaN     NaN     NaN
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT    NaN    NaN     NaN     NaN
#
# geneR1A_uniq                            AC005062.2  ...  ZNF721  ZNF808  \
# cell                                                ...
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC         NaN  ...     NaN     NaN
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC         NaN  ...     NaN     NaN
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT         NaN  ...     NaN     NaN
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT         NaN  ...     NaN     NaN
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT         NaN  ...     NaN     NaN
#
# geneR1A_uniq                            ZNF83  ZNF98  ZNHIT1  ZRANB2  ZRSR2  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC    NaN    NaN     NaN     NaN    NaN
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC    NaN    NaN     NaN     NaN    NaN
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT    NaN    NaN     NaN     NaN    NaN
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT    NaN    NaN     NaN     NaN    NaN
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT    NaN    NaN     NaN     NaN    NaN
#
# geneR1A_uniq                            ZSWIM7  bP-2189O9.2   unknown
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC     NaN          NaN       NaN
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC     NaN          NaN       NaN
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT     NaN          NaN       NaN
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT     NaN          NaN       NaN
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT     NaN          NaN -0.402279
#
# [5 rows x 2580 columns]

# %%
# %%time

muscle_df = splicing_utils.process_splicing(parquet, tissue="Muscle")
print(muscle_df.shape)
muscle_df.head()
# Out:
# (305008, 93)
# (2193, 1728)
# CPU times: user 42.9 s, sys: 1min 44s, total: 2min 27s
# Wall time: 26.3 s
# geneR1A_uniq                            A2M  AAK1  AAMDC  AARSD1  ABCA6  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC  NaN   NaN    NaN     NaN    NaN
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC  NaN   NaN    NaN     NaN    NaN
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC  NaN   NaN    NaN     NaN    NaN
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG  NaN   NaN    NaN     NaN    NaN
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC  NaN   NaN    NaN     NaN    NaN
#
# geneR1A_uniq                            ABCA9  ABI3BP  AC005329.7  AC009950.1  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC    NaN     NaN         NaN         NaN
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC    NaN     NaN         NaN         NaN
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC    NaN     NaN         NaN         NaN
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG    NaN     NaN         NaN         NaN
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC    NaN     NaN         NaN         NaN
#
# geneR1A_uniq                            AC018816.3  ...  ZNF106  ZNF331  \
# cell                                                ...
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC         NaN  ...     NaN     NaN
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC         NaN  ...     NaN     NaN
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC         NaN  ...     NaN     NaN
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG         NaN  ...     NaN     NaN
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC         NaN  ...     NaN     NaN
#
# geneR1A_uniq                            ZNF33A  ZNF385D  ZNF706  ZNF808  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC     NaN      NaN     NaN     NaN
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC     NaN      NaN     NaN     NaN
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC     NaN      NaN     NaN     NaN
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG     NaN      NaN     NaN     NaN
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC     NaN      NaN     NaN     NaN
#
# geneR1A_uniq                            ZNHIT1  ZRANB2  bP-2189O9.2  unknown
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC     NaN     NaN          NaN      NaN
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC     NaN     NaN          NaN      NaN
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC     NaN     NaN          NaN      NaN
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG     NaN     NaN          NaN      NaN
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC     NaN     NaN          NaN      NaN
#
# [5 rows x 1728 columns]

# %%
# %%time

all_tissue_dists_df = splicing_utils.compute_distances_df(splicing_df, n_jobs=32)
print(all_tissue_dists_df.shape)
all_tissue_dists_df.head()
# Out:
# Created memmapped input matrix
# Initialized memmapped similarities matrix
# Created similarity func
# Calculated chunk size for multiprocessing
# Initialized multiprocessing pool.imap
# Setting similarities completeddone in 0.75156 secondsn 0.00000 secondsetting similarities matrix for index 7856 done in 0.01020 secondsSetting similarities matrix for index 9091 done in 0.00996 secondsSetting similarities matrix for index 9139 done in 0.00920 secondsSetting similarities matrix for index 9746 done in 0.01289 secondsSetting similarities matrix for index 14228 done in 0.00588 secondsSetting similarities matrix for index 14401 done in 0.00633 secondsSetting similarities matrix for index 14736 done in 0.00601 secondsSetting similarities matrix for index 14939 done in 0.00582 secondsSetting similarities matrix for index 15100 done in 0.00608 secondsSetting similarities matrix for index 16449 done in 0.00494 secondsSetting similarities matrix for index 16501 done in 0.00550 secondsSetting similarities matrix for index 16798 done in 0.00510 secondsSetting similarities matrix for index 16841 done in 0.00504 secondsSetting similarities matrix for index 17078 done in 0.00468 secondsSetting similarities matrix for index 17456 done in 0.00476 secondsSetting similarities matrix for index 17896 done in 0.00486 secondsSetting similarities matrix for index 18189 done in 0.00428 secondsSetting similarities matrix for index 18378 done in 0.00468 secondsSetting similarities matrix for index 18506 done in 0.00451 secondsSetting similarities matrix for index 18612 done in 0.00473 secondsSetting similarities matrix for index 19518 done in 0.00435 secondsSetting similarities matrix for index 19621 done in 0.00516 secondsSetting similarities matrix for index 19645 done in 0.00440 secondsSetting similarities matrix for index 19757 done in 0.00465 secondsSetting similarities matrix for index 19814 done in 0.00385 secondsSetting similarities matrix for index 20353 done in 0.00366 secondsSetting similarities matrix for index 20934 done in 0.00476 secondsSetting similarities matrix for index 21362 done in 0.00416 secondsSetting similarities matrix for index 21915 done in 0.00374 secondsSetting similarities matrix for index 22264 done in 0.00375 secondsSetting similarities matrix for index 23503 done in 0.00316 secondsSetting similarities matrix for index 23606 done in 0.00321 secondsSetting similarities matrix for index 23671 done in 0.00312 secondsSetting similarities matrix for index 25014 done in 0.00232 secondsSetting similarities matrix for index 25215 done in 0.00218 secondsSetting similarities matrix for index 27454 done in 0.00184 secondsSetting similarities matrix for index 27732 done in 0.00160 secondsSetting similarities matrix for index 27863 done in 0.00134 secondsSetting similarities matrix for index 28042 done in 0.00144 secondsSetting similarities matrix for index 28536 done in 0.00111 secondsSetting similarities matrix for index 29214 done in 0.00094 secondsSetting similarities matrix for index 29920 done in 0.00135 secondsSetting similarities matrix for index 30453 done in 0.00099 secondsSetting similarities matrix for index 31053 done in 0.00033 secondsSetting similarities matrix for index 31302 done in 0.00024 seconds
# Time taken to compare all pairs parallely is 2115.71757 seconds
# (32042, 32042)
# CPU times: user 7min 31s, sys: 3min 1s, total: 10min 33s
# Wall time: 35min 16s
# cell                                    TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC                                0.000000
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC                               59.681675
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT                               54.006681
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT                               78.348585
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT                               82.678733
#
# cell                                    TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC                               59.681675
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC                                0.000000
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT                               59.345095
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT                               76.225425
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT                               78.737491
#
# cell                                    TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC                               54.006681
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC                               59.345095
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT                                0.000000
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT                               78.878612
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT                               77.245525
#
# cell                                    TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC                               78.348585
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC                               76.225425
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT                               78.878612
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT                                0.000000
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT                               76.557185
#
# cell                                    TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC                               82.678733
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC                               78.737491
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT                               77.245525
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT                               76.557185
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT                                0.000000
#
# cell                                    TSP1_bladder_1_S7_L00_AAACGCTGTCATCGCG  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC                               75.128480
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC                               75.755162
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT                               80.905339
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT                               81.551780
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT                               92.795427
#
# cell                                    TSP1_bladder_1_S7_L00_AAACGCTGTCCAAGAG  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC                               76.926503
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC                               75.832254
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT                               75.815077
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT                               85.902326
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT                               83.010425
#
# cell                                    TSP1_bladder_1_S7_L00_AAACGCTTCTGTGCGG  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC                               88.280793
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC                               94.994400
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT                               92.361255
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT                              101.582217
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT                               99.219235
#
# cell                                    TSP1_bladder_1_S7_L00_AAAGAACAGCAATTAG  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC                               65.164759
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC                               64.339622
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT                               70.248862
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT                               70.064612
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT                               81.767535
#
# cell                                    TSP1_bladder_1_S7_L00_AAAGAACCAAGTTCCA  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC                               86.866832
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC                               85.339229
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT                               82.053080
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT                               75.030835
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT                               71.746291
#
# cell                                    ...  \
# cell                                    ...
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC  ...
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC  ...
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT  ...
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT  ...
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT  ...
#
# cell                                    TSP1_muscle_3_S15_L00_TTTCCTCAGGCCTTCG  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC                               78.977566
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC                               81.055964
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT                               74.822013
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT                              112.167574
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT                              111.531228
#
# cell                                    TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC                              105.171392
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC                               99.155290
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT                               91.717457
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT                              115.575160
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT                              118.367638
#
# cell                                    TSP1_muscle_3_S15_L00_TTTCGATAGGTTAAAC  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC                              115.530661
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC                               97.082288
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT                              103.667761
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT                              111.155076
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT                              110.765373
#
# cell                                    TSP1_muscle_3_S15_L00_TTTCGATCAAGCTGTT  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC                              111.955806
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC                              103.114181
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT                              105.545372
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT                              133.215103
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT                              138.208647
#
# cell                                    TSP1_muscle_3_S15_L00_TTTGACTAGGGTGAAA  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC                               96.520607
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC                               96.520489
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT                               91.477729
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT                              115.674800
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT                              122.212057
#
# cell                                    TSP1_muscle_3_S15_L00_TTTGACTCACTGCGAC  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC                              102.274700
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC                               91.545132
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT                               86.763019
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT                              114.514531
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT                              113.336860
#
# cell                                    TSP1_muscle_3_S15_L00_TTTGGTTCATTGCCGG  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC                              119.091830
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC                              108.473600
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT                               93.912776
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT                              123.089299
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT                              118.050257
#
# cell                                    TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC                               83.312637
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC                               76.814927
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT                               68.609522
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT                              106.459560
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT                              111.109617
#
# cell                                    TSP1_muscle_3_S15_L00_TTTGTTGCAACGCATT  \
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC                              109.818735
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC                              100.223919
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT                               82.904133
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT                              116.008436
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT                              119.223472
#
# cell                                    TSP1_muscle_3_S15_L00_TTTGTTGGTAACATAG
# cell
# TSP1_bladder_1_S7_L00_AAACCCATCCTTCGAC                               93.084221
# TSP1_bladder_1_S7_L00_AAACCCATCGAAGGAC                               97.281255
# TSP1_bladder_1_S7_L00_AAACGAAGTGAGTAAT                               91.627158
# TSP1_bladder_1_S7_L00_AAACGCTAGCACGGAT                              105.043798
# TSP1_bladder_1_S7_L00_AAACGCTGTACCGGCT                              106.735774
#
# [5 rows x 32042 columns]

# %% [markdown]
# ### Write all tissue dists to file

# %%
distance_folder = f'{splicing_folder}/nan_aware_distances'
! mkdir -p $distance_folder
all_tissue_dists_df.to_parquet(f'{distance_folder}/TS_10x_redo_sym_S_0.1_z_0.0_b_5__distances.parquet')

# %%
# %%time

muscle_dists = splicing_utils.distances_parallel(muscle_df, n_jobs=8)
print(muscle_dists.shape)
# Out:
# Created memmapped input matrix
# Initialized memmapped similarities matrix
# Created similarity func
# Calculated chunk size for multiprocessing
# Initialized multiprocessing pool.imap
# Setting similarities completedr index 2192 done in 0.00000 secondsSetting similarities matrix for index 1105 done in 0.00032 secondsSetting similarities matrix for index 1503 done in 0.00024 seconds
# (2193, 2193)
# CPU times: user 2.4 s, sys: 4.14 s, total: 6.53 s
# Wall time: 34.2 s
# Time taken to compare all pairs parallely is 34.23452 seconds

# %%
muscle_dists_df = pd.DataFrame(muscle_dists, index=muscle_df.index, columns=muscle_df.index)
print(muscle_dists_df.shape)
muscle_dists_df.head()
# Out:
# (2193, 2193)
# cell                                    TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC                                0.000000
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC                               64.905423
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC                               78.590702
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG                               63.036527
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC                              100.899792
#
# cell                                    TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC                               64.905423
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC                                0.000000
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC                               70.962987
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG                               56.879149
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC                               96.694871
#
# cell                                    TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC                               78.590702
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC                               70.962987
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC                                0.000000
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG                               67.213372
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC                               64.517785
#
# cell                                    TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC                               63.036527
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC                               56.879149
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC                               67.213372
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG                                0.000000
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC                               62.290726
#
# cell                                    TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC                              100.899792
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC                               96.694871
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC                               64.517785
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG                               62.290726
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC                                0.000000
#
# cell                                    TSP1_muscle_1_S13_L00_AAATGGAAGCAGATAT  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC                               60.759464
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC                               44.079041
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC                               56.034204
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG                               60.614921
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC                               96.768701
#
# cell                                    TSP1_muscle_1_S13_L00_AACACACAGTGATTCC  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC                              124.069012
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC                               98.472187
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC                              131.404868
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG                              110.431863
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC                              103.861524
#
# cell                                    TSP1_muscle_1_S13_L00_AACACACCAGCACACC  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC                               69.370627
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC                               57.675664
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC                               56.141440
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG                               61.916032
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC                              101.962892
#
# cell                                    TSP1_muscle_1_S13_L00_AACAGGGGTTTACTGG  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC                               59.147103
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC                               46.678387
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC                               62.826320
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG                               59.007915
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC                               67.174546
#
# cell                                    TSP1_muscle_1_S13_L00_AACCAACAGACTCTAC  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC                               79.421200
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC                               67.671647
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC                               70.150058
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG                               63.353294
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC                              133.838731
#
# cell                                    ...  \
# cell                                    ...
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC  ...
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC  ...
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC  ...
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG  ...
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC  ...
#
# cell                                    TSP1_muscle_3_S15_L00_TTTCCTCAGCCTGACC  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC                               71.318296
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC                               75.414336
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC                              101.111568
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG                               87.488601
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC                              107.649525
#
# cell                                    TSP1_muscle_3_S15_L00_TTTCCTCAGGCCTTCG  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC                               71.785115
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC                               73.041602
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC                               70.173379
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG                               76.897420
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC                              134.104692
#
# cell                                    TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC                               76.858856
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC                               74.167948
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC                               88.143214
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG                               82.938572
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC                              129.018571
#
# cell                                    TSP1_muscle_3_S15_L00_TTTCGATAGGTTAAAC  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC                               72.017216
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC                               75.943463
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC                               89.769384
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG                               74.620650
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC                               92.036977
#
# cell                                    TSP1_muscle_3_S15_L00_TTTCGATCAAGCTGTT  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC                               80.879281
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC                               68.686309
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC                               77.457689
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG                               68.804253
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC                              123.750396
#
# cell                                    TSP1_muscle_3_S15_L00_TTTGACTAGGGTGAAA  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC                               68.717007
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC                               79.371609
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC                               75.745095
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG                               72.599116
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC                              115.518367
#
# cell                                    TSP1_muscle_3_S15_L00_TTTGACTCACTGCGAC  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC                               73.554703
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC                               65.985261
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC                               65.253979
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG                               66.700645
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC                              113.032170
#
# cell                                    TSP1_muscle_3_S15_L00_TTTGGTTCATTGCCGG  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC                               84.507145
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC                               74.310812
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC                               94.615487
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG                               89.982978
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC                              111.360558
#
# cell                                    TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT  \
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC                               71.374711
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC                               73.479676
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC                               77.696639
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG                               76.313683
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC                              130.981381
#
# cell                                    TSP1_muscle_3_S15_L00_TTTGTTGCAACGCATT
# cell
# TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC                               75.937644
# TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC                               69.427236
# TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC                               70.428732
# TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG                               72.560491
# TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC                              118.118669
#
# [5 rows x 2193 columns]

# %%
muscle_dists_df.to_parquet(f'{distance_folder}/TS_10x_redo_sym_S_0.1_z_0.0_b_5__tissue-Muscle__distances.parquet')

# %%
2+2
# Out:
# 4

# %% [markdown]
# ## Read h5ad

# %%
h5ad = '/home/olga/Pilot1_Pilot2_filtered_ensembl_id_Aug5.ss2_norm.ann.compartment.allgenes.h5ad'
adata = sc.read(h5ad)
adata
# Out:
# WARNING: Your filename has more than two extensions: ['.ss2_norm', '.ann', '.compartment', '.allgenes', '.h5ad'].
# Only considering the two last: ['.allgenes', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.ss2_norm', '.ann', '.compartment', '.allgenes', '.h5ad'].
# Only considering the two last: ['.allgenes', '.h5ad'].
# AnnData object with n_obs × n_vars = 207016 × 58870
#     obs: '10X_run', 'smartseq2_barcode', 'smartseq2_library_plate', 'smartseq2_sorting_direction', 'smartseq2_sort_order', 'smartseq2_cDNA_Plate', 'cell_id', 'method', 'donor', '10X_replicate', 'sequencer', 'sex', 'tissue', 'smartseq2_well_seq', 'notes', 'smartseq2_sorted_population', '10X_sample', 'anatomical_position', '10X_barcode', 'n_counts', 'n_genes', 'manual_cell_ontology_class', 'manual_annotation', 'doublet_filter', 'compartment', 'batch', 'compartment_pred', 'leiden', 'cluster_id', 'Propagated Annotation', 'Entropy All Methods', 'Entropy kNN Reps', 'Entropy scANVI Reps', 'Entropy SVM Reps', 'Potential Doublets', 'Onclass', 'singlecellNet', 'kNN', 'SVM', 'scANVI', 'compartment_pred_svm', 'manual_cell_ontology_classcollapsed', 'Propagated Annotationcollapsed', 'Onclasscollapsed', 'singlecellNetcollapsed', 'kNNcollapsed', 'SVMcollapsed', 'scANVIcollapsed', 'miscompartmentalized', 'log_n_counts', 'log_n_genes'
#     var: 'feature_types-0-0', 'n_cells-0-0', 'gene_symbol-0-0', 'n_cells-1-0', 'n_cells-0', 'n_cells-1-1', 'feature_types-0-0-0-1', 'gene_symbol-0-0-0-1', 'n_cells-1-0-0-1', 'n_cells-1-0-1', 'n_cells', 'len', 'ensembl_id'
#     obsm: 'X_scvi', 'X_umap'

# %%
adata.obs.head()
# Out:
#                                     10X_run smartseq2_barcode  \
# AAACCCAAGTTGTCGT_TSP1_blood_2  TSP1_blood_2               nan
# AAACGAAAGCCGTTAT_TSP1_blood_2  TSP1_blood_2               nan
# AAAGGATAGTGTTGTC_TSP1_blood_2  TSP1_blood_2               nan
# AAAGGGCAGGAACTAT_TSP1_blood_2  TSP1_blood_2               nan
# AAAGGGCCAACCAACT_TSP1_blood_2  TSP1_blood_2               nan
#
#                               smartseq2_library_plate  \
# AAACCCAAGTTGTCGT_TSP1_blood_2                     nan
# AAACGAAAGCCGTTAT_TSP1_blood_2                     nan
# AAAGGATAGTGTTGTC_TSP1_blood_2                     nan
# AAAGGGCAGGAACTAT_TSP1_blood_2                     nan
# AAAGGGCCAACCAACT_TSP1_blood_2                     nan
#
#                               smartseq2_sorting_direction  \
# AAACCCAAGTTGTCGT_TSP1_blood_2                         nan
# AAACGAAAGCCGTTAT_TSP1_blood_2                         nan
# AAAGGATAGTGTTGTC_TSP1_blood_2                         nan
# AAAGGGCAGGAACTAT_TSP1_blood_2                         nan
# AAAGGGCCAACCAACT_TSP1_blood_2                         nan
#
#                               smartseq2_sort_order smartseq2_cDNA_Plate  \
# AAACCCAAGTTGTCGT_TSP1_blood_2                  nan                  nan
# AAACGAAAGCCGTTAT_TSP1_blood_2                  nan                  nan
# AAAGGATAGTGTTGTC_TSP1_blood_2                  nan                  nan
# AAAGGGCAGGAACTAT_TSP1_blood_2                  nan                  nan
# AAAGGGCCAACCAACT_TSP1_blood_2                  nan                  nan
#
#                                                      cell_id method donor  \
# AAACCCAAGTTGTCGT_TSP1_blood_2  AAACCCAAGTTGTCGT_TSP1_blood_2    10X  TSP1
# AAACGAAAGCCGTTAT_TSP1_blood_2  AAACGAAAGCCGTTAT_TSP1_blood_2    10X  TSP1
# AAAGGATAGTGTTGTC_TSP1_blood_2  AAAGGATAGTGTTGTC_TSP1_blood_2    10X  TSP1
# AAAGGGCAGGAACTAT_TSP1_blood_2  AAAGGGCAGGAACTAT_TSP1_blood_2    10X  TSP1
# AAAGGGCCAACCAACT_TSP1_blood_2  AAAGGGCCAACCAACT_TSP1_blood_2    10X  TSP1
#
#                               10X_replicate  ...  \
# AAACCCAAGTTGTCGT_TSP1_blood_2             2  ...
# AAACGAAAGCCGTTAT_TSP1_blood_2             2  ...
# AAAGGATAGTGTTGTC_TSP1_blood_2             2  ...
# AAAGGGCAGGAACTAT_TSP1_blood_2             2  ...
# AAAGGGCCAACCAACT_TSP1_blood_2             2  ...
#
#                               manual_cell_ontology_classcollapsed  \
# AAACCCAAGTTGTCGT_TSP1_blood_2                          unassigned
# AAACGAAAGCCGTTAT_TSP1_blood_2                          unassigned
# AAAGGATAGTGTTGTC_TSP1_blood_2                          unassigned
# AAAGGGCAGGAACTAT_TSP1_blood_2                          unassigned
# AAAGGGCCAACCAACT_TSP1_blood_2                          unassigned
#
#                               Propagated Annotationcollapsed  \
# AAACCCAAGTTGTCGT_TSP1_blood_2                         T cell
# AAACGAAAGCCGTTAT_TSP1_blood_2                         T cell
# AAAGGATAGTGTTGTC_TSP1_blood_2                         T cell
# AAAGGGCAGGAACTAT_TSP1_blood_2             classical monocyte
# AAAGGGCCAACCAACT_TSP1_blood_2             classical monocyte
#
#                                  Onclasscollapsed singlecellNetcollapsed  \
# AAACCCAAGTTGTCGT_TSP1_blood_2              T cell                 T cell
# AAACGAAAGCCGTTAT_TSP1_blood_2              T cell                 T cell
# AAAGGATAGTGTTGTC_TSP1_blood_2              T cell                 T cell
# AAAGGGCAGGAACTAT_TSP1_blood_2  classical monocyte     classical monocyte
# AAAGGGCCAACCAACT_TSP1_blood_2  classical monocyte     classical monocyte
#
#                                      kNNcollapsed        SVMcollapsed  \
# AAACCCAAGTTGTCGT_TSP1_blood_2              T cell              T cell
# AAACGAAAGCCGTTAT_TSP1_blood_2              T cell              T cell
# AAAGGATAGTGTTGTC_TSP1_blood_2              T cell              T cell
# AAAGGGCAGGAACTAT_TSP1_blood_2  classical monocyte  classical monocyte
# AAAGGGCCAACCAACT_TSP1_blood_2  classical monocyte  classical monocyte
#
#                                   scANVIcollapsed miscompartmentalized  \
# AAACCCAAGTTGTCGT_TSP1_blood_2              T cell                False
# AAACGAAAGCCGTTAT_TSP1_blood_2              T cell                False
# AAAGGATAGTGTTGTC_TSP1_blood_2              T cell                False
# AAAGGGCAGGAACTAT_TSP1_blood_2  classical monocyte                False
# AAAGGGCCAACCAACT_TSP1_blood_2  classical monocyte                False
#
#                               log_n_counts  log_n_genes
# AAACCCAAGTTGTCGT_TSP1_blood_2     9.028579     7.628518
# AAACGAAAGCCGTTAT_TSP1_blood_2     8.651199     7.521318
# AAAGGATAGTGTTGTC_TSP1_blood_2     8.994669     7.699842
# AAAGGGCAGGAACTAT_TSP1_blood_2     9.131947     7.930925
# AAAGGGCCAACCAACT_TSP1_blood_2    10.058095     8.454040
#
# [5 rows x 51 columns]

# %%
adata.obs.method.value_counts()

# %%
2+2

# %%
adata.obs.sample(10)

# %%
muscle_dists_df.sample(10)

# %%
adata_has_splicing_data = adata.

# %% [markdown]
# # Do BBKNN and UMAP

# %%
import bbknn

# %%
batch_keys = adata.obs.loc[muscle_df.index]

# %%
bbknn.bbknn_pca_matrix(muscle_dists_df,  metric='precomputed')
