# %%
# %load_ext autoreload
# %autoreload 2
import glob

import numpy as np
import scanpy as sc
import pandas as pd
import seaborn as sns
from sklearn.metrics.pairwise import nan_euclidean_distances
from sklearn.metrics import pairwise_distances, pairwise_distances_chunked
from tqdm import tqdm

sc.settings.verbosity = 4
#sc.set_figure_params(dpi=200, dpi_save=300)
sc.logging.print_versions()
sc.set_figure_params(frameon=False, color_map='magma_r')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# scanpy==1.4.6.dev9+ge632939 anndata==0.7rc1 umap==0.3.10 numpy==1.17.3 scipy==1.3.2 pandas==0.25.3 scikit-learn==0.22 statsmodels==0.10.2 python-igraph==0.7.1 louvain==0.6.1

# %% [markdown]
# ## Data folder

# %%
splicing_folder = '/home/olga/data_sm/splicing/rawdata/rijk_zscore__2020-10-13'
! ls -lha $splicing_folder
# Out:
# total 1.0K
# drwxr-xr-x 2 olga czb 4.0K Oct 13 10:14 .
# drwxr-xr-x 7 olga czb 4.0K Oct 13 10:15 ..

# %% [markdown]
# # function for multiprocessing splicing

# %%
# %%file splicing_utils.py

import itertools
from functools import partial
import multiprocessing
import sys
import tempfile
import time

import numpy as np
import pandas as pd

_quiet = False
_debug = False
def set_quiet(val, print_debug=False):
    global _quiet, _debug
    _quiet = bool(val)
    _debug = bool(print_debug)



# Cribbed from https://github.com/dib-lab/sourmash/blob/c7ed8bef7de9b1581b9b067517f64ac64f31f9d0/sourmash/logging.py
def notify(s, *args, **kwargs):
    "A simple logging function => stderr."
    if _quiet:
        return

    print(u'\r\033[K', end=u'', file=sys.stderr)
    print(s.format(*args, **kwargs), file=sys.stderr,
          end=kwargs.get('end', u'\n'))
    if kwargs.get('flush'):
        sys.stderr.flush()



def process_splicing(filename, gene='geneR1A_uniq', cell='cell', tissue=None, method='10x'):
    splicing_df = pd.read_parquet(filename)
    
    
    # Add cell ids that match the h5ad object
    if method == '10x':
        # regex builder: https://regex101.com/r/rE1xfN/1
        matches = splicing_df[cell].str.extractall('(?P<channel_cleaned>[\w-]+)_S\d+_L\d+_(?P<cell_barcode>[ACGT]+)')
        matches = matches.droplevel(-1)
        splicing_df = pd.concat([splicing_df, matches], axis=1)
        splicing_df['cell_id'] = splicing_df['cell_barcode'].astype(str) + '_' + splicing_df['channel_cleaned'].astype(str)
    elif method == 'ss2_tsp1':
        splicing_df['cell_id'] = splicing_df['cell'].astype(str) + '.homo.gencode.v30.ERCC.chrM'
    elif method == "ss2_tsp2":
        splicing_df['cell_id'] = splicing_df['cell']

    # Drop duplicate cell ids and gene names
    splicing_df_no_dups = splicing_df.drop_duplicates(['cell_id', gene])

    
    if tissue is not None:
        splicing_df_no_dups = splicing_df_no_dups.query('tissue == @tissue')
        
    
    # Don't use rows with empty gene names -- these are unannotated genes
    splicing_df_no_dups = splicing_df_no_dups.query(f'{gene} != ""')
    print(splicing_df_no_dups.shape)
    splicing_df_no_dups.head()
    
#     splicing2d = splicing_df_no_dups.pivot(index='cell_id', columns=gene, values='z')
    return splicing_df_no_dups


def my_nan_euclidean_metric(row_i, row_j):
    #     assert row_i.shape == row_j.shape

    i_missing = np.isnan(row_i)
    j_missing = np.isnan(row_j)

    shared = (~i_missing) & (~j_missing)
    n_shared = shared.sum()
    if n_shared == 0:
        return 0
    weight = row_i.shape[0] / n_shared

    i_shared = row_i[shared]
    j_shared = row_j[shared]

    sum_of_squares = np.sum(np.square(i_shared - j_shared))
    distance = np.sqrt(weight * sum_of_squares)
    return distance


def to_memmap(array):
    """Write a memory mapped array
    Create a memory-map to an array stored in a binary file on disk.
    Memory-mapped files are used for accessing small segments of
    large files on disk, without reading the entire file into memory.
    :param np.array array to memory map
    :return: np.array large_memmap memory mapped array
    :return: str filename name of the file that memory mapped array is written to
    """
    import numpy as np

    filename = tempfile.NamedTemporaryFile(
        prefix="array", suffix=".mmap", delete=False
    ).name
    shape = array.shape
    f = np.memmap(filename, mode="w+", shape=shape, dtype=array.dtype)
    f[:] = array[:]
    del f
    large_memmap = np.memmap(filename, dtype=array.dtype, shape=shape)
    return large_memmap, filename


def distance_args_unpack(args):
    """Helper function to unpack the arguments. Written to use in pool.imap
    as it can only be given one argument."""
    row_i, row_j = args
    return my_nan_euclidean_metric(row_i, row_j)


def get_distances_at_index(index, matrix):
    """Returns similarities of all the combinations of signature at index in
    the siglist with the rest of the indices starting at index + 1. Doesn't
    redundantly calculate signatures with all the other indices prior to
    index - 1

    :param int index: generate masks from this image
    :param boolean ignore_abundance
        If the sketches are not abundance weighted, or ignore_abundance=True,
        compute Jaccard similarity.

        If the sketches are abundance weighted, calculate the angular
        similarity.
    :param boolean downsample by max_hash if True
    :param siglist list of signatures
    :return: list of similarities for the combinations of signature at index
        with rest of the signatures from index+1
    """
    startt = time.time()
    sig_iterator = itertools.product([matrix[index, :]], matrix[(index + 1) :, :])
    func = partial(distance_args_unpack,)
    similarity_list = list(map(func, sig_iterator))
    notify(
        "comparison for index {} done in {:.5f} seconds",
        index,
        time.time() - startt,
        end="\r",
    )
    return similarity_list


def distances_parallel(matrix, n_jobs):
    """Compare all combinations of signatures and return a matrix
    of similarities. Processes combinations parallely on number of processes
    given by n_jobs

    :param list siglist: list of signatures to compare
    :param boolean ignore_abundance
        If the sketches are not abundance weighted, or ignore_abundance=True,
        compute Jaccard similarity.

        If the sketches are abundance weighted, calculate the angular
        similarity.
    :param boolean downsample by max_hash if True
    :param int n_jobs number of processes to run the similarity calculations on
    :return: np.array similarity matrix
    """

    # Starting time - calculate time to keep track in case of lengthy siglist
    start_initial = time.time()

    # Create a memory map of the siglist using numpy to avoid memory burden
    # while accessing small parts in it
    matrix, _ = to_memmap(np.array(matrix))
    notify("Created memmapped input matrix")

    # Check that length of combinations can result in a square similarity matrix
    length_matrix = len(matrix)
    shape = (length_matrix, length_matrix)

    # Initialize with ones in the diagonal as the similarity of a signature with
    # itself is one
    distances = np.zeros(shape, dtype=np.float64)
    memmap_distances, filename = to_memmap(distances)
    notify("Initialized memmapped similarities matrix")

    # Initialize the function using func.partial with the common arguments like
    # siglist, ignore_abundance, downsample, for computing all the signatures
    # The only changing parameter that will be mapped from the pool is the index
    func = partial(get_distances_at_index, matrix=matrix,)
    notify("Created similarity func")

    # Initialize multiprocess.pool
    pool = multiprocessing.Pool(processes=n_jobs)

    # Calculate chunk size, by default pool.imap chunk size is 1
    chunksize, extra = divmod(length_matrix, n_jobs)
    if extra:
        chunksize += 1
    notify("Calculated chunk size for multiprocessing")

    # This will not generate the results yet, since pool.imap returns a generator
    result = pool.imap(func, range(length_matrix), chunksize=chunksize)
    notify("Initialized multiprocessing pool.imap")

    # Enumerate and calculate similarities at each of the indices
    # and set the results at the appropriate combination coordinate
    # locations inside the similarity matrix
    for index, l in enumerate(result):
        startt = time.time()
        col_idx = index + 1
        for idx_condensed, item in enumerate(l):
            i = index
            j = col_idx + idx_condensed
            memmap_distances[i, j] = memmap_distances[j, i] = item
        notify(
            "Setting similarities matrix for index {} done in {:.5f} seconds",
            index,
            time.time() - startt,
            end="\r",
        )
    notify("Setting similarities completed")

    pool.close()
    pool.join()

    notify(
        "Time taken to compare all pairs parallely is {:.5f} seconds ",
        time.time() - start_initial,
    )
    return np.memmap(filename, dtype=np.float64, shape=shape)


def make2d(splicing_tidy, index='cell_id', values='scaled_z', columns='geneR1A_uniq'):
    data2d = splicing_tidy.pivot(index=index, values=values, columns=columns)
    return data2d


def compute_distances_df(splicing2d, n_jobs):
    dists = distances_parallel(splicing2d, n_jobs=n_jobs)
    dists_df = pd.DataFrame(dists, index=splicing2d.index, columns=splicing2d.index)
    return dists_df
# Out:
# Overwriting splicing_utils.py

# %% [markdown]
# ## import `splicing_utils` to process splicing

# %%
import splicing_utils

# %% [markdown]
# ## Read h5ad

# %%
h5ad = '/home/olga/Pilot1_Pilot2_filtered_ensembl_id_Aug5.ss2_norm.ann.compartment.allgenes.h5ad'
adata = sc.read(h5ad)
adata
# Out:
# WARNING: Your filename has more than two extensions: ['.ss2_norm', '.ann', '.compartment', '.allgenes', '.h5ad'].
# Only considering the two last: ['.allgenes', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.ss2_norm', '.ann', '.compartment', '.allgenes', '.h5ad'].
# Only considering the two last: ['.allgenes', '.h5ad'].
# AnnData object with n_obs × n_vars = 207016 × 58870
#     obs: '10X_run', 'smartseq2_barcode', 'smartseq2_library_plate', 'smartseq2_sorting_direction', 'smartseq2_sort_order', 'smartseq2_cDNA_Plate', 'cell_id', 'method', 'donor', '10X_replicate', 'sequencer', 'sex', 'tissue', 'smartseq2_well_seq', 'notes', 'smartseq2_sorted_population', '10X_sample', 'anatomical_position', '10X_barcode', 'n_counts', 'n_genes', 'manual_cell_ontology_class', 'manual_annotation', 'doublet_filter', 'compartment', 'batch', 'compartment_pred', 'leiden', 'cluster_id', 'Propagated Annotation', 'Entropy All Methods', 'Entropy kNN Reps', 'Entropy scANVI Reps', 'Entropy SVM Reps', 'Potential Doublets', 'Onclass', 'singlecellNet', 'kNN', 'SVM', 'scANVI', 'compartment_pred_svm', 'manual_cell_ontology_classcollapsed', 'Propagated Annotationcollapsed', 'Onclasscollapsed', 'singlecellNetcollapsed', 'kNNcollapsed', 'SVMcollapsed', 'scANVIcollapsed', 'miscompartmentalized', 'log_n_counts', 'log_n_genes'
#     var: 'feature_types-0-0', 'n_cells-0-0', 'gene_symbol-0-0', 'n_cells-1-0', 'n_cells-0', 'n_cells-1-1', 'feature_types-0-0-0-1', 'gene_symbol-0-0-0-1', 'n_cells-1-0-0-1', 'n_cells-1-0-1', 'n_cells', 'len', 'ensembl_id'
#     obsm: 'X_scvi', 'X_umap'

# %%
adata.obs.tissue.value_counts()
# Out:
# Lung               37320
# Bladder            25976
# Kidney             24237
# Muscle             22247
# Blood              16834
# Thymus             13125
# Lymph_Node         10376
# Small_Intestine     9567
# Vasculature         9213
# Pancreas            8893
# Spleen              8366
# Large_Intestine     8324
# Trachea             8033
# Bone_Marrow         3649
# Skin                 856
# Name: tissue, dtype: int64

# %%
adata.obs.query('tissue == "Pancreas"').sample(10)
# Out:
#                                                         10X_run  \
# AAGTTCGGTGGCCTCA_TSP1_exopancreas2_1        TSP1_exopancreas2_1
# CTATCTATCATGAAAG_TSP1_exopancreas2_3        TSP1_exopancreas2_3
# TATCAGGCAGAAATCA_TSP1_endopancreas_3        TSP1_endopancreas_3
# TCTCCGATCCGCTTAC_TSP1_exopancreas2_2        TSP1_exopancreas2_2
# TGATCTTGTCCACTTC_TSP1_exopancreas2_2        TSP1_exopancreas2_2
# TGTTCTAGTTCCATTT_TSP1_exopancreas2_2        TSP1_exopancreas2_2
# TTACGTTGTCCACGCA_TSP1_exopancreas2_2        TSP1_exopancreas2_2
# B107819_M3_S279.homo.gencode.v30.ERCC.chrM                  nan
# TTCCTCTTCTGAACGT_TSP1_exopancreas2_3        TSP1_exopancreas2_3
# AATTCCTAGAACAGGA_TSP1_exopancreas2_3        TSP1_exopancreas2_3
#
#                                            smartseq2_barcode  \
# AAGTTCGGTGGCCTCA_TSP1_exopancreas2_1                     nan
# CTATCTATCATGAAAG_TSP1_exopancreas2_3                     nan
# TATCAGGCAGAAATCA_TSP1_endopancreas_3                     nan
# TCTCCGATCCGCTTAC_TSP1_exopancreas2_2                     nan
# TGATCTTGTCCACTTC_TSP1_exopancreas2_2                     nan
# TGTTCTAGTTCCATTT_TSP1_exopancreas2_2                     nan
# TTACGTTGTCCACGCA_TSP1_exopancreas2_2                     nan
# B107819_M3_S279.homo.gencode.v30.ERCC.chrM               BC1
# TTCCTCTTCTGAACGT_TSP1_exopancreas2_3                     nan
# AATTCCTAGAACAGGA_TSP1_exopancreas2_3                     nan
#
#                                            smartseq2_library_plate  \
# AAGTTCGGTGGCCTCA_TSP1_exopancreas2_1                           nan
# CTATCTATCATGAAAG_TSP1_exopancreas2_3                           nan
# TATCAGGCAGAAATCA_TSP1_endopancreas_3                           nan
# TCTCCGATCCGCTTAC_TSP1_exopancreas2_2                           nan
# TGATCTTGTCCACTTC_TSP1_exopancreas2_2                           nan
# TGTTCTAGTTCCATTT_TSP1_exopancreas2_2                           nan
# TTACGTTGTCCACGCA_TSP1_exopancreas2_2                           nan
# B107819_M3_S279.homo.gencode.v30.ERCC.chrM             B107819Blue
# TTCCTCTTCTGAACGT_TSP1_exopancreas2_3                           nan
# AATTCCTAGAACAGGA_TSP1_exopancreas2_3                           nan
#
#                                            smartseq2_sorting_direction  \
# AAGTTCGGTGGCCTCA_TSP1_exopancreas2_1                               nan
# CTATCTATCATGAAAG_TSP1_exopancreas2_3                               nan
# TATCAGGCAGAAATCA_TSP1_endopancreas_3                               nan
# TCTCCGATCCGCTTAC_TSP1_exopancreas2_2                               nan
# TGATCTTGTCCACTTC_TSP1_exopancreas2_2                               nan
# TGTTCTAGTTCCATTT_TSP1_exopancreas2_2                               nan
# TTACGTTGTCCACGCA_TSP1_exopancreas2_2                               nan
# B107819_M3_S279.homo.gencode.v30.ERCC.chrM                         Row
# TTCCTCTTCTGAACGT_TSP1_exopancreas2_3                               nan
# AATTCCTAGAACAGGA_TSP1_exopancreas2_3                               nan
#
#                                            smartseq2_sort_order  \
# AAGTTCGGTGGCCTCA_TSP1_exopancreas2_1                          2
# CTATCTATCATGAAAG_TSP1_exopancreas2_3                          2
# TATCAGGCAGAAATCA_TSP1_endopancreas_3                        nan
# TCTCCGATCCGCTTAC_TSP1_exopancreas2_2                          2
# TGATCTTGTCCACTTC_TSP1_exopancreas2_2                          2
# TGTTCTAGTTCCATTT_TSP1_exopancreas2_2                          2
# TTACGTTGTCCACGCA_TSP1_exopancreas2_2                          2
# B107819_M3_S279.homo.gencode.v30.ERCC.chrM              Plate 3
# TTCCTCTTCTGAACGT_TSP1_exopancreas2_3                          2
# AATTCCTAGAACAGGA_TSP1_exopancreas2_3                          2
#
#                                            smartseq2_cDNA_Plate  \
# AAGTTCGGTGGCCTCA_TSP1_exopancreas2_1                        nan
# CTATCTATCATGAAAG_TSP1_exopancreas2_3                        nan
# TATCAGGCAGAAATCA_TSP1_endopancreas_3                        nan
# TCTCCGATCCGCTTAC_TSP1_exopancreas2_2                        nan
# TGATCTTGTCCACTTC_TSP1_exopancreas2_2                        nan
# TGTTCTAGTTCCATTT_TSP1_exopancreas2_2                        nan
# TTACGTTGTCCACGCA_TSP1_exopancreas2_2                        nan
# B107819_M3_S279.homo.gencode.v30.ERCC.chrM              B107819
# TTCCTCTTCTGAACGT_TSP1_exopancreas2_3                        nan
# AATTCCTAGAACAGGA_TSP1_exopancreas2_3                        nan
#
#                                                                                cell_id  \
# AAGTTCGGTGGCCTCA_TSP1_exopancreas2_1              AAGTTCGGTGGCCTCA_TSP1_exopancreas2_1
# CTATCTATCATGAAAG_TSP1_exopancreas2_3              CTATCTATCATGAAAG_TSP1_exopancreas2_3
# TATCAGGCAGAAATCA_TSP1_endopancreas_3              TATCAGGCAGAAATCA_TSP1_endopancreas_3
# TCTCCGATCCGCTTAC_TSP1_exopancreas2_2              TCTCCGATCCGCTTAC_TSP1_exopancreas2_2
# TGATCTTGTCCACTTC_TSP1_exopancreas2_2              TGATCTTGTCCACTTC_TSP1_exopancreas2_2
# TGTTCTAGTTCCATTT_TSP1_exopancreas2_2              TGTTCTAGTTCCATTT_TSP1_exopancreas2_2
# TTACGTTGTCCACGCA_TSP1_exopancreas2_2              TTACGTTGTCCACGCA_TSP1_exopancreas2_2
# B107819_M3_S279.homo.gencode.v30.ERCC.chrM  B107819_M3_S279.homo.gencode.v30.ERCC.chrM
# TTCCTCTTCTGAACGT_TSP1_exopancreas2_3              TTCCTCTTCTGAACGT_TSP1_exopancreas2_3
# AATTCCTAGAACAGGA_TSP1_exopancreas2_3              AATTCCTAGAACAGGA_TSP1_exopancreas2_3
#
#                                                method donor 10X_replicate  \
# AAGTTCGGTGGCCTCA_TSP1_exopancreas2_1              10X  TSP1             1
# CTATCTATCATGAAAG_TSP1_exopancreas2_3              10X  TSP1             3
# TATCAGGCAGAAATCA_TSP1_endopancreas_3              10X  TSP1             3
# TCTCCGATCCGCTTAC_TSP1_exopancreas2_2              10X  TSP1             2
# TGATCTTGTCCACTTC_TSP1_exopancreas2_2              10X  TSP1             2
# TGTTCTAGTTCCATTT_TSP1_exopancreas2_2              10X  TSP1             2
# TTACGTTGTCCACGCA_TSP1_exopancreas2_2              10X  TSP1             2
# B107819_M3_S279.homo.gencode.v30.ERCC.chrM  smartseq2  TSP1           nan
# TTCCTCTTCTGAACGT_TSP1_exopancreas2_3              10X  TSP1             3
# AATTCCTAGAACAGGA_TSP1_exopancreas2_3              10X  TSP1             3
#
#                                             ...  \
# AAGTTCGGTGGCCTCA_TSP1_exopancreas2_1        ...
# CTATCTATCATGAAAG_TSP1_exopancreas2_3        ...
# TATCAGGCAGAAATCA_TSP1_endopancreas_3        ...
# TCTCCGATCCGCTTAC_TSP1_exopancreas2_2        ...
# TGATCTTGTCCACTTC_TSP1_exopancreas2_2        ...
# TGTTCTAGTTCCATTT_TSP1_exopancreas2_2        ...
# TTACGTTGTCCACGCA_TSP1_exopancreas2_2        ...
# B107819_M3_S279.homo.gencode.v30.ERCC.chrM  ...
# TTCCTCTTCTGAACGT_TSP1_exopancreas2_3        ...
# AATTCCTAGAACAGGA_TSP1_exopancreas2_3        ...
#
#                                            manual_cell_ontology_classcollapsed  \
# AAGTTCGGTGGCCTCA_TSP1_exopancreas2_1                                unassigned
# CTATCTATCATGAAAG_TSP1_exopancreas2_3                    pancreatic ductal cell
# TATCAGGCAGAAATCA_TSP1_endopancreas_3                                unassigned
# TCTCCGATCCGCTTAC_TSP1_exopancreas2_2                    pancreatic acinar cell
# TGATCTTGTCCACTTC_TSP1_exopancreas2_2                    pancreatic acinar cell
# TGTTCTAGTTCCATTT_TSP1_exopancreas2_2                    pancreatic acinar cell
# TTACGTTGTCCACGCA_TSP1_exopancreas2_2                                unassigned
# B107819_M3_S279.homo.gencode.v30.ERCC.chrM                          unassigned
# TTCCTCTTCTGAACGT_TSP1_exopancreas2_3                                unassigned
# AATTCCTAGAACAGGA_TSP1_exopancreas2_3                                unassigned
#
#                                            Propagated Annotationcollapsed  \
# AAGTTCGGTGGCCTCA_TSP1_exopancreas2_1               pancreatic acinar cell
# CTATCTATCATGAAAG_TSP1_exopancreas2_3               pancreatic ductal cell
# TATCAGGCAGAAATCA_TSP1_endopancreas_3               pancreatic acinar cell
# TCTCCGATCCGCTTAC_TSP1_exopancreas2_2               pancreatic acinar cell
# TGATCTTGTCCACTTC_TSP1_exopancreas2_2               pancreatic acinar cell
# TGTTCTAGTTCCATTT_TSP1_exopancreas2_2               pancreatic acinar cell
# TTACGTTGTCCACGCA_TSP1_exopancreas2_2               pancreatic acinar cell
# B107819_M3_S279.homo.gencode.v30.ERCC.chrM         pancreatic acinar cell
# TTCCTCTTCTGAACGT_TSP1_exopancreas2_3               pancreatic acinar cell
# AATTCCTAGAACAGGA_TSP1_exopancreas2_3               pancreatic acinar cell
#
#                                                   Onclasscollapsed  \
# AAGTTCGGTGGCCTCA_TSP1_exopancreas2_1        pancreatic acinar cell
# CTATCTATCATGAAAG_TSP1_exopancreas2_3        pancreatic ductal cell
# TATCAGGCAGAAATCA_TSP1_endopancreas_3        pancreatic acinar cell
# TCTCCGATCCGCTTAC_TSP1_exopancreas2_2        pancreatic acinar cell
# TGATCTTGTCCACTTC_TSP1_exopancreas2_2        pancreatic acinar cell
# TGTTCTAGTTCCATTT_TSP1_exopancreas2_2        pancreatic acinar cell
# TTACGTTGTCCACGCA_TSP1_exopancreas2_2        pancreatic acinar cell
# B107819_M3_S279.homo.gencode.v30.ERCC.chrM  pancreatic acinar cell
# TTCCTCTTCTGAACGT_TSP1_exopancreas2_3        pancreatic acinar cell
# AATTCCTAGAACAGGA_TSP1_exopancreas2_3                          cell
#
#                                             singlecellNetcollapsed  \
# AAGTTCGGTGGCCTCA_TSP1_exopancreas2_1        pancreatic acinar cell
# CTATCTATCATGAAAG_TSP1_exopancreas2_3        pancreatic ductal cell
# TATCAGGCAGAAATCA_TSP1_endopancreas_3        pancreatic acinar cell
# TCTCCGATCCGCTTAC_TSP1_exopancreas2_2        pancreatic acinar cell
# TGATCTTGTCCACTTC_TSP1_exopancreas2_2        pancreatic acinar cell
# TGTTCTAGTTCCATTT_TSP1_exopancreas2_2        pancreatic acinar cell
# TTACGTTGTCCACGCA_TSP1_exopancreas2_2        pancreatic acinar cell
# B107819_M3_S279.homo.gencode.v30.ERCC.chrM  pancreatic acinar cell
# TTCCTCTTCTGAACGT_TSP1_exopancreas2_3        pancreatic acinar cell
# AATTCCTAGAACAGGA_TSP1_exopancreas2_3        pancreatic acinar cell
#
#                                                       kNNcollapsed  \
# AAGTTCGGTGGCCTCA_TSP1_exopancreas2_1        pancreatic acinar cell
# CTATCTATCATGAAAG_TSP1_exopancreas2_3        pancreatic ductal cell
# TATCAGGCAGAAATCA_TSP1_endopancreas_3        pancreatic acinar cell
# TCTCCGATCCGCTTAC_TSP1_exopancreas2_2        pancreatic acinar cell
# TGATCTTGTCCACTTC_TSP1_exopancreas2_2        pancreatic acinar cell
# TGTTCTAGTTCCATTT_TSP1_exopancreas2_2        pancreatic acinar cell
# TTACGTTGTCCACGCA_TSP1_exopancreas2_2        pancreatic acinar cell
# B107819_M3_S279.homo.gencode.v30.ERCC.chrM  pancreatic acinar cell
# TTCCTCTTCTGAACGT_TSP1_exopancreas2_3        pancreatic acinar cell
# AATTCCTAGAACAGGA_TSP1_exopancreas2_3        pancreatic acinar cell
#
#                                                       SVMcollapsed  \
# AAGTTCGGTGGCCTCA_TSP1_exopancreas2_1        pancreatic acinar cell
# CTATCTATCATGAAAG_TSP1_exopancreas2_3        pancreatic ductal cell
# TATCAGGCAGAAATCA_TSP1_endopancreas_3        pancreatic acinar cell
# TCTCCGATCCGCTTAC_TSP1_exopancreas2_2        pancreatic acinar cell
# TGATCTTGTCCACTTC_TSP1_exopancreas2_2        pancreatic acinar cell
# TGTTCTAGTTCCATTT_TSP1_exopancreas2_2        pancreatic acinar cell
# TTACGTTGTCCACGCA_TSP1_exopancreas2_2        pancreatic acinar cell
# B107819_M3_S279.homo.gencode.v30.ERCC.chrM  pancreatic acinar cell
# TTCCTCTTCTGAACGT_TSP1_exopancreas2_3        pancreatic acinar cell
# AATTCCTAGAACAGGA_TSP1_exopancreas2_3        pancreatic acinar cell
#
#                                                    scANVIcollapsed  \
# AAGTTCGGTGGCCTCA_TSP1_exopancreas2_1        pancreatic acinar cell
# CTATCTATCATGAAAG_TSP1_exopancreas2_3        pancreatic ductal cell
# TATCAGGCAGAAATCA_TSP1_endopancreas_3        pancreatic acinar cell
# TCTCCGATCCGCTTAC_TSP1_exopancreas2_2                    macrophage
# TGATCTTGTCCACTTC_TSP1_exopancreas2_2        pancreatic acinar cell
# TGTTCTAGTTCCATTT_TSP1_exopancreas2_2        pancreatic acinar cell
# TTACGTTGTCCACGCA_TSP1_exopancreas2_2        pancreatic acinar cell
# B107819_M3_S279.homo.gencode.v30.ERCC.chrM  pancreatic acinar cell
# TTCCTCTTCTGAACGT_TSP1_exopancreas2_3        pancreatic acinar cell
# AATTCCTAGAACAGGA_TSP1_exopancreas2_3        pancreatic acinar cell
#
#                                            miscompartmentalized log_n_counts  \
# AAGTTCGGTGGCCTCA_TSP1_exopancreas2_1                      False     9.534307
# CTATCTATCATGAAAG_TSP1_exopancreas2_3                      False     8.725994
# TATCAGGCAGAAATCA_TSP1_endopancreas_3                      False     8.073714
# TCTCCGATCCGCTTAC_TSP1_exopancreas2_2                      False    11.832397
# TGATCTTGTCCACTTC_TSP1_exopancreas2_2                      False     9.942948
# TGTTCTAGTTCCATTT_TSP1_exopancreas2_2                      False    10.010547
# TTACGTTGTCCACGCA_TSP1_exopancreas2_2                      False    10.582764
# B107819_M3_S279.homo.gencode.v30.ERCC.chrM                False    14.955721
# TTCCTCTTCTGAACGT_TSP1_exopancreas2_3                      False     8.410499
# AATTCCTAGAACAGGA_TSP1_exopancreas2_3                      False     8.223895
#
#                                             log_n_genes
# AAGTTCGGTGGCCTCA_TSP1_exopancreas2_1           7.374002
# CTATCTATCATGAAAG_TSP1_exopancreas2_3           7.484930
# TATCAGGCAGAAATCA_TSP1_endopancreas_3           5.846439
# TCTCCGATCCGCTTAC_TSP1_exopancreas2_2           8.881975
# TGATCTTGTCCACTTC_TSP1_exopancreas2_2           7.709757
# TGTTCTAGTTCCATTT_TSP1_exopancreas2_2           7.740664
# TTACGTTGTCCACGCA_TSP1_exopancreas2_2           8.433159
# B107819_M3_S279.homo.gencode.v30.ERCC.chrM     8.367997
# TTCCTCTTCTGAACGT_TSP1_exopancreas2_3           6.416732
# AATTCCTAGAACAGGA_TSP1_exopancreas2_3           5.598422
#
# [10 rows x 51 columns]

# %%
adata.obs.head()
# Out:
#                                     10X_run smartseq2_barcode  \
# AAACCCAAGTTGTCGT_TSP1_blood_2  TSP1_blood_2               nan
# AAACGAAAGCCGTTAT_TSP1_blood_2  TSP1_blood_2               nan
# AAAGGATAGTGTTGTC_TSP1_blood_2  TSP1_blood_2               nan
# AAAGGGCAGGAACTAT_TSP1_blood_2  TSP1_blood_2               nan
# AAAGGGCCAACCAACT_TSP1_blood_2  TSP1_blood_2               nan
#
#                               smartseq2_library_plate  \
# AAACCCAAGTTGTCGT_TSP1_blood_2                     nan
# AAACGAAAGCCGTTAT_TSP1_blood_2                     nan
# AAAGGATAGTGTTGTC_TSP1_blood_2                     nan
# AAAGGGCAGGAACTAT_TSP1_blood_2                     nan
# AAAGGGCCAACCAACT_TSP1_blood_2                     nan
#
#                               smartseq2_sorting_direction  \
# AAACCCAAGTTGTCGT_TSP1_blood_2                         nan
# AAACGAAAGCCGTTAT_TSP1_blood_2                         nan
# AAAGGATAGTGTTGTC_TSP1_blood_2                         nan
# AAAGGGCAGGAACTAT_TSP1_blood_2                         nan
# AAAGGGCCAACCAACT_TSP1_blood_2                         nan
#
#                               smartseq2_sort_order smartseq2_cDNA_Plate  \
# AAACCCAAGTTGTCGT_TSP1_blood_2                  nan                  nan
# AAACGAAAGCCGTTAT_TSP1_blood_2                  nan                  nan
# AAAGGATAGTGTTGTC_TSP1_blood_2                  nan                  nan
# AAAGGGCAGGAACTAT_TSP1_blood_2                  nan                  nan
# AAAGGGCCAACCAACT_TSP1_blood_2                  nan                  nan
#
#                                                      cell_id method donor  \
# AAACCCAAGTTGTCGT_TSP1_blood_2  AAACCCAAGTTGTCGT_TSP1_blood_2    10X  TSP1
# AAACGAAAGCCGTTAT_TSP1_blood_2  AAACGAAAGCCGTTAT_TSP1_blood_2    10X  TSP1
# AAAGGATAGTGTTGTC_TSP1_blood_2  AAAGGATAGTGTTGTC_TSP1_blood_2    10X  TSP1
# AAAGGGCAGGAACTAT_TSP1_blood_2  AAAGGGCAGGAACTAT_TSP1_blood_2    10X  TSP1
# AAAGGGCCAACCAACT_TSP1_blood_2  AAAGGGCCAACCAACT_TSP1_blood_2    10X  TSP1
#
#                               10X_replicate  ...  \
# AAACCCAAGTTGTCGT_TSP1_blood_2             2  ...
# AAACGAAAGCCGTTAT_TSP1_blood_2             2  ...
# AAAGGATAGTGTTGTC_TSP1_blood_2             2  ...
# AAAGGGCAGGAACTAT_TSP1_blood_2             2  ...
# AAAGGGCCAACCAACT_TSP1_blood_2             2  ...
#
#                               manual_cell_ontology_classcollapsed  \
# AAACCCAAGTTGTCGT_TSP1_blood_2                          unassigned
# AAACGAAAGCCGTTAT_TSP1_blood_2                          unassigned
# AAAGGATAGTGTTGTC_TSP1_blood_2                          unassigned
# AAAGGGCAGGAACTAT_TSP1_blood_2                          unassigned
# AAAGGGCCAACCAACT_TSP1_blood_2                          unassigned
#
#                               Propagated Annotationcollapsed  \
# AAACCCAAGTTGTCGT_TSP1_blood_2                         T cell
# AAACGAAAGCCGTTAT_TSP1_blood_2                         T cell
# AAAGGATAGTGTTGTC_TSP1_blood_2                         T cell
# AAAGGGCAGGAACTAT_TSP1_blood_2             classical monocyte
# AAAGGGCCAACCAACT_TSP1_blood_2             classical monocyte
#
#                                  Onclasscollapsed singlecellNetcollapsed  \
# AAACCCAAGTTGTCGT_TSP1_blood_2              T cell                 T cell
# AAACGAAAGCCGTTAT_TSP1_blood_2              T cell                 T cell
# AAAGGATAGTGTTGTC_TSP1_blood_2              T cell                 T cell
# AAAGGGCAGGAACTAT_TSP1_blood_2  classical monocyte     classical monocyte
# AAAGGGCCAACCAACT_TSP1_blood_2  classical monocyte     classical monocyte
#
#                                      kNNcollapsed        SVMcollapsed  \
# AAACCCAAGTTGTCGT_TSP1_blood_2              T cell              T cell
# AAACGAAAGCCGTTAT_TSP1_blood_2              T cell              T cell
# AAAGGATAGTGTTGTC_TSP1_blood_2              T cell              T cell
# AAAGGGCAGGAACTAT_TSP1_blood_2  classical monocyte  classical monocyte
# AAAGGGCCAACCAACT_TSP1_blood_2  classical monocyte  classical monocyte
#
#                                   scANVIcollapsed miscompartmentalized  \
# AAACCCAAGTTGTCGT_TSP1_blood_2              T cell                False
# AAACGAAAGCCGTTAT_TSP1_blood_2              T cell                False
# AAAGGATAGTGTTGTC_TSP1_blood_2              T cell                False
# AAAGGGCAGGAACTAT_TSP1_blood_2  classical monocyte                False
# AAAGGGCCAACCAACT_TSP1_blood_2  classical monocyte                False
#
#                               log_n_counts  log_n_genes
# AAACCCAAGTTGTCGT_TSP1_blood_2     9.028579     7.628518
# AAACGAAAGCCGTTAT_TSP1_blood_2     8.651199     7.521318
# AAAGGATAGTGTTGTC_TSP1_blood_2     8.994669     7.699842
# AAAGGGCAGGAACTAT_TSP1_blood_2     9.131947     7.930925
# AAAGGGCCAACCAACT_TSP1_blood_2    10.058095     8.454040
#
# [5 rows x 51 columns]

# %%
2+2
# Out:
# 4

# %%
adata.obs.query('donor == "TSP1"').sample(10)
# Out:
#                                                          10X_run  \
# ACGATCAGTACTCGCG_TSP1_bladder_3                   TSP1_bladder_3
# GACAGCCTCTTAGCTT_TSP1_lung_2                         TSP1_lung_2
# B107909_C13_S287.homo.gencode.v30.ERCC.chrM                  nan
# TGATTCTCACTTCAGA_TSP1_bladder_2                   TSP1_bladder_2
# AAGTTCGGTAAGTTGA_TSP1_bladder_3                   TSP1_bladder_3
# GTAGAGGGTGTCACAT_TSP1_lung_3                         TSP1_lung_3
# TCATTCAAGACGAGCT_TSP1_lung_2                         TSP1_lung_2
# GTCATCCGTTCCCAAA_TSP1_lung_3                         TSP1_lung_3
# TCTATCAGTGAGTAGC_TSP1_exopancreas2_3         TSP1_exopancreas2_3
# TTACGCCGTTCTCCTG_TSP1_exopancreas2_1         TSP1_exopancreas2_1
#
#                                             smartseq2_barcode  \
# ACGATCAGTACTCGCG_TSP1_bladder_3                           nan
# GACAGCCTCTTAGCTT_TSP1_lung_2                              nan
# B107909_C13_S287.homo.gencode.v30.ERCC.chrM              BC14
# TGATTCTCACTTCAGA_TSP1_bladder_2                           nan
# AAGTTCGGTAAGTTGA_TSP1_bladder_3                           nan
# GTAGAGGGTGTCACAT_TSP1_lung_3                              nan
# TCATTCAAGACGAGCT_TSP1_lung_2                              nan
# GTCATCCGTTCCCAAA_TSP1_lung_3                              nan
# TCTATCAGTGAGTAGC_TSP1_exopancreas2_3                      nan
# TTACGCCGTTCTCCTG_TSP1_exopancreas2_1                      nan
#
#                                             smartseq2_library_plate  \
# ACGATCAGTACTCGCG_TSP1_bladder_3                                 nan
# GACAGCCTCTTAGCTT_TSP1_lung_2                                    nan
# B107909_C13_S287.homo.gencode.v30.ERCC.chrM             B107909Blue
# TGATTCTCACTTCAGA_TSP1_bladder_2                                 nan
# AAGTTCGGTAAGTTGA_TSP1_bladder_3                                 nan
# GTAGAGGGTGTCACAT_TSP1_lung_3                                    nan
# TCATTCAAGACGAGCT_TSP1_lung_2                                    nan
# GTCATCCGTTCCCAAA_TSP1_lung_3                                    nan
# TCTATCAGTGAGTAGC_TSP1_exopancreas2_3                            nan
# TTACGCCGTTCTCCTG_TSP1_exopancreas2_1                            nan
#
#                                             smartseq2_sorting_direction  \
# ACGATCAGTACTCGCG_TSP1_bladder_3                                     nan
# GACAGCCTCTTAGCTT_TSP1_lung_2                                        nan
# B107909_C13_S287.homo.gencode.v30.ERCC.chrM                         Row
# TGATTCTCACTTCAGA_TSP1_bladder_2                                     nan
# AAGTTCGGTAAGTTGA_TSP1_bladder_3                                     nan
# GTAGAGGGTGTCACAT_TSP1_lung_3                                        nan
# TCATTCAAGACGAGCT_TSP1_lung_2                                        nan
# GTCATCCGTTCCCAAA_TSP1_lung_3                                        nan
# TCTATCAGTGAGTAGC_TSP1_exopancreas2_3                                nan
# TTACGCCGTTCTCCTG_TSP1_exopancreas2_1                                nan
#
#                                             smartseq2_sort_order  \
# ACGATCAGTACTCGCG_TSP1_bladder_3                              nan
# GACAGCCTCTTAGCTT_TSP1_lung_2                                 nan
# B107909_C13_S287.homo.gencode.v30.ERCC.chrM              Plate 4
# TGATTCTCACTTCAGA_TSP1_bladder_2                              nan
# AAGTTCGGTAAGTTGA_TSP1_bladder_3                              nan
# GTAGAGGGTGTCACAT_TSP1_lung_3                                 nan
# TCATTCAAGACGAGCT_TSP1_lung_2                                 nan
# GTCATCCGTTCCCAAA_TSP1_lung_3                                 nan
# TCTATCAGTGAGTAGC_TSP1_exopancreas2_3                           2
# TTACGCCGTTCTCCTG_TSP1_exopancreas2_1                           2
#
#                                             smartseq2_cDNA_Plate  \
# ACGATCAGTACTCGCG_TSP1_bladder_3                              nan
# GACAGCCTCTTAGCTT_TSP1_lung_2                                 nan
# B107909_C13_S287.homo.gencode.v30.ERCC.chrM              B107909
# TGATTCTCACTTCAGA_TSP1_bladder_2                              nan
# AAGTTCGGTAAGTTGA_TSP1_bladder_3                              nan
# GTAGAGGGTGTCACAT_TSP1_lung_3                                 nan
# TCATTCAAGACGAGCT_TSP1_lung_2                                 nan
# GTCATCCGTTCCCAAA_TSP1_lung_3                                 nan
# TCTATCAGTGAGTAGC_TSP1_exopancreas2_3                         nan
# TTACGCCGTTCTCCTG_TSP1_exopancreas2_1                         nan
#
#                                                                                  cell_id  \
# ACGATCAGTACTCGCG_TSP1_bladder_3                          ACGATCAGTACTCGCG_TSP1_bladder_3
# GACAGCCTCTTAGCTT_TSP1_lung_2                                GACAGCCTCTTAGCTT_TSP1_lung_2
# B107909_C13_S287.homo.gencode.v30.ERCC.chrM  B107909_C13_S287.homo.gencode.v30.ERCC.chrM
# TGATTCTCACTTCAGA_TSP1_bladder_2                          TGATTCTCACTTCAGA_TSP1_bladder_2
# AAGTTCGGTAAGTTGA_TSP1_bladder_3                          AAGTTCGGTAAGTTGA_TSP1_bladder_3
# GTAGAGGGTGTCACAT_TSP1_lung_3                                GTAGAGGGTGTCACAT_TSP1_lung_3
# TCATTCAAGACGAGCT_TSP1_lung_2                                TCATTCAAGACGAGCT_TSP1_lung_2
# GTCATCCGTTCCCAAA_TSP1_lung_3                                GTCATCCGTTCCCAAA_TSP1_lung_3
# TCTATCAGTGAGTAGC_TSP1_exopancreas2_3                TCTATCAGTGAGTAGC_TSP1_exopancreas2_3
# TTACGCCGTTCTCCTG_TSP1_exopancreas2_1                TTACGCCGTTCTCCTG_TSP1_exopancreas2_1
#
#                                                 method donor 10X_replicate  \
# ACGATCAGTACTCGCG_TSP1_bladder_3                    10X  TSP1             3
# GACAGCCTCTTAGCTT_TSP1_lung_2                       10X  TSP1             2
# B107909_C13_S287.homo.gencode.v30.ERCC.chrM  smartseq2  TSP1           nan
# TGATTCTCACTTCAGA_TSP1_bladder_2                    10X  TSP1             2
# AAGTTCGGTAAGTTGA_TSP1_bladder_3                    10X  TSP1             3
# GTAGAGGGTGTCACAT_TSP1_lung_3                       10X  TSP1             3
# TCATTCAAGACGAGCT_TSP1_lung_2                       10X  TSP1             2
# GTCATCCGTTCCCAAA_TSP1_lung_3                       10X  TSP1             3
# TCTATCAGTGAGTAGC_TSP1_exopancreas2_3               10X  TSP1             3
# TTACGCCGTTCTCCTG_TSP1_exopancreas2_1               10X  TSP1             1
#
#                                              ...  \
# ACGATCAGTACTCGCG_TSP1_bladder_3              ...
# GACAGCCTCTTAGCTT_TSP1_lung_2                 ...
# B107909_C13_S287.homo.gencode.v30.ERCC.chrM  ...
# TGATTCTCACTTCAGA_TSP1_bladder_2              ...
# AAGTTCGGTAAGTTGA_TSP1_bladder_3              ...
# GTAGAGGGTGTCACAT_TSP1_lung_3                 ...
# TCATTCAAGACGAGCT_TSP1_lung_2                 ...
# GTCATCCGTTCCCAAA_TSP1_lung_3                 ...
# TCTATCAGTGAGTAGC_TSP1_exopancreas2_3         ...
# TTACGCCGTTCTCCTG_TSP1_exopancreas2_1         ...
#
#                                             manual_cell_ontology_classcollapsed  \
# ACGATCAGTACTCGCG_TSP1_bladder_3                                mesenchymal cell
# GACAGCCTCTTAGCTT_TSP1_lung_2                                           basophil
# B107909_C13_S287.homo.gencode.v30.ERCC.chrM                          unassigned
# TGATTCTCACTTCAGA_TSP1_bladder_2                              smooth muscle cell
# AAGTTCGGTAAGTTGA_TSP1_bladder_3                                      macrophage
# GTAGAGGGTGTCACAT_TSP1_lung_3                                         unassigned
# TCATTCAAGACGAGCT_TSP1_lung_2                             non-classical monocyte
# GTCATCCGTTCCCAAA_TSP1_lung_3                                         unassigned
# TCTATCAGTGAGTAGC_TSP1_exopancreas2_3                     pancreatic acinar cell
# TTACGCCGTTCTCCTG_TSP1_exopancreas2_1                                 unassigned
#
#                                             Propagated Annotationcollapsed  \
# ACGATCAGTACTCGCG_TSP1_bladder_3                           mesenchymal cell
# GACAGCCTCTTAGCTT_TSP1_lung_2                                      basophil
# B107909_C13_S287.homo.gencode.v30.ERCC.chrM                     macrophage
# TGATTCTCACTTCAGA_TSP1_bladder_2                         smooth muscle cell
# AAGTTCGGTAAGTTGA_TSP1_bladder_3                                 macrophage
# GTAGAGGGTGTCACAT_TSP1_lung_3                                    macrophage
# TCATTCAAGACGAGCT_TSP1_lung_2                        non-classical monocyte
# GTCATCCGTTCCCAAA_TSP1_lung_3                                    macrophage
# TCTATCAGTGAGTAGC_TSP1_exopancreas2_3                pancreatic acinar cell
# TTACGCCGTTCTCCTG_TSP1_exopancreas2_1                pancreatic ductal cell
#
#                                                    Onclasscollapsed  \
# ACGATCAGTACTCGCG_TSP1_bladder_3                          fibroblast
# GACAGCCTCTTAGCTT_TSP1_lung_2                               basophil
# B107909_C13_S287.homo.gencode.v30.ERCC.chrM              macrophage
# TGATTCTCACTTCAGA_TSP1_bladder_2                  smooth muscle cell
# AAGTTCGGTAAGTTGA_TSP1_bladder_3                          macrophage
# GTAGAGGGTGTCACAT_TSP1_lung_3                             macrophage
# TCATTCAAGACGAGCT_TSP1_lung_2                 non-classical monocyte
# GTCATCCGTTCCCAAA_TSP1_lung_3                             macrophage
# TCTATCAGTGAGTAGC_TSP1_exopancreas2_3         pancreatic acinar cell
# TTACGCCGTTCTCCTG_TSP1_exopancreas2_1         pancreatic acinar cell
#
#                                              singlecellNetcollapsed  \
# ACGATCAGTACTCGCG_TSP1_bladder_3                    mesenchymal cell
# GACAGCCTCTTAGCTT_TSP1_lung_2                               basophil
# B107909_C13_S287.homo.gencode.v30.ERCC.chrM              macrophage
# TGATTCTCACTTCAGA_TSP1_bladder_2                  smooth muscle cell
# AAGTTCGGTAAGTTGA_TSP1_bladder_3                          macrophage
# GTAGAGGGTGTCACAT_TSP1_lung_3                             macrophage
# TCATTCAAGACGAGCT_TSP1_lung_2                 non-classical monocyte
# GTCATCCGTTCCCAAA_TSP1_lung_3                             macrophage
# TCTATCAGTGAGTAGC_TSP1_exopancreas2_3         pancreatic acinar cell
# TTACGCCGTTCTCCTG_TSP1_exopancreas2_1         pancreatic ductal cell
#
#                                                        kNNcollapsed  \
# ACGATCAGTACTCGCG_TSP1_bladder_3               mesenchymal stem cell
# GACAGCCTCTTAGCTT_TSP1_lung_2                               basophil
# B107909_C13_S287.homo.gencode.v30.ERCC.chrM              macrophage
# TGATTCTCACTTCAGA_TSP1_bladder_2                  smooth muscle cell
# AAGTTCGGTAAGTTGA_TSP1_bladder_3                          macrophage
# GTAGAGGGTGTCACAT_TSP1_lung_3                             macrophage
# TCATTCAAGACGAGCT_TSP1_lung_2                 non-classical monocyte
# GTCATCCGTTCCCAAA_TSP1_lung_3                             macrophage
# TCTATCAGTGAGTAGC_TSP1_exopancreas2_3         pancreatic acinar cell
# TTACGCCGTTCTCCTG_TSP1_exopancreas2_1         pancreatic acinar cell
#
#                                                        SVMcollapsed  \
# ACGATCAGTACTCGCG_TSP1_bladder_3                    mesenchymal cell
# GACAGCCTCTTAGCTT_TSP1_lung_2                               basophil
# B107909_C13_S287.homo.gencode.v30.ERCC.chrM              macrophage
# TGATTCTCACTTCAGA_TSP1_bladder_2                  smooth muscle cell
# AAGTTCGGTAAGTTGA_TSP1_bladder_3                          macrophage
# GTAGAGGGTGTCACAT_TSP1_lung_3                             macrophage
# TCATTCAAGACGAGCT_TSP1_lung_2                 non-classical monocyte
# GTCATCCGTTCCCAAA_TSP1_lung_3                             macrophage
# TCTATCAGTGAGTAGC_TSP1_exopancreas2_3         pancreatic acinar cell
# TTACGCCGTTCTCCTG_TSP1_exopancreas2_1         pancreatic acinar cell
#
#                                                     scANVIcollapsed  \
# ACGATCAGTACTCGCG_TSP1_bladder_3               mesenchymal stem cell
# GACAGCCTCTTAGCTT_TSP1_lung_2                               basophil
# B107909_C13_S287.homo.gencode.v30.ERCC.chrM              macrophage
# TGATTCTCACTTCAGA_TSP1_bladder_2                  smooth muscle cell
# AAGTTCGGTAAGTTGA_TSP1_bladder_3                          macrophage
# GTAGAGGGTGTCACAT_TSP1_lung_3                             macrophage
# TCATTCAAGACGAGCT_TSP1_lung_2                 non-classical monocyte
# GTCATCCGTTCCCAAA_TSP1_lung_3                             macrophage
# TCTATCAGTGAGTAGC_TSP1_exopancreas2_3         pancreatic acinar cell
# TTACGCCGTTCTCCTG_TSP1_exopancreas2_1         pancreatic ductal cell
#
#                                             miscompartmentalized log_n_counts  \
# ACGATCAGTACTCGCG_TSP1_bladder_3                            False     9.042749
# GACAGCCTCTTAGCTT_TSP1_lung_2                               False     8.154788
# B107909_C13_S287.homo.gencode.v30.ERCC.chrM                False    13.673645
# TGATTCTCACTTCAGA_TSP1_bladder_2                            False     8.231642
# AAGTTCGGTAAGTTGA_TSP1_bladder_3                            False     8.859790
# GTAGAGGGTGTCACAT_TSP1_lung_3                               False     9.897368
# TCATTCAAGACGAGCT_TSP1_lung_2                               False     8.479283
# GTCATCCGTTCCCAAA_TSP1_lung_3                               False    10.642683
# TCTATCAGTGAGTAGC_TSP1_exopancreas2_3                       False     9.629577
# TTACGCCGTTCTCCTG_TSP1_exopancreas2_1                       False    10.733217
#
#                                              log_n_genes
# ACGATCAGTACTCGCG_TSP1_bladder_3                 7.774436
# GACAGCCTCTTAGCTT_TSP1_lung_2                    6.899723
# B107909_C13_S287.homo.gencode.v30.ERCC.chrM     7.882692
# TGATTCTCACTTCAGA_TSP1_bladder_2                 7.326466
# AAGTTCGGTAAGTTGA_TSP1_bladder_3                 7.719130
# GTAGAGGGTGTCACAT_TSP1_lung_3                    8.196988
# TCATTCAAGACGAGCT_TSP1_lung_2                    7.415175
# GTCATCCGTTCCCAAA_TSP1_lung_3                    8.591558
# TCTATCAGTGAGTAGC_TSP1_exopancreas2_3            7.357556
# TTACGCCGTTCTCCTG_TSP1_exopancreas2_1            8.655737
#
# [10 rows x 51 columns]

# %%
muscle_dists_df.sample(10)
# Out:
# cell                                    TSP1_muscle_1_S13_L00_AAACGAACACTGTTCC  \
# cell
# TSP1_muscle_1_S13_L00_GTCAGCGCAGACGATG                               73.984996
# TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT                               71.374711
# TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT                               76.858856
# TSP1_muscle_3_S15_L00_TCCACCATCAAAGCCT                               79.157764
# TSP1_muscle_1_S13_L00_GAAACCTGTGTTACAC                               70.932553
# TSP1_muscle_2_S14_L00_AACCATGGTCTTGCGG                               81.872599
# TSP1_muscle_3_S15_L00_GTGTGGCCAAATCAGA                               78.336565
# TSP1_muscle_2_S14_L00_GCAGCCATCTGCGATA                               91.539229
# TSP1_muscle_2_S14_L00_GTTGCTCTCGATCCCT                               87.162694
# TSP1_muscle_3_S15_L00_ATCGCCTTCCTTCAGC                               68.776784
#
# cell                                    TSP1_muscle_1_S13_L00_AAAGAACCAACGTATC  \
# cell
# TSP1_muscle_1_S13_L00_GTCAGCGCAGACGATG                               56.859070
# TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT                               73.479676
# TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT                               74.167948
# TSP1_muscle_3_S15_L00_TCCACCATCAAAGCCT                               73.396891
# TSP1_muscle_1_S13_L00_GAAACCTGTGTTACAC                               60.995439
# TSP1_muscle_2_S14_L00_AACCATGGTCTTGCGG                               78.252220
# TSP1_muscle_3_S15_L00_GTGTGGCCAAATCAGA                               77.857195
# TSP1_muscle_2_S14_L00_GCAGCCATCTGCGATA                               97.552942
# TSP1_muscle_2_S14_L00_GTTGCTCTCGATCCCT                               81.939707
# TSP1_muscle_3_S15_L00_ATCGCCTTCCTTCAGC                               70.738041
#
# cell                                    TSP1_muscle_1_S13_L00_AAAGAACTCGTTCTGC  \
# cell
# TSP1_muscle_1_S13_L00_GTCAGCGCAGACGATG                               50.347889
# TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT                               77.696639
# TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT                               88.143214
# TSP1_muscle_3_S15_L00_TCCACCATCAAAGCCT                               89.533109
# TSP1_muscle_1_S13_L00_GAAACCTGTGTTACAC                               70.223257
# TSP1_muscle_2_S14_L00_AACCATGGTCTTGCGG                               87.275514
# TSP1_muscle_3_S15_L00_GTGTGGCCAAATCAGA                               84.910370
# TSP1_muscle_2_S14_L00_GCAGCCATCTGCGATA                              107.102108
# TSP1_muscle_2_S14_L00_GTTGCTCTCGATCCCT                               89.095200
# TSP1_muscle_3_S15_L00_ATCGCCTTCCTTCAGC                               79.665719
#
# cell                                    TSP1_muscle_1_S13_L00_AAAGGGCCAAGACTGG  \
# cell
# TSP1_muscle_1_S13_L00_GTCAGCGCAGACGATG                               65.294851
# TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT                               76.313683
# TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT                               82.938572
# TSP1_muscle_3_S15_L00_TCCACCATCAAAGCCT                               87.174603
# TSP1_muscle_1_S13_L00_GAAACCTGTGTTACAC                               68.707200
# TSP1_muscle_2_S14_L00_AACCATGGTCTTGCGG                               92.678883
# TSP1_muscle_3_S15_L00_GTGTGGCCAAATCAGA                               77.371528
# TSP1_muscle_2_S14_L00_GCAGCCATCTGCGATA                               98.871229
# TSP1_muscle_2_S14_L00_GTTGCTCTCGATCCCT                               93.626840
# TSP1_muscle_3_S15_L00_ATCGCCTTCCTTCAGC                               69.571147
#
# cell                                    TSP1_muscle_1_S13_L00_AAAGTCCCAGCAATTC  \
# cell
# TSP1_muscle_1_S13_L00_GTCAGCGCAGACGATG                               79.361180
# TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT                              130.981381
# TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT                              129.018571
# TSP1_muscle_3_S15_L00_TCCACCATCAAAGCCT                              117.789658
# TSP1_muscle_1_S13_L00_GAAACCTGTGTTACAC                              102.809803
# TSP1_muscle_2_S14_L00_AACCATGGTCTTGCGG                              113.529537
# TSP1_muscle_3_S15_L00_GTGTGGCCAAATCAGA                               96.345100
# TSP1_muscle_2_S14_L00_GCAGCCATCTGCGATA                              113.524603
# TSP1_muscle_2_S14_L00_GTTGCTCTCGATCCCT                              110.841805
# TSP1_muscle_3_S15_L00_ATCGCCTTCCTTCAGC                              114.418816
#
# cell                                    TSP1_muscle_1_S13_L00_AAATGGAAGCAGATAT  \
# cell
# TSP1_muscle_1_S13_L00_GTCAGCGCAGACGATG                               56.490799
# TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT                               48.568372
# TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT                               65.702029
# TSP1_muscle_3_S15_L00_TCCACCATCAAAGCCT                              107.376104
# TSP1_muscle_1_S13_L00_GAAACCTGTGTTACAC                               60.410976
# TSP1_muscle_2_S14_L00_AACCATGGTCTTGCGG                              102.777397
# TSP1_muscle_3_S15_L00_GTGTGGCCAAATCAGA                               66.726952
# TSP1_muscle_2_S14_L00_GCAGCCATCTGCGATA                               68.956813
# TSP1_muscle_2_S14_L00_GTTGCTCTCGATCCCT                               58.991131
# TSP1_muscle_3_S15_L00_ATCGCCTTCCTTCAGC                               55.705885
#
# cell                                    TSP1_muscle_1_S13_L00_AACACACAGTGATTCC  \
# cell
# TSP1_muscle_1_S13_L00_GTCAGCGCAGACGATG                               96.674650
# TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT                              150.620055
# TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT                              135.521943
# TSP1_muscle_3_S15_L00_TCCACCATCAAAGCCT                              123.276605
# TSP1_muscle_1_S13_L00_GAAACCTGTGTTACAC                              101.057785
# TSP1_muscle_2_S14_L00_AACCATGGTCTTGCGG                              132.799592
# TSP1_muscle_3_S15_L00_GTGTGGCCAAATCAGA                              138.020827
# TSP1_muscle_2_S14_L00_GCAGCCATCTGCGATA                              159.557334
# TSP1_muscle_2_S14_L00_GTTGCTCTCGATCCCT                              129.049723
# TSP1_muscle_3_S15_L00_ATCGCCTTCCTTCAGC                              119.615279
#
# cell                                    TSP1_muscle_1_S13_L00_AACACACCAGCACACC  \
# cell
# TSP1_muscle_1_S13_L00_GTCAGCGCAGACGATG                               60.636079
# TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT                               60.263043
# TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT                               71.814628
# TSP1_muscle_3_S15_L00_TCCACCATCAAAGCCT                               71.713547
# TSP1_muscle_1_S13_L00_GAAACCTGTGTTACAC                               72.489336
# TSP1_muscle_2_S14_L00_AACCATGGTCTTGCGG                               73.691601
# TSP1_muscle_3_S15_L00_GTGTGGCCAAATCAGA                               71.772207
# TSP1_muscle_2_S14_L00_GCAGCCATCTGCGATA                               91.380998
# TSP1_muscle_2_S14_L00_GTTGCTCTCGATCCCT                               78.674081
# TSP1_muscle_3_S15_L00_ATCGCCTTCCTTCAGC                               68.075378
#
# cell                                    TSP1_muscle_1_S13_L00_AACAGGGGTTTACTGG  \
# cell
# TSP1_muscle_1_S13_L00_GTCAGCGCAGACGATG                               53.639780
# TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT                               64.745455
# TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT                               73.448739
# TSP1_muscle_3_S15_L00_TCCACCATCAAAGCCT                               76.292615
# TSP1_muscle_1_S13_L00_GAAACCTGTGTTACAC                               54.294086
# TSP1_muscle_2_S14_L00_AACCATGGTCTTGCGG                               78.520646
# TSP1_muscle_3_S15_L00_GTGTGGCCAAATCAGA                               70.524941
# TSP1_muscle_2_S14_L00_GCAGCCATCTGCGATA                               94.144710
# TSP1_muscle_2_S14_L00_GTTGCTCTCGATCCCT                               75.732754
# TSP1_muscle_3_S15_L00_ATCGCCTTCCTTCAGC                               68.865433
#
# cell                                    TSP1_muscle_1_S13_L00_AACCAACAGACTCTAC  \
# cell
# TSP1_muscle_1_S13_L00_GTCAGCGCAGACGATG                               66.715700
# TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT                               74.240065
# TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT                               75.796421
# TSP1_muscle_3_S15_L00_TCCACCATCAAAGCCT                               82.377699
# TSP1_muscle_1_S13_L00_GAAACCTGTGTTACAC                               64.441952
# TSP1_muscle_2_S14_L00_AACCATGGTCTTGCGG                               82.914519
# TSP1_muscle_3_S15_L00_GTGTGGCCAAATCAGA                               70.256650
# TSP1_muscle_2_S14_L00_GCAGCCATCTGCGATA                               93.969580
# TSP1_muscle_2_S14_L00_GTTGCTCTCGATCCCT                               68.736678
# TSP1_muscle_3_S15_L00_ATCGCCTTCCTTCAGC                               62.145798
#
# cell                                    ...  \
# cell                                    ...
# TSP1_muscle_1_S13_L00_GTCAGCGCAGACGATG  ...
# TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT  ...
# TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT  ...
# TSP1_muscle_3_S15_L00_TCCACCATCAAAGCCT  ...
# TSP1_muscle_1_S13_L00_GAAACCTGTGTTACAC  ...
# TSP1_muscle_2_S14_L00_AACCATGGTCTTGCGG  ...
# TSP1_muscle_3_S15_L00_GTGTGGCCAAATCAGA  ...
# TSP1_muscle_2_S14_L00_GCAGCCATCTGCGATA  ...
# TSP1_muscle_2_S14_L00_GTTGCTCTCGATCCCT  ...
# TSP1_muscle_3_S15_L00_ATCGCCTTCCTTCAGC  ...
#
# cell                                    TSP1_muscle_3_S15_L00_TTTCCTCAGCCTGACC  \
# cell
# TSP1_muscle_1_S13_L00_GTCAGCGCAGACGATG                               77.857214
# TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT                               58.442143
# TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT                               71.807327
# TSP1_muscle_3_S15_L00_TCCACCATCAAAGCCT                               55.177386
# TSP1_muscle_1_S13_L00_GAAACCTGTGTTACAC                               73.329657
# TSP1_muscle_2_S14_L00_AACCATGGTCTTGCGG                               61.454078
# TSP1_muscle_3_S15_L00_GTGTGGCCAAATCAGA                               55.867509
# TSP1_muscle_2_S14_L00_GCAGCCATCTGCGATA                               66.537887
# TSP1_muscle_2_S14_L00_GTTGCTCTCGATCCCT                               63.307452
# TSP1_muscle_3_S15_L00_ATCGCCTTCCTTCAGC                               57.432680
#
# cell                                    TSP1_muscle_3_S15_L00_TTTCCTCAGGCCTTCG  \
# cell
# TSP1_muscle_1_S13_L00_GTCAGCGCAGACGATG                               81.459251
# TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT                               40.114559
# TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT                               66.450427
# TSP1_muscle_3_S15_L00_TCCACCATCAAAGCCT                               61.696675
# TSP1_muscle_1_S13_L00_GAAACCTGTGTTACAC                               66.550786
# TSP1_muscle_2_S14_L00_AACCATGGTCTTGCGG                               63.562904
# TSP1_muscle_3_S15_L00_GTGTGGCCAAATCAGA                               64.408806
# TSP1_muscle_2_S14_L00_GCAGCCATCTGCGATA                               65.983271
# TSP1_muscle_2_S14_L00_GTTGCTCTCGATCCCT                               62.401715
# TSP1_muscle_3_S15_L00_ATCGCCTTCCTTCAGC                               54.829219
#
# cell                                    TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT  \
# cell
# TSP1_muscle_1_S13_L00_GTCAGCGCAGACGATG                               82.929667
# TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT                               67.755901
# TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT                                0.000000
# TSP1_muscle_3_S15_L00_TCCACCATCAAAGCCT                               72.287608
# TSP1_muscle_1_S13_L00_GAAACCTGTGTTACAC                               75.218596
# TSP1_muscle_2_S14_L00_AACCATGGTCTTGCGG                               63.472924
# TSP1_muscle_3_S15_L00_GTGTGGCCAAATCAGA                               70.910607
# TSP1_muscle_2_S14_L00_GCAGCCATCTGCGATA                               75.900989
# TSP1_muscle_2_S14_L00_GTTGCTCTCGATCCCT                               74.037728
# TSP1_muscle_3_S15_L00_ATCGCCTTCCTTCAGC                               62.779731
#
# cell                                    TSP1_muscle_3_S15_L00_TTTCGATAGGTTAAAC  \
# cell
# TSP1_muscle_1_S13_L00_GTCAGCGCAGACGATG                               65.687125
# TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT                               54.713839
# TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT                               70.129591
# TSP1_muscle_3_S15_L00_TCCACCATCAAAGCCT                               59.398536
# TSP1_muscle_1_S13_L00_GAAACCTGTGTTACAC                               67.630781
# TSP1_muscle_2_S14_L00_AACCATGGTCTTGCGG                               73.659259
# TSP1_muscle_3_S15_L00_GTGTGGCCAAATCAGA                               51.140089
# TSP1_muscle_2_S14_L00_GCAGCCATCTGCGATA                               65.812168
# TSP1_muscle_2_S14_L00_GTTGCTCTCGATCCCT                               64.305277
# TSP1_muscle_3_S15_L00_ATCGCCTTCCTTCAGC                               53.550092
#
# cell                                    TSP1_muscle_3_S15_L00_TTTCGATCAAGCTGTT  \
# cell
# TSP1_muscle_1_S13_L00_GTCAGCGCAGACGATG                               74.409688
# TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT                               63.122826
# TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT                               88.237092
# TSP1_muscle_3_S15_L00_TCCACCATCAAAGCCT                               79.702063
# TSP1_muscle_1_S13_L00_GAAACCTGTGTTACAC                               68.292739
# TSP1_muscle_2_S14_L00_AACCATGGTCTTGCGG                               85.643907
# TSP1_muscle_3_S15_L00_GTGTGGCCAAATCAGA                               74.472361
# TSP1_muscle_2_S14_L00_GCAGCCATCTGCGATA                               82.375298
# TSP1_muscle_2_S14_L00_GTTGCTCTCGATCCCT                               73.998019
# TSP1_muscle_3_S15_L00_ATCGCCTTCCTTCAGC                               67.680641
#
# cell                                    TSP1_muscle_3_S15_L00_TTTGACTAGGGTGAAA  \
# cell
# TSP1_muscle_1_S13_L00_GTCAGCGCAGACGATG                               72.805623
# TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT                               43.616137
# TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT                               67.450479
# TSP1_muscle_3_S15_L00_TCCACCATCAAAGCCT                               56.952872
# TSP1_muscle_1_S13_L00_GAAACCTGTGTTACAC                               71.019602
# TSP1_muscle_2_S14_L00_AACCATGGTCTTGCGG                               65.608842
# TSP1_muscle_3_S15_L00_GTGTGGCCAAATCAGA                               57.097166
# TSP1_muscle_2_S14_L00_GCAGCCATCTGCGATA                               82.556336
# TSP1_muscle_2_S14_L00_GTTGCTCTCGATCCCT                               65.257671
# TSP1_muscle_3_S15_L00_ATCGCCTTCCTTCAGC                               53.900937
#
# cell                                    TSP1_muscle_3_S15_L00_TTTGACTCACTGCGAC  \
# cell
# TSP1_muscle_1_S13_L00_GTCAGCGCAGACGATG                               64.922482
# TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT                               55.612712
# TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT                               55.249242
# TSP1_muscle_3_S15_L00_TCCACCATCAAAGCCT                               66.481332
# TSP1_muscle_1_S13_L00_GAAACCTGTGTTACAC                               60.686553
# TSP1_muscle_2_S14_L00_AACCATGGTCTTGCGG                               61.797698
# TSP1_muscle_3_S15_L00_GTGTGGCCAAATCAGA                               56.351425
# TSP1_muscle_2_S14_L00_GCAGCCATCTGCGATA                               69.928229
# TSP1_muscle_2_S14_L00_GTTGCTCTCGATCCCT                               66.247565
# TSP1_muscle_3_S15_L00_ATCGCCTTCCTTCAGC                               55.466669
#
# cell                                    TSP1_muscle_3_S15_L00_TTTGGTTCATTGCCGG  \
# cell
# TSP1_muscle_1_S13_L00_GTCAGCGCAGACGATG                               82.512940
# TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT                               74.754644
# TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT                               61.027060
# TSP1_muscle_3_S15_L00_TCCACCATCAAAGCCT                               70.256005
# TSP1_muscle_1_S13_L00_GAAACCTGTGTTACAC                               70.957494
# TSP1_muscle_2_S14_L00_AACCATGGTCTTGCGG                               61.542284
# TSP1_muscle_3_S15_L00_GTGTGGCCAAATCAGA                               73.434728
# TSP1_muscle_2_S14_L00_GCAGCCATCTGCGATA                               63.720564
# TSP1_muscle_2_S14_L00_GTTGCTCTCGATCCCT                               70.960427
# TSP1_muscle_3_S15_L00_ATCGCCTTCCTTCAGC                               74.531297
#
# cell                                    TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT  \
# cell
# TSP1_muscle_1_S13_L00_GTCAGCGCAGACGATG                               80.461860
# TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT                                0.000000
# TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT                               67.755901
# TSP1_muscle_3_S15_L00_TCCACCATCAAAGCCT                               61.783319
# TSP1_muscle_1_S13_L00_GAAACCTGTGTTACAC                               75.440234
# TSP1_muscle_2_S14_L00_AACCATGGTCTTGCGG                               62.098947
# TSP1_muscle_3_S15_L00_GTGTGGCCAAATCAGA                               56.051420
# TSP1_muscle_2_S14_L00_GCAGCCATCTGCGATA                               69.535907
# TSP1_muscle_2_S14_L00_GTTGCTCTCGATCCCT                               62.677634
# TSP1_muscle_3_S15_L00_ATCGCCTTCCTTCAGC                               56.223628
#
# cell                                    TSP1_muscle_3_S15_L00_TTTGTTGCAACGCATT
# cell
# TSP1_muscle_1_S13_L00_GTCAGCGCAGACGATG                               77.526531
# TSP1_muscle_3_S15_L00_TTTGGTTTCGGCTTCT                               55.982545
# TSP1_muscle_3_S15_L00_TTTCCTCGTGAAGCGT                               56.060856
# TSP1_muscle_3_S15_L00_TCCACCATCAAAGCCT                               64.026333
# TSP1_muscle_1_S13_L00_GAAACCTGTGTTACAC                               63.423610
# TSP1_muscle_2_S14_L00_AACCATGGTCTTGCGG                               64.070853
# TSP1_muscle_3_S15_L00_GTGTGGCCAAATCAGA                               64.153277
# TSP1_muscle_2_S14_L00_GCAGCCATCTGCGATA                               72.825427
# TSP1_muscle_2_S14_L00_GTTGCTCTCGATCCCT                               62.599014
# TSP1_muscle_3_S15_L00_ATCGCCTTCCTTCAGC                               64.487900
#
# [10 rows x 2193 columns]

# %% [markdown]
# # Do all of sapiens

# %% [markdown]
# ## Data folder

# %%
# splicing_folder = '/home/olga/data_sm/splicing/rawdata/rijk_zscore__2020-09-15'
# ! ls -lha $splicing_folder

splicing_folder = '/home/olga/data_sm/splicing/rawdata/rijk_zscore__2020-10-13'
! ls -lha $splicing_folder
# Out:
# total 1.5G
# drwxr-xr-x 2 olga czb 4.0K Oct 13 10:48 .
# drwxr-xr-x 7 olga czb 4.0K Oct 13 10:15 ..
# -rw-r--r-- 1 olga czb 690M Oct 13 10:15 TSP1_10x_nopanc_with_postprocessing_shared_sym_S_0.1_z_0.0_b_5.pq
# -rw-r--r-- 1 olga czb 803M Oct 13 10:14 TSP2_10x_3prime_with_postprocessing_shared_sym_S_0.1_z_0.0_b_5.pq

# %% [markdown]
# ## Read all TS (tabula sapiens) 10x paruqet files

# %%
# %%time
import splicing_utils

dfs = []
for parquet in glob.glob(f"{splicing_folder}/TSP*10x*.pq"):
    print(parquet)
    df = splicing_utils.process_splicing(parquet, method='10x')
    print(df.shape)
    dfs.append(df)
sapiens_splicing_tidy = pd.concat(dfs)
print(sapiens_splicing_tidy.shape)
sapiens_splicing_tidy.head()
# Out:
# /home/olga/data_sm/splicing/rawdata/rijk_zscore__2020-10-13/TSP2_10x_3prime_with_postprocessing_shared_sym_S_0.1_z_0.0_b_5.pq
# (2701021, 101)
# (2701021, 101)
# /home/olga/data_sm/splicing/rawdata/rijk_zscore__2020-10-13/TSP1_10x_nopanc_with_postprocessing_shared_sym_S_0.1_z_0.0_b_5.pq
# (2555970, 101)
# (2555970, 101)
# (5256991, 101)
# CPU times: user 2min 25s, sys: 2min 16s, total: 4min 42s
# Wall time: 3min 14s
#    inc_emp.p   tissue  gene_count_per_cell_filt   juncPosR1A geneR1A_uniq  \
# 0       True  Bladder                      21.0  100526975.0       NDUFB8
# 1       True  Bladder                      25.0  100526975.0       NDUFB8
# 2       True  Bladder                      21.0  100526975.0       NDUFB8
# 3       True    Blood                      23.0  100526975.0       NDUFB8
# 4       True    Blood                       9.0  100526975.0       NDUFB8
#
#     juncPosR1B  numReads                                             cell  \
# 0  100523929.0       1.0  TSP2_Bladder_NA_10X_1_1_S5_L00_CATACAGGTAACATGA
# 1  100523929.0       1.0  TSP2_Bladder_NA_10X_1_1_S5_L00_GCTGCAGCATGAGATA
# 2  100523929.0       1.0  TSP2_Bladder_NA_10X_1_1_S5_L00_ATTACCTAGTTGGCTT
# 3  100523929.0       1.0   TSP2_Blood_NA_10X_1_3_S15_L00_CTCCTCCAGCTAATGA
# 4  100523929.0       1.0   TSP2_Blood_NA_10X_1_3_S15_L00_TTGCTGCGTGAATTAG
#
#                           channel  splice_ann  ... cov_dom_unch z_dom_unch  \
# 0  TSP2_Bladder_NA_10X_1_1_S5_L00       False  ...          NaN        NaN
# 1  TSP2_Bladder_NA_10X_1_1_S5_L00       False  ...          NaN        NaN
# 2  TSP2_Bladder_NA_10X_1_1_S5_L00       False  ...          NaN        NaN
# 3   TSP2_Blood_NA_10X_1_3_S15_L00       False  ...          NaN        NaN
# 4   TSP2_Blood_NA_10X_1_3_S15_L00       False  ...          NaN        NaN
#
#                                             ontology   n.g  scaled_z  \
# 0                   BladderImmunenatural killer cell  21.0  1.273449
# 1                   BladderImmunenatural killer cell  25.0  1.065466
# 2        BladderEpithelialintermediate epitheliocyte  21.0  1.343825
# 3  BloodImmuneCD4-positive, alpha-beta memory T cell  23.0  1.105109
# 4  BloodImmuneCD4-positive, alpha-beta memory T cell   8.0  2.990745
#
#    zcontribA  zcontribB          channel_cleaned      cell_barcode  \
# 0  -2.890378   2.609321  TSP2_Bladder_NA_10X_1_1  CATACAGGTAACATGA
# 1  -2.649075   2.391482  TSP2_Bladder_NA_10X_1_1  GCTGCAGCATGAGATA
# 2  -2.890378   2.609321  TSP2_Bladder_NA_10X_1_1  ATTACCTAGTTGGCTT
# 3  -2.761852   2.493292    TSP2_Blood_NA_10X_1_3  CTCCTCCAGCTAATGA
# 4  -4.682948   4.227583    TSP2_Blood_NA_10X_1_3  TTGCTGCGTGAATTAG
#
#                                     cell_id
# 0  CATACAGGTAACATGA_TSP2_Bladder_NA_10X_1_1
# 1  GCTGCAGCATGAGATA_TSP2_Bladder_NA_10X_1_1
# 2  ATTACCTAGTTGGCTT_TSP2_Bladder_NA_10X_1_1
# 3    CTCCTCCAGCTAATGA_TSP2_Blood_NA_10X_1_3
# 4    TTGCTGCGTGAATTAG_TSP2_Blood_NA_10X_1_3
#
# [5 rows x 101 columns]

# %%
# %%time

sapiens_splicing_2d = splicing_utils.make2d(sapiens_splicing_tidy)
print(sapiens_splicing_2d.shape)
sapiens_splicing_2d.head()
# Out:
# (59367, 1617)
# CPU times: user 5.35 s, sys: 34.7 s, total: 40 s
# Wall time: 40.7 s
# geneR1A_uniq                            A2M  AAMDC  AARSD1  ABCA6  ABI3BP  \
# cell_id
# AAACCCAAGATGTTAG_TSP1_muscle_2          NaN    NaN     NaN    NaN     NaN
# AAACCCAAGCAACAGC_TSP1_blood_3           NaN    NaN     NaN    NaN     NaN
# AAACCCAAGCACTTTG_TSP2_Blood_NA_10X_2_1  NaN    NaN     NaN    NaN     NaN
# AAACCCAAGCATCAAA_TSP2_Blood_NA_10X_1_3  NaN    NaN     NaN    NaN     NaN
# AAACCCAAGCATCAGG_TSP1_lung_3            NaN    NaN     NaN    NaN     NaN
#
# geneR1A_uniq                            AC005062.2  AC006369.2  AC011513.3  \
# cell_id
# AAACCCAAGATGTTAG_TSP1_muscle_2                 NaN         NaN         NaN
# AAACCCAAGCAACAGC_TSP1_blood_3                  NaN         NaN         NaN
# AAACCCAAGCACTTTG_TSP2_Blood_NA_10X_2_1         NaN         NaN         NaN
# AAACCCAAGCATCAAA_TSP2_Blood_NA_10X_1_3         NaN         NaN         NaN
# AAACCCAAGCATCAGG_TSP1_lung_3                   NaN         NaN         NaN
#
# geneR1A_uniq                            AC012146.7  AC013264.2  ...  ZNF706  \
# cell_id                                                         ...
# AAACCCAAGATGTTAG_TSP1_muscle_2                 NaN         NaN  ...     NaN
# AAACCCAAGCAACAGC_TSP1_blood_3                  NaN         NaN  ...     NaN
# AAACCCAAGCACTTTG_TSP2_Blood_NA_10X_2_1         NaN         NaN  ...     NaN
# AAACCCAAGCATCAAA_TSP2_Blood_NA_10X_1_3         NaN         NaN  ...     NaN
# AAACCCAAGCATCAGG_TSP1_lung_3                   NaN         NaN  ...     NaN
#
# geneR1A_uniq                            ZNRF1  ZRSR2  snoU13  uc_338  \
# cell_id
# AAACCCAAGATGTTAG_TSP1_muscle_2            NaN    NaN     NaN     NaN
# AAACCCAAGCAACAGC_TSP1_blood_3             NaN    NaN     NaN     NaN
# AAACCCAAGCACTTTG_TSP2_Blood_NA_10X_2_1    NaN    NaN     NaN     NaN
# AAACCCAAGCATCAAA_TSP2_Blood_NA_10X_1_3    NaN    NaN     NaN     NaN
# AAACCCAAGCATCAGG_TSP1_lung_3              NaN    NaN     NaN     NaN
#
# geneR1A_uniq                            unknown_chr17_68100000  \
# cell_id
# AAACCCAAGATGTTAG_TSP1_muscle_2                             NaN
# AAACCCAAGCAACAGC_TSP1_blood_3                              NaN
# AAACCCAAGCACTTTG_TSP2_Blood_NA_10X_2_1                     NaN
# AAACCCAAGCATCAAA_TSP2_Blood_NA_10X_1_3                     NaN
# AAACCCAAGCATCAGG_TSP1_lung_3                               NaN
#
# geneR1A_uniq                            unknown_chr19_15900000  \
# cell_id
# AAACCCAAGATGTTAG_TSP1_muscle_2                             NaN
# AAACCCAAGCAACAGC_TSP1_blood_3                              NaN
# AAACCCAAGCACTTTG_TSP2_Blood_NA_10X_2_1                     NaN
# AAACCCAAGCATCAAA_TSP2_Blood_NA_10X_1_3                     NaN
# AAACCCAAGCATCAGG_TSP1_lung_3                               NaN
#
# geneR1A_uniq                            unknown_chr2_145700000  \
# cell_id
# AAACCCAAGATGTTAG_TSP1_muscle_2                             NaN
# AAACCCAAGCAACAGC_TSP1_blood_3                              NaN
# AAACCCAAGCACTTTG_TSP2_Blood_NA_10X_2_1                     NaN
# AAACCCAAGCATCAAA_TSP2_Blood_NA_10X_1_3                     NaN
# AAACCCAAGCATCAGG_TSP1_lung_3                               NaN
#
# geneR1A_uniq                            unknown_chr4_73800000  \
# cell_id
# AAACCCAAGATGTTAG_TSP1_muscle_2                            NaN
# AAACCCAAGCAACAGC_TSP1_blood_3                             NaN
# AAACCCAAGCACTTTG_TSP2_Blood_NA_10X_2_1                    NaN
# AAACCCAAGCATCAAA_TSP2_Blood_NA_10X_1_3                    NaN
# AAACCCAAGCATCAGG_TSP1_lung_3                              NaN
#
# geneR1A_uniq                            unknown_chr9_76500000
# cell_id
# AAACCCAAGATGTTAG_TSP1_muscle_2                            NaN
# AAACCCAAGCAACAGC_TSP1_blood_3                             NaN
# AAACCCAAGCACTTTG_TSP2_Blood_NA_10X_2_1                    NaN
# AAACCCAAGCATCAAA_TSP2_Blood_NA_10X_1_3                    NaN
# AAACCCAAGCATCAGG_TSP1_lung_3                              NaN
#
# [5 rows x 1617 columns]

# %% [markdown]
# ## Write concatenated (cell, gene) splicing scores to file

# %%
concatenated_splicing_folder = f'{splicing_folder}/concatenated'
! mkdir -p $concatenated_splicing_folder

# %% [markdown]
# ### Write 2d version first to get started on clustering

# %%
# %%time

sapiens_splicing_2d.to_parquet(f'{concatenated_splicing_folder}/tabula_sapiens_10x_splicing_2d.parquet')
# Out:
# CPU times: user 3.85 s, sys: 502 ms, total: 4.35 s
# Wall time: 4.54 s

# %% [markdown]
# ### Write tall, tidy version

# %%
# %%time

sapiens_splicing_tidy.to_parquet(f'{concatenated_splicing_folder}/tabula_sapiens_10x_splicing_tidy.parquet')
# Out:
# CPU times: user 23.1 s, sys: 6.05 s, total: 29.1 s
# Wall time: 31.3 s
