# %% [markdown]
# # General import functions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
import scanpy as sc
from igraph import *
from MulticoreTSNE import MulticoreTSNE as TSNE #faster TSNE alternative
from anndata import read_h5ad
from anndata import read_csv
sc.logging.print_versions()
# Out:
# scanpy==1.4.4.post1 anndata==0.6.22 umap==0.3.10 numpy==1.17.2 scipy==1.3.1 pandas==0.25.1 scikit-learn==0.21.3 statsmodels==0.10.1 python-igraph==0.7.1 louvain==0.6.1

# %%
pwd
# Out:
# '/Users/angela.pisco/src/sapiens/tabula-sapiens/analysis-scripts'

# %% [markdown]
# # Load the data

# %%
tissue = 'Muscle'

# %%
tiss_facs = read_h5ad('../../data-analysis/pilot/facs/tabula-sapiens-facs-pilot-filtered-Muscle.h5ad')
tiss_droplet = read_h5ad('../../data-analysis/pilot/10X/tabula-sapiens-10X-pilot-filtered-muscle.h5ad')
tiss_facs, tiss_droplet
# Out:
# (AnnData object with n_obs × n_vars = 1272 × 24697
#      obs: 'plate', 'well', 'tissue', 'primary_sort', 'anatomical_position', 'sort_order', 'well_group', 'excluded', 'sort_direction', 'investigator', 'barcode', 'cDNA_prep_person', 'cDNA_dilute', 'library_prep', 'lib_prep_date', 'bead_cleanup', 'BA_nM', 'NovaSeqRun', 'additional_notes', 'n_genes'
#      var: 'n_cells', AnnData object with n_obs × n_vars = 6230 × 21380
#      obs: '10X_plate', 'batch', 'tissue', 'method', 'sex', 'subjectid', 'n_genes'
#      var: 'n_cells')

# %% [markdown]
# # Load the data

# %%
adata

# %%
set(adata.obs['tissue'])

# %% [markdown]
# Filter out cells with less than 200 genes detected and genes expressed in less than 3 cells

# %%
adata

# %% [markdown]
# save the filtered data

# %%
adata.write('/maca-bulk/sapiens/tabula-sapiens-10X-pilot-filtered.h5ad')

# %% [markdown]
# # Annotate the FACS data

# %%
adata = tiss_facs
adata
# Out:
# AnnData object with n_obs × n_vars = 1272 × 24697
#     obs: 'plate', 'well', 'tissue', 'primary_sort', 'anatomical_position', 'sort_order', 'well_group', 'excluded', 'sort_direction', 'investigator', 'barcode', 'cDNA_prep_person', 'cDNA_dilute', 'library_prep', 'lib_prep_date', 'bead_cleanup', 'BA_nM', 'NovaSeqRun', 'additional_notes', 'n_genes'
#     var: 'n_cells'

# %%
igg_genes = adata.var_names[adata.var_names.str.startswith('MT')]
igg_genes
# Out:
# Index(['MT1A', 'MT1B', 'MT1DP', 'MT1E', 'MT1F', 'MT1G', 'MT1H', 'MT1HL1',
#        'MT1IP', 'MT1JP', 'MT1L', 'MT1M', 'MT1X', 'MT2A', 'MT3', 'MT4', 'MTA1',
#        'MTA2', 'MTA3', 'MTAP', 'MTBP', 'MTCH1', 'MTCH2', 'MTCL1', 'MTCP1',
#        'MTDH', 'MTERF1', 'MTERF2', 'MTERF3', 'MTERF4', 'MTF1', 'MTF2', 'MTFMT',
#        'MTFP1', 'MTFR1', 'MTFR1L', 'MTFR2', 'MTG1', 'MTG2', 'MTHFD1',
#        'MTHFD1L', 'MTHFD2', 'MTHFD2L', 'MTHFD2P1', 'MTHFR', 'MTHFS', 'MTHFSD',
#        'MTIF2', 'MTIF3', 'MTL5', 'MTM1', 'MTMR1', 'MTMR10', 'MTMR11', 'MTMR12',
#        'MTMR14', 'MTMR2', 'MTMR3', 'MTMR4', 'MTMR6', 'MTMR7', 'MTMR8', 'MTMR9',
#        'MTMR9LP', 'MTNR1A', 'MTNR1B', 'MTO1', 'MTOR', 'MTOR-AS1', 'MTPAP',
#        'MTR', 'MTRF1', 'MTRF1L', 'MTRNR2L1', 'MTRNR2L10', 'MTRNR2L2',
#        'MTRNR2L3', 'MTRNR2L4', 'MTRNR2L5', 'MTRNR2L6', 'MTRNR2L7', 'MTRNR2L8',
#        'MTRNR2L9', 'MTRR', 'MTSS1', 'MTSS1L', 'MTTP', 'MTURN', 'MTUS1',
#        'MTUS2', 'MTUS2-AS1', 'MTVR2', 'MTX1', 'MTX2', 'MTX3'],
#       dtype='object', name='index')

# %%
ercc_genes = adata.var_names[adata.var_names.str.startswith('ERCC-')]
ercc_genes
# Out:
# Index(['ERCC-00002', 'ERCC-00003', 'ERCC-00004', 'ERCC-00009', 'ERCC-00012',
#        'ERCC-00013', 'ERCC-00014', 'ERCC-00019', 'ERCC-00022', 'ERCC-00024',
#        'ERCC-00025', 'ERCC-00028', 'ERCC-00031', 'ERCC-00033', 'ERCC-00034',
#        'ERCC-00035', 'ERCC-00039', 'ERCC-00042', 'ERCC-00043', 'ERCC-00044',
#        'ERCC-00046', 'ERCC-00051', 'ERCC-00053', 'ERCC-00054', 'ERCC-00058',
#        'ERCC-00059', 'ERCC-00060', 'ERCC-00062', 'ERCC-00067', 'ERCC-00069',
#        'ERCC-00071', 'ERCC-00073', 'ERCC-00074', 'ERCC-00076', 'ERCC-00077',
#        'ERCC-00078', 'ERCC-00079', 'ERCC-00084', 'ERCC-00085', 'ERCC-00092',
#        'ERCC-00095', 'ERCC-00096', 'ERCC-00099', 'ERCC-00108', 'ERCC-00109',
#        'ERCC-00111', 'ERCC-00112', 'ERCC-00113', 'ERCC-00116', 'ERCC-00126',
#        'ERCC-00130', 'ERCC-00131', 'ERCC-00134', 'ERCC-00136', 'ERCC-00137',
#        'ERCC-00138', 'ERCC-00143', 'ERCC-00144', 'ERCC-00145', 'ERCC-00147',
#        'ERCC-00148', 'ERCC-00150', 'ERCC-00154', 'ERCC-00157', 'ERCC-00160',
#        'ERCC-00162', 'ERCC-00163', 'ERCC-00164', 'ERCC-00165', 'ERCC-00170',
#        'ERCC-00171'],
#       dtype='object', name='index')

# %%
adata = adata[:,~adata.var_names.isin(ercc_genes)]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 1272 × 24626
#     obs: 'plate', 'well', 'tissue', 'primary_sort', 'anatomical_position', 'sort_order', 'well_group', 'excluded', 'sort_direction', 'investigator', 'barcode', 'cDNA_prep_person', 'cDNA_dilute', 'library_prep', 'lib_prep_date', 'bead_cleanup', 'BA_nM', 'NovaSeqRun', 'additional_notes', 'n_genes'
#     var: 'n_cells'

# %%
adata.var_names
# Out:
# Index(['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', 'A2M-AS1', 'A2ML1', 'A2MP1',
#        'A3GALT2', 'A4GALT', 'A4GNT',
#        ...
#        'ZWILCH', 'ZWINT', 'ZXDA', 'ZXDB', 'ZXDC', 'ZYG11A', 'ZYG11B', 'ZYX',
#        'ZZEF1', 'ZZZ3'],
#       dtype='object', name='index', length=24626)

# %%
sc.pp.filter_cells(adata, min_genes=500)
sc.pp.filter_cells(adata, min_counts=5000)
sc.pp.filter_genes(adata, min_cells=3)
# Out:
# Trying to set attribute `.obs` of view, making a copy.

# %%
set(adata.obs['tissue'])
# Out:
# {'Muscle'}

# %% [markdown]
# Compute the nUMIS (using 'n_counts' as generic column name)

# %%
# adata.obs['n_counts'] = adata.X.sum(axis=1)#.A1

# %% [markdown]
# Look at the overall distribution of the data

# %%
sc.pl.violin(adata, ['n_genes', 'n_counts'],jitter=0.4, multi_panel=True)

# %%
sc.pl.scatter(adata, x='n_counts', y='n_genes')

# %% [markdown]
# Because we're doing first exploratory pass let's remove cells that have more than 5000 genes given that those have higher chances of being doublets

# %%
#adata = adata[adata.obs['n_genes'] < 5000, :]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1174 × 18864
#     obs: 'plate', 'well', 'tissue', 'primary_sort', 'anatomical_position', 'sort_order', 'well_group', 'excluded', 'sort_direction', 'investigator', 'barcode', 'cDNA_prep_person', 'cDNA_dilute', 'library_prep', 'lib_prep_date', 'bead_cleanup', 'BA_nM', 'NovaSeqRun', 'additional_notes', 'n_genes', 'n_counts'
#     var: 'n_cells'

# %% [markdown]
# Following the standard pipeline, next we normalize, log, compute highly variable genes and scale

# %%
sc.pp.normalize_per_cell(adata, counts_per_cell_after=1e4)

# %%
sc.pp.log1p(adata)

# %%
adata.raw = adata

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)

# %%
sc.pl.highly_variable_genes(adata)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1174 × 18864
#     obs: 'plate', 'well', 'tissue', 'primary_sort', 'anatomical_position', 'sort_order', 'well_group', 'excluded', 'sort_direction', 'investigator', 'barcode', 'cDNA_prep_person', 'cDNA_dilute', 'library_prep', 'lib_prep_date', 'bead_cleanup', 'BA_nM', 'NovaSeqRun', 'additional_notes', 'n_genes', 'n_counts'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'

# %%
sc.pp.scale(adata, max_value=10)

# %% [markdown]
# Next we compute PCA

# %%
sc.tl.pca(adata, svd_solver='arpack')

# %%
sc.pl.pca(adata, color='tissue')

# %%
sc.pl.pca_variance_ratio(adata, log=True)

# %%
sc.pl.pca_overview(adata)

# %% [markdown]
# Now we're ready to start fishing out some structure in the data

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=10)

# %%
sc.tl.louvain(adata)
sc.tl.leiden(adata)

# %%
sc.tl.umap(adata)

# %%
# sc.settings.set_figure_params(dpi=200)
sc.pl.umap(adata, color=['tissue'])

# %%
set(adata.obs['tissue'])
# Out:
# {'Muscle'}

# %%
sc.pl.umap(adata, color=['tissue'],use_raw=False)

# %% [markdown]
# Let's take a look at one tissue as e.g. for batch effect...

# %%
adata.obs.columns
# Out:
# Index(['plate', 'well', 'tissue', 'primary_sort', 'anatomical_position',
#        'sort_order', 'well_group', 'excluded', 'sort_direction',
#        'investigator', 'barcode', 'cDNA_prep_person', 'cDNA_dilute',
#        'library_prep', 'lib_prep_date', 'bead_cleanup', 'BA_nM', 'NovaSeqRun',
#        'additional_notes', 'n_genes', 'n_counts', 'louvain', 'leiden'],
#       dtype='object')

# %%
sc.pl.umap(adata, color=['primary_sort','louvain','plate','leiden'],ncols=2)

# %% [markdown]
# Looking good! Into clustering...

# %%
sc.pl.umap(adata, color=['tissue','primary_sort'])
sc.pl.umap(adata, color=['louvain','leiden'], legend_loc='on data')

# %%
sc.pl.violin(adata, ['n_counts'],jitter=0.4, groupby='louvain')
sc.pl.violin(adata, ['n_genes'],jitter=0.4, groupby='louvain')

# %% [markdown]
# Using the wilcoxon rank test we can compute the marker genes for each of the 45 global clusters

# %%
sc.tl.rank_genes_groups(adata, 'leiden', method='wilcoxon')

# %%
sc.pl.rank_genes_groups(adata, n_genes=25, sharey=False)

# %%
sapiens_rank_genes = pd.DataFrame(adata.uns['rank_genes_groups']['names'])
# sapiens_rank_genes.to_csv('/maca-bulk/sapiens/tabula-sapiens-10X-pilot-filtered-global-rank-genes.csv')
sapiens_rank_genes.head(50)
# Out:
#            0         1          2         3         4          5         6  \
# 0       MYOC       GSN       MEG3     PLVAP    MS4A6A     NOTCH3      TNXB
# 1       APOD       C1R       DLK1     ACKR1      MRC1     IGFBP7       GSN
# 2   SERPING1        C3     CHRNA1     RAMP3      AIF1       MYL9    COL6A2
# 3        DCN       DCN      APOC1    TM4SF1    TYROBP       RGS5     FSTL1
# 4       GPX3    SCARA5       APOE      THBD     F13A1        CPE    COL6A3
# 5        C1S       C1S       MYF5    IGFBP4    FCGR2B      SPARC    COL1A2
# 6        MGP       CFD   HSP90AB1       IL6     CSF1R   NDUFA4L2     MFAP5
# 7      FBLN1    COL6A3       PON2    PECAM1    FCGR2A      ACTA2      FBN1
# 8      MFAP4     FBLN5       EIF1    PCAT19     VSIG4     PDGFRB     SMOC2
# 9      PTPRS     FBLN2     IGFBP5      AQP1    FCER1G      CALD1       DPT
# 10       LUM     ADH1B       MEST   ADAMTS9       LYZ      TIMP3      ISLR
# 11  SERPINF1      MMP2       DAG1      RND1      MSR1   CRISPLD2    COL6A1
# 12     PRELP     LTBP4      GPM6B     MCTP1     CD163     STEAP4     FBLN2
# 13      CILP    COL6A2      CADM2      SELE      C1QA      ABCC9      CILP
# 14    RNASE4      GPX3       TRDN    C2CD4B       FTL    ADAMTS1     LAMC1
# 15       GSN  SERPING1     CXCL14       VWF      CD68     IGFBP5      MMP2
# 16       CFH     MFAP4       RPL3    TSPAN7      CTSS      MFGE8      NID1
# 17    CYBRD1    PDGFRL       CD63     RCAN1      CYBB       EPS8     LTBP4
# 18      LRP1       DPT    SLC47A1     NPDC1     FOLR2      TAGLN    IGFBP6
# 19       CFD     ABCA8      HMGN2   ADAMTS4      CD14    TINAGL1     ACKR3
# 20     GPNMB      LRP1       MT1X      CSF3      CTSB     COX4I2       DCN
# 21     SLIT2  SERPINF1       SGCA      PLAT      C1QC      ITGA7       C1R
# 22     ADH1B     FBLN1      RPL41      CD74     IFI30     MALAT1     LAMA2
# 23     LAMA2    IGFBP6       MAFF    LRRC32  HLA-DRB1       GJC1       CFD
# 24    IGFBP6    COL6A1       RPL7      ETS2     STAB1        AXL       LUM
# 25      ISLR     LAMA2     EEF1A1      GJA1      C1QB       GJA4     SVEP1
# 26       C1R    COL1A2    SPATS2L    CDKN1A      PLEK       CD36       FN1
# 27      CTSK    EFEMP1       UGCG    ATP1A1     LYVE1      MUC3A    PCOLCE
# 28        C3       LUM      RPL15     ICAM1     MS4A7    ADAMTS4    PDGFRL
# 29    COL6A3      CILP       RPL5     ECSCR     TGFBI    GUCY1A3      CST3
# 30    EFEMP1     LAMC1      YWHAE    FKBP1A  HLA-DRB5       MT1A      LRP1
# 31     TIMP2      APOD       CNN3     ACTN1   HLA-DRA       MCAM   COL15A1
# 32     NUPR1     PTPRS     RPL10A   HLA-DRA      NPC2     EGFLAM     ITIH5
# 33    COL1A2      SDC2      GREM1      JAM2      PLTP       MT2A      MRC2
# 34   COL12A1  LGALS3BP        MYC       CLU      CD83        A2M        C3
# 35    CXCL14     FSTL1  TNFRSF12A     IL1R1     CXCL8       CLMN      VCAN
# 36     PMP22    CXCL12      RPL24     CYYR1      CST3  ACTA2-AS1      FHL1
# 37       DPT      MYOC      RPS3A  HLA-DRB5      MAFB       TPM2  SERPINF1
# 38     FBLN5     NEGR1     GNB2L1     CCL14   HLA-DMA      ADIRF  LGALS3BP
# 39     NTRK2     PMP22       NNMT    CALCRL       CD4     SLC2A4   COL12A1
# 40    COL6A1   COL12A1       DDX5     IFI27  HLA-DRB6      NR2F2    PDGFRA
# 41      MMP2    CCDC80      EEF1G  HLA-DRB1    GPR183       TPM1     FBLN5
# 42    PDGFRL     MFAP5       GLUL      TGM2     ITGAM     IFITM1     HSPG2
# 43    SCARA5      ISLR       SBDS      LY6E  RASGEF1B   PPP1R14A    COL3A1
# 44    COL1A1     ABCA9      CRYAB       PNP      GPX1     ISYNA1    COL4A1
# 45    ABI3BP      PODN       WTAP     CRIP2     PTPRE      EPAS1      LSP1
# 46      EBF1       MGP      CALCR      CD93      CD74     ATP1B2     MXRA8
# 47     MGST1      FBN1       SOX4     RAMP2    RNASE1   ARHGEF17      PLAU
# 48     ABCA8     SLIT2      ANXA5      FLT1     MPEG1      NDRG2     MFAP4
# 49    PDGFRA      TNXB       WBP5     NDRG1       SYK    SPARCL1     PLAC9
#
#            7         8         9        10        11        12         13  \
# 0     TM4SF1     CXCR4       A2M      PRF1     FABP4   ARHGDIB        MGP
# 1     TMSB10      CD52     IFI27      NKG7     BTNL9     RPS27       APOD
# 2       CD74     PTPRC     FABP4      GNLY      CD36      CREM   MTRNR2L8
# 3      IFI27     CRIP1      WARS      GZMB     FABP5      CD52     MALAT1
# 4      ADIRF    STK17B      CAV1      CST7    ADGRF5     RPLP1        FTL
# 5     PECAM1   ARHGDIB    TM4SF1      CCL5      CDH5     CXCR4     S100A6
# 6    HLA-DRA      IL7R      BST2     PTPRC      WARS     RPS19   MTRNR2L1
# 7     IFITM3     ANXA1     GNG11      CTSW       A2M      SRGN        DCN
# 8        VWF       EZR     EPAS1      LCP1     CLDN5      RPS6   MTRNR2L2
# 9        B2M     ARL4C    RNASE1     HLA-C     GNG11     RPL37     CXCL14
# 10     FABP5      IL32     S1PR1     HLA-A      MGLL    TMSB4X       FTH1
# 11      SELE   TSC22D3     FABP5     HLA-H      SDPR       B2M        LUM
# 12       IL6     SARAF       VWF     KLRD1    ABLIM3     RPS29      NUPR1
# 13    MALAT1      CD3D      CDH5      GZMH    NOTCH4     RPL21       MYOC
# 14     RPL21     HLA-A       B2M     HLA-B        F8    MALAT1  MTRNR2L10
# 15      THBD     RPS27     CXCL2      PFN1     ANXA3     RPS14   MTRNR2L6
# 16    TMSB4X   SLC38A1      CD74      RAC2      NRP1      PFN1      RPS27
# 17  HLA-DRB1      SRGN     CLDN5     ITGB2      AQP1     PTPRC      RPL31
# 18    NFKBIA      CFL1     HLA-E     IL2RG      STOM     RPL30       RPL7
# 19    PCAT19      CD44      SDPR      HCST      TJP1    RPL18A      ADH1B
# 20    RNASE1     YPEL5      CD36     ARL4C   PHACTR2      PTMA      SLIT2
# 21    IFITM1     IL2RG    PECAM1      CREM      ESAM      CD69    LAPTM4A
# 22      AQP1      LCP1  SLC9A3R2     RUNX3   CLEC14A     RPS18        C1S
# 23     ACKR1    FAM46C      MGLL    STK17B       CA4    LAPTM5        CFD
# 24     RPS14     RUNX3      FLT1     CD247     EPAS1      CD53        UBB
# 25      CCL2      RGCC     ANXA3   PIP4K2A     S1PR1      IL32        VIM
# 26      PTMA      CCL5    NOTCH4     CXCR4       VWF      EMP3    PLA2G2A
# 27      EMCN   ZFP36L2      ESAM    FCGR3A      BST2     RPL34      RPL34
# 28      CD93   TNFAIP3     BTNL9       B2M      EMCN    RPL23A     EFEMP1
# 29     RPS18       CD2  HLA-DRB5     ARPC2  SLC9A3R2     ANXA1      SEC62
# 30  HLA-DRB5    GPR183   CLEC14A     LITAF     ITGA6  CDC42SE2      RPS14
# 31     ICAM1      STK4        F8      CFL1      CAV1     RPL10        CFH
# 32      FLT1      CREM  HLA-DRB1      GNG2    ADGRL4     RPL41      RPS18
# 33     S1PR1     HLA-H   FAM107A      CD53      FLT1    STK17B      ITM2A
# 34      RAC1  CDC42SE2     ICAM2  TNFRSF1B     IFI27    RPL37A       CTSK
# 35    SLC2A3    LAPTM5     HLA-B     PLAC8      RGS5    RPL13A      TIMP2
# 36      JAM2      PFN1      TJP1   ARHGDIB      LAP3     RPS3A         C3
# 37   ADAMTS4      RAC2      LAP3     STAT4      RGCC  HSP90AA1      FBLN1
# 38     RPS27      RPS3      EMCN     S1PR5     RAMP2      LCP1       BDH2
# 39    C2CD4B     MPZL3      CD93      IL32    RNASE1     SARAF       GPX3
# 40      CD59    TAGLN2    ABLIM3      CYBA    PECAM1     RPL32      MGST1
# 41       A2M       B2M     ECSCR     SARAF   CD300LG     CRIP1     TMSB4X
# 42      CSF3    SAMSN1     HSPB1    TMSB4X     HLA-E     RPL27     IFITM3
# 43     HSPB1     YWHAZ     PALMD    ADGRE5     NEDD9     NR4A2    RPS14P3
# 44     MYCT1    TMSB4X      CD59    CLEC2D      CAV2     RPS15      CALM2
# 45     MCTP1     DUSP2   SPARCL1      CD52      HES1   RPS14P3      RPLP1
# 46     HLA-B      CD53    ADGRF5     CCND2    TM4SF1       CD2      SERF2
# 47       CLU    EEF1A1     HLA-C    SH2D2A    APOLD1    RPS27A     FTH1P3
# 48     RPS19    ATP2B1      CAV2    CNOT6L     HLA-C  SH3BGRL3     COL1A2
# 49      RPL7      CD69  HLA-DRB6    VPS37B     CXCL2      RPS3        GSN
#
#            14        15        16         17
# 0       MYH11  SERPINA1      RGS5       MYOT
# 1       ACTA2     ITGAX      CD36        CKM
# 2       CASQ2     C5AR1  NDUFA4L2        CA3
# 3       TAGLN      CTSS      MYL9         MB
# 4        MYL9     TIMP1     FABP4       PYGM
# 5        TPM2     PLAUR     SPARC      ACTA1
# 6       LMOD1    ATP2B1     ABCC9      MYOZ1
# 7       NRIP2    FCER1G    NOTCH3       ENO3
# 8      SORBS2     IFI30     FRMD3      MYLPF
# 9      MUSTN1      SAT1       CPE      CASQ1
# 10       DSTN     COTL1      SDPR        SLN
# 11        PLN      CYBB     MFGE8     MYBPC1
# 12     SYNPO2    BCL2A1    COX4I2      TNNC2
# 13  ACTA2-AS1      IL1B  CDC42BPA       LDB3
# 14      CSRP1      SRGN      WARS       TCAP
# 15       MCAM    TYROBP    HIGD1B      ALDOA
# 16      RERGL      AQP9       A2M        TTN
# 17       FLNA    CD300E      FLT1       FHL1
# 18       MYLK      AIF1     EPAS1       ASB2
# 19      ADIRF       LYZ     ACTA2  LOC653513
# 20    GUCY1A3     ANPEP    DPYSL2        DES
# 21   C11orf96      ZEB2      CAV2     KLHL41
# 22     IGFBP5      FTH1    ADGRF5      CMYA5
# 23        LBH      TYMP     NR4A1    PDE4DIP
# 24   PPP1R12A     MYO9B      ESAM       BIN1
# 25     NOTCH3       FGR       LPL       TPM2
# 26        LPP      JUND     BTNL9      HSPB6
# 27      MFGE8   SLC11A1     FABP5     SLC2A4
# 28       CDH6      FCN1      CAV1       SVIL
# 29       MYL6     NBPF8        F8     COX7A1
# 30   PPP1R12B      FPR1    IGFBP7      CRYAB
# 31   PPP1R14A      LST1    IFITM1       MYL1
# 32      RCAN2  TNFRSF1B      EMCN     COX6A2
# 33       ACTB     PTPRE     IFI27    APOBEC2
# 34     MAPRE2      EREG    APOLD1      PGAM2
# 35       TNS1      CD44    TMEM88      PADI2
# 36      HSPB6     ITGB2      NMD3       G0S2
# 37       CYCS      G0S2      STOM      ACTN2
# 38     PTP4A3    LAPTM5     MYO1B    C8orf22
# 39      CALD1    S100A9   TINAGL1     DDIT4L
# 40     NDUFA4      LCP1      EPS8        NEB
# 41      ITGA8      MAFB     NR2F2       FHL3
# 42   CRISPLD2   ATP13A3     CXCL2     PDLIM3
# 43      EDNRA      PSAP    TM4SF1       YBX3
# 44     PPP1CB      PLEK   GUCY1B3       GBAS
# 45      ZFHX3     NEAT1     TIMP3    SLC25A4
# 46    GADD45B    SAMSN1     PODXL       TRDN
# 47   NDUFA4L2     ACSL1     HBEGF      POTEE
# 48       CLMN     MPEG1       CD9      HSPB1
# 49    TSC22D1      ACTB  SLC9A3R2       NEXN

# %%
muscleSC = ['PAX7','MYF5','MYOD1','NCAM1','CD82','EGFR']
# Cd56 = NCAM1
mesenchymalSC = ['PDGFRA','THY1']
# Cd90 = THY1
tcells = ['CD3E']
monocytes = ['PTPRC']
endothelial = ['PECAM1']
bcell = ['CD79B']
tenocyte = ['SCX']
schwanncell = ['SOX10']

# %%
sc.pl.umap(adata,color=['louvain','leiden'],legend_loc='on data',cmap='Oranges')
sc.pl.umap(adata,color=muscleSC,legend_loc='on data',cmap='Oranges')
sc.pl.umap(adata,color=mesenchymalSC,legend_loc='on data',cmap='Oranges')
sc.pl.umap(adata,color=tcells,legend_loc='on data',cmap='Oranges')
sc.pl.umap(adata,color=monocytes,legend_loc='on data',cmap='Oranges')
sc.pl.umap(adata,color=endothelial,legend_loc='on data',cmap='Oranges')
sc.pl.umap(adata,color=bcell,legend_loc='on data',cmap='Oranges')
sc.pl.umap(adata,color=tenocyte,legend_loc='on data',cmap='Oranges')
# sc.pl.umap(adata,color=schwanncell,legend_loc='on data',cmap='Oranges') # not found

# %%
muscle_leiden_cell_ontology_facs = {}
muscle_leiden_cell_ontology_facs['2'] = 'muscle stem cell'
muscle_leiden_cell_ontology_facs['0'] = 'mesenchymal stem cell'
muscle_leiden_cell_ontology_facs['1'] = 'mesenchymal stem cell'
muscle_leiden_cell_ontology_facs['6'] = 'mesenchymal stem cell'
muscle_leiden_cell_ontology_facs['13'] = 'mesenchymal stem cell'
muscle_leiden_cell_ontology_facs['10'] = 'T cells'
muscle_leiden_cell_ontology_facs['8'] = 'T cells'
muscle_leiden_cell_ontology_facs['12'] = 'T cells'
muscle_leiden_cell_ontology_facs['4'] = 'endothelial'
muscle_leiden_cell_ontology_facs['15'] = 'endothelial'
muscle_leiden_cell_ontology_facs['3'] = 'endothelial'
muscle_leiden_cell_ontology_facs['7'] = 'endothelial'
muscle_leiden_cell_ontology_facs['9'] = 'endothelial'
muscle_leiden_cell_ontology_facs['11'] = 'endothelial'
muscle_leiden_cell_ontology_facs['16'] = 'endothelial'
muscle_leiden_cell_ontology_facs['17'] = 'skeletal muscle cell'
muscle_leiden_cell_ontology_facs['5'] = 'smooth muscle cell'
muscle_leiden_cell_ontology_facs['14'] = 'smooth muscle cell'
muscle_leiden_cell_ontology_facs
# Out:
# {'2': 'muscle stem cell',
#  '0': 'mesenchymal stem cell',
#  '1': 'mesenchymal stem cell',
#  '6': 'mesenchymal stem cell',
#  '13': 'mesenchymal stem cell',
#  '10': 'T cells',
#  '8': 'T cells',
#  '12': 'T cells',
#  '4': 'endothelial',
#  '15': 'endothelial',
#  '3': 'endothelial',
#  '7': 'endothelial',
#  '9': 'endothelial',
#  '11': 'endothelial',
#  '16': 'endothelial',
#  '17': 'skeletal muscle cell',
#  '5': 'smooth muscle cell',
#  '14': 'smooth muscle cell'}

# %% [markdown]
# Look at different cell types. The idea is to subcluster based on the global cell

# %%
adata.obs['cell_ontology_class'] = adata.obs['leiden'].map(muscle_leiden_cell_ontology_facs)
set(adata.obs['cell_ontology_class'])
# Out:
# {'T cells',
#  'endothelial',
#  'mesenchymal stem cell',
#  'muscle stem cell',
#  'skeletal muscle cell',
#  'smooth muscle cell'}

# %%
adata.write('../../data-objs/Muscle_facs_annotation_round_1.h5ad')
# Out:
# ... storing 'cell_ontology_class' as categorical

# %% [markdown]
# # Annotate the DROPLET data

# %%
adata = tiss_droplet
adata
# Out:
# AnnData object with n_obs × n_vars = 6230 × 21380
#     obs: '10X_plate', 'batch', 'tissue', 'method', 'sex', 'subjectid', 'n_genes'
#     var: 'n_cells'

# %%
igg_genes = adata.var_names[adata.var_names.str.startswith('IGG')]
igg_genes
# Out:
# Index([], dtype='object', name='index')

# %%
ercc_genes = adata.var_names[adata.var_names.str.startswith('ERCC')]
ercc_genes = list(set(ercc_genes)-set(['ERCC6L2', 'ERCC6L']))
ercc_genes
# Out:
# ['ERCC3', 'ERCC5', 'ERCC6', 'ERCC2', 'ERCC8', 'ERCC4', 'ERCC1']

# %%
adata = adata[:,~adata.var_names.isin(ercc_genes)]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 6230 × 21373
#     obs: '10X_plate', 'batch', 'tissue', 'method', 'sex', 'subjectid', 'n_genes'
#     var: 'n_cells'

# %%
sc.pp.filter_cells(adata, min_genes=300)
sc.pp.filter_cells(adata, min_counts=2000)
sc.pp.filter_genes(adata, min_cells=3)
# Out:
# Trying to set attribute `.obs` of view, making a copy.

# %%
set(adata.obs['tissue'])
# Out:
# {'muscle'}

# %% [markdown]
# Compute the nUMIS (using 'n_counts' as generic column name)

# %%
#adata.obs['n_counts'] = adata.X.sum(axis=1)#.A1

# %% [markdown]
# Look at the overall distribution of the data

# %%
sc.pl.violin(adata, ['n_genes', 'n_counts'],jitter=0.4, multi_panel=True)

# %%
sc.pl.scatter(adata, x='n_counts', y='n_genes')

# %% [markdown]
# Because we're doing first exploratory pass let's remove cells that have more than 5000 genes given that those have higher chances of being doublets

# %%
#adata = adata[adata.obs['n_genes'] < 5000, :]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2818 × 17480
#     obs: '10X_plate', 'batch', 'tissue', 'method', 'sex', 'subjectid', 'n_genes', 'n_counts'
#     var: 'n_cells'

# %% [markdown]
# Following the standard pipeline, next we normalize, log, compute highly variable genes and scale

# %%
sc.pp.normalize_per_cell(adata, counts_per_cell_after=1e4)

# %%
sc.pp.log1p(adata)

# %%
adata.raw = adata

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)

# %%
sc.pl.highly_variable_genes(adata)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2818 × 17480
#     obs: '10X_plate', 'batch', 'tissue', 'method', 'sex', 'subjectid', 'n_genes', 'n_counts'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'

# %%
sc.pp.scale(adata, max_value=10)

# %% [markdown]
# Next we compute PCA

# %%
sc.tl.pca(adata, svd_solver='arpack')

# %%
sc.pl.pca(adata, color='tissue')

# %%
sc.pl.pca_overview(adata)

# %% [markdown]
# Now we're ready to start fishing out some structure in the data

# %%
sc.pp.neighbors(adata, n_neighbors=12, n_pcs=10)

# %%
sc.tl.louvain(adata)
sc.tl.leiden(adata)

# %%
sc.tl.umap(adata)

# %%
# sc.settings.set_figure_params(dpi=200)
sc.pl.umap(adata, color=['tissue'])

# %%
set(adata.obs['tissue'])
# Out:
# {'muscle'}

# %%
sc.pl.umap(adata, color=['tissue'],use_raw=False)

# %% [markdown]
# Let's take a look at one tissue as e.g. for batch effect...

# %%
adata.obs.columns
# Out:
# Index(['10X_plate', 'batch', 'tissue', 'method', 'sex', 'subjectid', 'n_genes',
#        'n_counts', 'louvain', 'leiden'],
#       dtype='object')

# %%
sc.pl.umap(adata, color=['10X_plate','louvain','leiden'])

# %% [markdown]
# Looking good! Into clustering...

# %%
adata.obs.columns
# Out:
# Index(['10X_plate', 'batch', 'tissue', 'method', 'sex', 'subjectid', 'n_genes',
#        'n_counts', 'louvain', 'leiden'],
#       dtype='object')

# %%
sc.pl.umap(adata, color=['tissue','10X_plate'])
sc.pl.umap(adata, color=['louvain','leiden'], legend_loc='on data')

# %%
sc.pl.violin(adata, ['n_counts'],jitter=0.4, groupby='louvain')
sc.pl.violin(adata, ['n_genes'],jitter=0.4, groupby='louvain')

# %% [markdown]
# Using the wilcoxon rank test we can compute the marker genes for each of the 45 global clusters

# %%
sc.tl.rank_genes_groups(adata, 'leiden', method='wilcoxon')

# %%
sc.pl.rank_genes_groups(adata, n_genes=25, sharey=False)

# %%
sapiens_rank_genes = pd.DataFrame(adata.uns['rank_genes_groups']['names'])
# sapiens_rank_genes.to_csv('/maca-bulk/sapiens/tabula-sapiens-10X-pilot-filtered-global-rank-genes.csv')
sapiens_rank_genes.head(50)
# Out:
#            0         1         2         3         4         5         6  \
# 0     COL6A2     APOC1       MGP     FABP4       DCN      CAV1     ACKR1
# 1      MFAP5      DLK1     FBLN1     FABP5       GSN     GNG11     PLVAP
# 2      FBLN2      APOE    EFEMP1     EGFL7      APOD     FABP4      SELE
# 3     COL6A1    CHRNA1       C1S     CLDN5       DPT      CD36    IGFBP4
# 4      SMOC2    RPL10A     MGST1      BST2    COL6A2     CLDN5     IL1R1
# 5     COL1A2      RPL3    CXCL14     HLA-B       CFD      RGCC     RAMP3
# 6       FBN1      RPL5      MYOC      CAV1      MMP2      MGLL     NPDC1
# 7     PDGFRL     RPL24        C3       B2M     LTBP4     FABP5      CD74
# 8      LAMC1      MEG3       CFH  SLC9A3R2    COL6A3     BTNL9       IL6
# 9     COL6A3     RPS3A       C1R     GNG11    COL6A1      SDPR    ATP1A1
# 10     FSTL1     RPL18      GPX3   CLEC14A     ADH1B    ADGRF5   ADAMTS9
# 11       DCN   SPATS2L      APOD     HLA-A      GPX3     ANXA3   HLA-DRA
# 12      CST3      RPL6       CFD      MGLL     SMOC2     HLA-C      PLAT
# 13     ACKR3      RPS3      PODN     HLA-C    PDGFRL      CDH5      GJA1
# 14     LTBP4     RPL41    CYBRD1     IFI27     LAMC1      BST2      AQP1
# 15       CFD      RPS2    SCARA5     BTNL9     NOVA1  SLC9A3R2  HLA-DQA1
# 16       GSN    RPL13A      LRP1      RGCC        C3      CAV2     NDRG1
# 17     LAMA2  PPP1R14B  SERPING1     HLA-E     FBLN5   CLEC14A      ETS2
# 18     PLAC9      RPL9     NOVA1      CD36     WISP2      WARS    PECAM1
# 19       DPT      NACA       GSN    HSPA1A    IGFBP6    TMEM88    PCAT19
# 20     FBLN5     RPL26       FTL      SDPR       C1R     HLA-B  HLA-DQB1
# 21      MRC2    GNB2L1    CCDC80    HSPA1B       C1S       A2M  HLA-DPA1
# 22  SERPINF1     RPS21     EPHX1    TM4SF1  SERPINF1      EMCN      THBD
# 23      SDC2    TUBB2B     SEPP1     CXCL2     FBLN1       VWF      RND1
# 24      MMP2     RPS18     MFAP4      CAV2     LAMA2     HLA-E    TM4SF1
# 25      NID1      MYF5      SOD3    ADGRF5      CILP     HLA-A       PNP
# 26    IGFBP6      RPL4       VIM      EMCN     PLAC9       B2M    C2CD4B
# 27   LRRN4CL     RPL17  SERPINF1      LAP3      LRP1     EGFL7    CALCRL
# 28      ISLR     RPL12      FTH1      IER2       MGP        F8    FKBP1A
# 29     WISP2      RPL7       DPT     SOX18     MGST1      STOM     ECSCR
# 30    PDGFRA    RPL35A     NUPR1     SOCS3     FBLN2   GPIHBP1   ADAMTS4
# 31  SERPING1    RPS27A     GPNMB      CDH5      SDC2   SEC14L1       CLU
# 32     HSPG2     CADM2   PLA2G2A      STOM    SCARA5   PHACTR2  HLA-DPB1
# 33   ANGPTL2     RPL34       LUM       A2M      FBN1     SOX18  HLA-DRB5
# 34    PCOLCE     GPM6B       DCN        F8     ABCA8     TCF15     ICAM1
# 35       C1R      RPS6    RNASE4    RNASE1     MFAP5    GIMAP7  HLA-DRB1
# 36       LUM    IGFBP5      MMP2       VWF    PDGFRA     IFI27       VWF
# 37      CILP     RPS13    PDGFRA      HES1     HTRA3    LGALS3      GUK1
# 38        C3     RPL39     FBLN5    DNAJB1      CST3    RNASE1    DUSP23
# 39    COL3A1     RPL13     TIMP2      SRGN    COL1A2      FLT1      JAM2
# 40     ADH1B      CD63     ABCA8     ICAM2    PPAP2B      ESAM     CPXM2
# 41    SCARA5     RPL21     NEGR1     ANXA3       LUM      AQP1  HLA-DQA2
# 42     ITIH5      RBP1     NTRK2    TMEM88  SERPING1    ADGRL4      CD93
# 43      VCAN     RPL7A     ADH1B      FLT1     NEGR1   TSPAN13      CD59
# 44     NEGR1     RPS4X     SFRP2  HSP90AA1     ACKR3     ICAM2     CLIC2
# 45   COL12A1     RPS24     FBLN2      KLF2     SPON2     ITGA6      CSF3
# 46    CLEC3B     RPS12     WISP2    TMSB10      MYOC       CA4      SELP
# 47    PLXDC1     RPL15     WNT11      ESAM       BOC     KANK3    TSPAN7
# 48     NOVA1     RPL10    PCOLCE     NEDD9    EFEMP1      LAP3     HYAL2
# 49   HSD11B1      PON2      FGF7     ITGA6    RNASE4    C8orf4     VCAM1
#
#            7         8         9  ...        12        13        14       15  \
# 0      MYH11      FHL1       CPE  ...     RAMP3     THBS4    TM4SF1   TYROBP
# 1       DSTN      PYGM  NDUFA4L2  ...   HLA-DRA     PRELP      SRGN     CTSS
# 2      ACTA2    PDLIM3      RGS5  ...     NPDC1      FMOD     IFI27   FCER1G
# 3      TAGLN      MYL1    IGFBP7  ...      CD74     AEBP1    NFKBIA      FTL
# 4       MYL9       SLN    NOTCH3  ...     ACKR1       CD9       B2M     AIF1
# 5      CSRP1     ALDOA     MFGE8  ...  HLA-DPA1      ASPN     HLA-B     CD68
# 6      ADIRF        MB     SPARC  ...     PLVAP      MYOC     HLA-E     CTSB
# 7       MCAM      BIN1    HIGD1B  ...     RPS28      COMP     ICAM1    ITGB2
# 8       FLNA      FHL3     GPAT2  ...  HLA-DRB5      TNMD     CLDN5      LYZ
# 9      LMOD1     GAPDH    MALAT1  ...     ECSCR      CILP     EPAS1    CSF1R
# 10    SORBS2      ENO3      GJA4  ...    PCAT19     FBLN1      THBD     PSAP
# 11      WTIP      TPM2     CALD1  ...  HLA-DQB1   ALDH1A1   CLEC14A     CTSC
# 12     RERGL       CA3    PDGFRB  ...      RPS6   RARRES1    PECAM1   FCGR2A
# 13      MYL6     MYOZ1      CYGB  ...       PNP      MT1X       A2M     CD14
# 14      MYLK       CKM     NR2F2  ...     RPS18     FIBIN     MMRN2   MS4A6A
# 15     CALD1    COX7A1      MYL9  ...      PLAT       FTL    TMSB10     NPC2
# 16  PPP1R14A     ACTN2      EPS8  ...     RPL36     MXRA8      STOM     SRGN
# 17   GUCY1A3      TCAP     ITGB1  ...      THBD    S100A6      CAV1     CYBA
# 18  PPP1R12A   SLC25A4     ACTA2  ...    IGFBP4     MRPS6     HLA-A  RNASET2
# 19  C11orf96     MYLPF     ITM2C  ...     RPS19       LUM    C2CD4B     CTSZ
# 20     RCAN2    EEF1A2   CAMK2N1  ...      RPS2    CYBRD1     HLA-C    CD163
# 21       PLN     ACTA1      MCAM  ...    TMSB10     CIRBP    KCTD12     SPI1
# 22      ACTB       DES    COX4I2  ...      ETS2   S100A13     PODXL     LCP1
# 23     ITGA8      YBX3    IFITM1  ...      CD59    ITGA10    IFITM1     CD74
# 24     CCDC3    COX6A2      TBX2  ...      RPL3     NTRK2     PALMD     CYBB
# 25      TNS1       AK1  PPP1R14A  ...  HLA-DRB1      CD99     SOX17     C1QA
# 26      HES4     PGAM2    EGFLAM  ...      LMO2      SELM    SWAP70     PLEK
# 27    IGFBP5   APOBEC2     ABCC9  ...     RPS12     TIMP2      CDH5  HLA-DRA
# 28      CNN1    ADSSL1    IGFBP2  ...    PECAM1       CFH     HBEGF   LAPTM5
# 29    NOTCH3     TNNC2     MYO1B  ...    TM4SF1     CYR61  HLA-DRB5    MPEG1
# 30      BCAM   C8orf22      TESC  ...      SELE    PIK3R1      CD74    MS4A7
# 31       CKB    PDLIM5      MT2A  ...  HLA-DPB1      CCNI   HLA-DRA    C3AR1
# 32      SNCG      PGM1   ARHGDIB  ...      RPS7     USP53    GIMAP4    PTPRC
# 33    PHLDA2    KLHL41    STEAP4  ...     RPL26    STEAP2      ETS2      CD4
# 34     CASQ2    MYBPC1      CD36  ...    C2CD4B     SFRP2     RAMP2     C1QB
# 35      SOD3     CRYAB     SEPT7  ...     RPL34       CLU    GIMAP1     C1QC
# 36      TBX2     CSRP3   FAM213A  ...    RPS15A        XG      BST2    F13A1
# 37     CALM2      GAMT      LHFP  ...  HLA-DQA1     THBS1      MSX1    TGFBI
# 38   SH3BGRL       PKM   TINAGL1  ...  HLA-DRB6   ANGPTL5    IFITM3   GLIPR1
# 39     CRIP1     ATP5D    PMEPA1  ...      RPL8       VIM      IRF1   GGTA1P
# 40  PPP1R12B    ATP2A1  C20orf27  ...    ADGRL4     LTBP2  SLC9A3R2   FCGR2B
# 41    IGFBP7      LDB3   GUCY1A2  ...     RPL28       PTN     MAST4     EMP3
# 42      TPM2   CHCHD10      UBA2  ...     RPS23   COL12A1      LAP3     GPX1
# 43      UBA2  MIR1-1HG     TIMP3  ...   HLA-DMA      GPX3    CX3CL1     HCST
# 44       ZAK    FBXO32      RHOB  ...    RPS27A    TWIST1      FLT1      GRN
# 45   C2orf40     RPL3L       LPL  ...     HLA-B     MFAP4    RNASE1     CPVL
# 46    NDUFA4    RAD23A     ITGA7  ...      RPS3     MFGE8     EFNB2   PABPC1
# 47    ISYNA1      TPT1   GUCY1A3  ...     IFI27      LEPR      CAV2   IL10RA
# 48      RHOB      MYOT     NR4A1  ...     RPL37       DCN    GIMAP7     MRC1
# 49     MGST3     SEPW1      SIK1  ...  MARCKSL1  SERPINF1    IFI44L    FOLR2
#
#              16        17          18        19      20            21
# 0         TAGLN      HCST         TTN    HIGD1B   RPS28         CTRB2
# 1          SOD3     PTPRC        TRDN  NDUFA4L2    RPL8         PRSS2
# 2         NR2F2      CCL5         NEB      RGS5   RPS4X         CTRB1
# 3        IGFBP7     ARL4C       CMYA5       CPE   RPL32       PLA2G1B
# 4       RARRES2     CXCR4        NRAP     SPARC   RPL39        CELA3B
# 5       C2orf40      CYBA      MYBPC1      TESC   RPL30        SPINK1
# 6        IGFBP5      CD48     ANKRD23       LPL   SERP1        CELA3A
# 7         CALD1     RPS19        NEXN    IGFBP7   RPL11          SYCN
# 8         CSRP1   PTPRCAP      PDLIM5   ARHGDIB   RPS12          CTRC
# 9          MYL9     RPL28        SVIL      EPS8     FAU         AMY2A
# 10        NR4A1      CD52       XIRP2     FRMD3   RPL34        CELA2A
# 11          ID4    TMSB4X        FHL1     MFGE8    SSR4        CELA2B
# 12       SYNPO2       B2M        MYOT     ITM2C   RPS15          CPA1
# 13       STEAP4      SRGN      ATP1A2    NOTCH3   RPL12          CPA2
# 14       ISYNA1      GZMM      ATP1B1    PMEPA1   RPS21          CPB1
# 15        ADIRF      CTSW       LMOD2     ITGB1   RPS23         PRSS1
# 16        LMOD1     RPS29        MURC    PDGFRB   RPL41         PRSS3
# 17       NOTCH3     DUSP2        LDB3  PPP1R14A   RPLP1      PNLIPRP2
# 18         BTG2      CD37  MIR133A1HG      CYGB   RPL19           CEL
# 19        CALM2     CYTIP      PDLIM3    IGFBP2   RPL10         PNLIP
# 20         MT1A     RPS27         DMD   FAM213A  RPS27A           GP2
# 21        TGFBI     ITGB2       MEF2C     ACTA2   RPL36      PNLIPRP1
# 22        ACTA2      LCP1        ASB5      GJA4   RPL18         REG1A
# 23          CPE      IL32       AMPD1     CALD1   RPS10          CLPS
# 24       S100A6     TGFB1      KLHL41     KCNJ8    RPL6          KLK1
# 25        GSTM3     RUNX3        RYR1      MYL9    SRGN         PDIA2
# 26        SEPT7      PFN1      FBXO32      MYH9   RPL22         AMY2B
# 27         DSTN      RAC2      TRIM54     ABCC9  FCER1G          CD24
# 28          LPP      CD53       CORO6    COX4I2   RPL37  LOC100506281
# 29         LGI4      RPS3        MYF6      CD36   RPL7A      SERPINI2
# 30      PLEKHA4     HLA-A       RBM24  SLC9A3R2   SERF2          CTRL
# 31         TNS1   ARHGDIB      SMTNL1     ASAH1    RPS7          GATM
# 32        CEBPD      NKG7    MIR1-1HG     NR2F2    RPL5          RBP1
# 33         FLNA      CST7     PDE4DIP     GPAT2   ARPC3         PRDX4
# 34      ADAMTS4    CORO1A       ACTA1   CAMK2N1     FTL          AQP8
# 35       ZNF331     HLA-C     PPP1R27  C20orf27   RPS26         GSTA2
# 36        CCDC3  SH3BGRL3   HNF1A-AS1     ITGA7   RPS13           ALB
# 37         EPS8      CFL1       CRYAB   GUCY1A2   RPS29          SSR4
# 38          CKB     HLA-B          MB    IFITM1  TPSAB1        RNASE1
# 39        NR4A2      GNLY         DES  MAP1LC3A   TPSB2         ANPEP
# 40        FXYD1      CREM        TCAP      MCAM    CTSG         NUCB2
# 41         GAS5    RPS27A     FAM134B      DKK3   HPGDS         RAMP1
# 42         RPS8      GZMA        ART3     MYO1B   RPL26       SLC39A5
# 43        TIMP3     IL2RG       SESN1   GUCY1A3  EEF1B2         ERP27
# 44  LRRC75A-AS1     ARPC2       STAC3    ISYNA1    RPS3        CLDN10
# 45        NFIL3    RPS15A        ENO3    LGALS1    HPGD          KRT8
# 46         RRAD    RPL23A       TNNC2     FABP4    FTH1          MT1G
# 47         TPM1     RPLP2      SYNPO2    TMSB4X  RPL35A         KRT18
# 48     CRISPLD2     RPS12     FILIP1L       H19    CD37        COMTD1
# 49       IGFBP6      PRF1      FILIP1     FABP5   RPS24      EIF4EBP1
#
# [50 rows x 22 columns]

# %%
muscleSC = ['PAX7','MYF5','MYOD1','NCAM1','CD82','EGFR']
# Cd56 = NCAM1
mesenchymalSC = ['PDGFRA','THY1']
# Cd90 = THY1
tcells = ['CD3E']
monocytes = ['PTPRC']
endothelial = ['PECAM1']
bcell = ['CD79B']
tenocyte = ['SCX']
schwanncell = ['GAP43'] #'SOX10',, 'BLBP'

# %%
sc.pl.umap(adata,color=['louvain','leiden'],legend_loc='on data',cmap='Oranges')
sc.pl.umap(adata,color=muscleSC,legend_loc='on data',cmap='Oranges')
sc.pl.umap(adata,color=mesenchymalSC,legend_loc='on data',cmap='Oranges')
sc.pl.umap(adata,color=tcells,legend_loc='on data',cmap='Oranges')
sc.pl.umap(adata,color=monocytes,legend_loc='on data',cmap='Oranges')
sc.pl.umap(adata,color=endothelial,legend_loc='on data',cmap='Oranges')
sc.pl.umap(adata,color=bcell,legend_loc='on data',cmap='Oranges')
sc.pl.umap(adata,color=tenocyte,legend_loc='on data',cmap='Oranges')
sc.pl.umap(adata,color=schwanncell,legend_loc='on data',cmap='Oranges') # not found

# %%
muscle_leiden_cell_ontology_droplet = {}
muscle_leiden_cell_ontology_droplet['1'] = 'muscle stem cell'
muscle_leiden_cell_ontology_droplet['0'] = 'mesenchymal stem cell'
muscle_leiden_cell_ontology_droplet['4'] = 'mesenchymal stem cell'
muscle_leiden_cell_ontology_droplet['2'] = 'mesenchymal stem cell'
muscle_leiden_cell_ontology_droplet['17'] = 'T cells'
muscle_leiden_cell_ontology_droplet['15'] = 'monocytes'
muscle_leiden_cell_ontology_droplet['20'] = 'monocytes'
muscle_leiden_cell_ontology_droplet['21'] = 'monocytes'
muscle_leiden_cell_ontology_droplet['6'] = 'endothelial'
muscle_leiden_cell_ontology_droplet['12'] = 'endothelial'
muscle_leiden_cell_ontology_droplet['14'] = 'endothelial'
muscle_leiden_cell_ontology_droplet['3'] = 'endothelial'
muscle_leiden_cell_ontology_droplet['5'] = 'endothelial'
muscle_leiden_cell_ontology_droplet['11'] = 'endothelial'
muscle_leiden_cell_ontology_droplet['19'] = 'endothelial'
muscle_leiden_cell_ontology_droplet['13'] = 'tenocyte'
muscle_leiden_cell_ontology_droplet['8'] = 'skeletal muscle cell'
muscle_leiden_cell_ontology_droplet['10'] = 'skeletal muscle cell'
muscle_leiden_cell_ontology_droplet['18'] = 'skeletal muscle cell'
muscle_leiden_cell_ontology_droplet['7'] = 'smooth muscle cell'
muscle_leiden_cell_ontology_droplet['9'] = 'smooth muscle cell'
muscle_leiden_cell_ontology_droplet['16'] = 'smooth muscle cell'
muscle_leiden_cell_ontology_droplet
# Out:
# {'1': 'muscle stem cell',
#  '0': 'mesenchymal stem cell',
#  '4': 'mesenchymal stem cell',
#  '2': 'mesenchymal stem cell',
#  '17': 'T cells',
#  '15': 'monocytes',
#  '20': 'monocytes',
#  '21': 'monocytes',
#  '6': 'endothelial',
#  '12': 'endothelial',
#  '14': 'endothelial',
#  '3': 'endothelial',
#  '5': 'endothelial',
#  '11': 'endothelial',
#  '19': 'endothelial',
#  '13': 'tenocyte',
#  '8': 'skeletal muscle cell',
#  '10': 'skeletal muscle cell',
#  '18': 'skeletal muscle cell',
#  '7': 'smooth muscle cell',
#  '9': 'smooth muscle cell',
#  '16': 'smooth muscle cell'}

# %% [markdown]
# Look at different cell types. The idea is to subcluster based on the global cell

# %%
adata.obs['cell_ontology_class'] = adata.obs['leiden'].map(muscle_leiden_cell_ontology_droplet)
set(adata.obs['cell_ontology_class'])
# Out:
# {'T cells',
#  'endothelial',
#  'mesenchymal stem cell',
#  'monocytes',
#  'muscle stem cell',
#  'skeletal muscle cell',
#  'smooth muscle cell',
#  'tenocyte'}

# %%
adata.obs.head()
# Out:
#                      10X_plate batch  tissue   method     sex subjectid  \
# index
# AAACCCAAGATGTTAG-1-4         2     4  muscle  droplet  female     pilot
# AAACCCAGTTTACACG-1-4         2     4  muscle  droplet  female     pilot
# AAAGGGCAGATGTAGT-1-4         2     4  muscle  droplet  female     pilot
# AAAGGTATCACATTGG-1-4         2     4  muscle  droplet  female     pilot
# AAAGGTATCGGACAAG-1-4         2     4  muscle  droplet  female     pilot
#
#                       n_genes  n_counts louvain leiden cell_ontology_class
# index
# AAACCCAAGATGTTAG-1-4     1972    6043.0       3      1    muscle stem cell
# AAACCCAGTTTACACG-1-4     6542   41982.0       8     11         endothelial
# AAAGGGCAGATGTAGT-1-4     4255   20679.0       2      6         endothelial
# AAAGGTATCACATTGG-1-4     2353    8112.0       3      1    muscle stem cell
# AAAGGTATCGGACAAG-1-4     2423    8252.0       3      1    muscle stem cell

# %%
adata.write('../../data-objs/Muscle_droplet_annotation_round_1.h5ad')
# Out:
# ... storing 'cell_ontology_class' as categorical
